# %%
#some imports
from bs4 import BeautifulSoup
from dateutil import parser

import re,os
import glob

# %%
def read_html_pages_in_dir(pages_dir):
    dict_auteur_mail={}
    #rootdir="./DHFR_sample/"
    for subdir, dirs, files in os.walk(pages_dir):
#ON A LIRE TOU LES FICHIERS DU REP ROOTDIR
        for file in files:
    #V1     if file.endswith('.html') == True  and file != ("index.html") and not re.match("mail\d+.html",file) : 
           if re.match("msg\d+.html",file) : 
          
            # les index.html sont des recap, on pourrait les compter pour s'assurer du nombre de messages
                
                print "\n",os.path.join(subdir, file), "\n"
                champs_auteur={}
                filename=os.path.join(subdir, file)
                soup=BeautifulSoup(open(filename, 'r').read(),'lxml')#, 'html.parser') 
#RECUPERER LE SUJET DU MESSAGE
                
                
                for zone_cible in soup.findAll('ul'):
                    sujet_messg = zone_cible.find(string=re.compile(": \[DH\]"))
                    zone_de_metadonnees_auteur = None
                    i=0
                    for ZC in zone_cible.findAll('strong'):
#TESTER QUE LA ZONE EST BIEN FORMEE               
                        i+=1 
                        zone_de_metadonnees_auteur = zone_cible.strong.parent
                        print zone_de_metadonnees_auteur,"\n\n",i    
                        if sujet_messg is not None:
                         if zone_de_metadonnees_auteur is not None:
                          print "ZMA \n",zone_de_metadonnees_auteur
                          if '<li><strong>From</strong>:' in str(zone_de_metadonnees_auteur):
                          #if r'<li><strong>To</strong>: ' in zone_de_metadonnees_auteur:
                            print zone_de_metadonnees_auteur
                            
                            zone_de_metadonnees_destinataires = zone_cible.strong.parent.parent
                            print "NEXT ELEM", zone_de_metadonnees_destinataires

	##EXEMPLE:
	##_______________
	####<li><strong>From</strong>: Eric Guichard &lt;
	## <script type="text/javascript">
	## <!-- 
	## document.write("Eric.Guichard" + "@" + "enssib.fr")
	## // -->
	## </script>&gt;</li>
	##NOM Eric Guichard
	##MAIL  Eric.Guichard@enssib.fr
	##: [DH] école d'été Méthodes digital es pour SHS - Lyon - 16-20 septembre
	##Eric Guichard
	## 
	##  
	## Eric.Guichard@enssib.fr
	####./DHFRsample/2013-07/msg00018.html 
	
#RECUPERER L AUTEUR DU MESSAGE
	#PARSAGE DE L HTML AUTEUR
                            zone_de_metadonnees_auteur_nettoye  = re.sub(r'<li><strong>From</strong>: ', '',str(zone_de_metadonnees_auteur))
                            #re.compile(re.escape("\" &lt; <script type=\"text/javascript\"> <!\-\-  document\.write(\""))
                            zone_de_metadonnees_auteur_nettoye = re.sub(r' &lt;.*', '',str(zone_de_metadonnees_auteur_nettoye))
                            zone_de_metadonnees_auteur_nettoye= re.sub(r"<script type=\"text/javascript\">",'',str(zone_de_metadonnees_auteur_nettoye))
                            zone_de_metadonnees_auteur_nettoye= re.sub(r"<!--",'',str(zone_de_metadonnees_auteur_nettoye))
                            zone_de_metadonnees_auteur_nettoye= re.sub("document.write\(\"",'',zone_de_metadonnees_auteur_nettoye)
                            zone_de_metadonnees_auteur_nettoye= zone_de_metadonnees_auteur_nettoye.replace("\" + \"@\" + \"",'@')
                            zone_de_metadonnees_auteur_nettoye= re.sub(r"\"\)\n // \-\->\n </script>&gt;</li>","",zone_de_metadonnees_auteur_nettoye)
                            zone_de_metadonnees_auteur_nettoye= re.sub(r"\"\)\n // \-\->\n </script></li>","",zone_de_metadonnees_auteur_nettoye)
                            
                            
                            
                            nom= zone_de_metadonnees_auteur_nettoye.split("\n")[0]
                            try:
                                mail= zone_de_metadonnees_auteur_nettoye.split("\n")[3]
                            except:
                                print "###",zone_de_metadonnees_auteur_nettoye.split("\n")
                                print "\n",os.path.join(subdir, file), "\n"
                                print zone_de_metadonnees_auteur
                                next( ZC)
                            
                            print "NOM",nom
                            print "MAIL",mail
                            champs_auteur["nom_auteur"]=  nom
                            champs_auteur["mail_auteur"]=  mail
                            champs_auteur["ref_physique_de_l_article"]=  os.path.join(subdir, file)
                            champs_auteur["sujet_du_message"] = sujet_messg
                            print sujet_messg
                            #print zone_de_metadonnees_auteur1
                            print zone_de_metadonnees_auteur_nettoye
                            
                            dict_auteur_mail[champs_auteur["ref_physique_de_l_article"]]=champs_auteur
                            #AFFICHAGE DBG
                            print "\n",os.path.join(subdir, file), "\n"
                            print "_______________\n"
                            break
                            
            
#RECUPERER LES DESTINAIRES DU MESSAGE
                    #zone_de_metadonnees_destinataires = zone_cible.strong.parent.next_element
                    #print "NEXT ELEM", zone_de_metadonnees_destinataires

#RECUPERER LES CC DU MESSAGE

#RECUPERER LES DATES ET HEURES DU MESSAGE
                
				
#AFFICHAGE NOM DE FICHIER TRAITE
#                print "\n",os.path.join(subdir, file), "\n"
#                print "_______________\n"
                
                
				
    return dict_auteur_mail

# %%
soup=read_html_pages_in_dir("./DHFRsample")

 

print soup
# Out:
# ./DHFRsample/2011-07/msg00000.html
#
# <li><strong>From</strong>: Maud Ingarao &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("maud.ingarao" + "@" + "ens-lyon.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Maud Ingarao &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("maud.ingarao" + "@" + "ens-lyon.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Maud Ingarao &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("maud.ingarao" + "@" + "ens-lyon.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Maud Ingarao &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("maud.ingarao" + "@" + "ens-lyon.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: Torsten Schassan &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("schassan" + "@" + "hab.de")
#  // -->
#  </script>&gt;,        Christof Schöch &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("c.schoech" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: [DH] Un petit tour d'Allemagne des digital humanities  - 2 : Interview de Torsten Schaßan</li>
# <li><strong>Date</strong>: Thu, 7 Jul 2011 15:59:17 +0200</li>
# </ul>
# NOM Maud Ingarao
# MAIL  maud.ingarao@ens-lyon.fr
# : [DH] Un petit tour d'Allemagne des digital humanities  - 2 : Interview de Torsten Schaßan
# Maud Ingarao
#
#
#  maud.ingarao@ens-lyon.fr
#
# ./DHFRsample/2011-07/msg00000.html
#
# _______________
#
# <li><strong>[DH] Un petit tour d'Allemagne des digital humanities  - 2 : Interview de Torsten Schaßan</strong>, <em>Maud Ingarao, 07/07/2011</em>
# </li>
#
# 1
#
# ./DHFRsample/2011-07/msg00005.html
#
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: "
#  <script type="text/javascript">
#  <!--
#  document.write("DH" + "@" + "cru.fr")
#  // -->
#  </script>" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("DH" + "@" + "cru.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: [DH] RE: Les Historiens et l'Informatique, u n métier à réinventer, actes du colloque de Rome</li>
# <li><strong>Date</strong>: Tue, 19 Jul 2011 08:04:41 -0700</li>
# <li><strong>Accept-language</strong>: fr-FR, en-US</li>
# <li><strong>Acceptlanguage</strong>: fr-FR, en-US</li>
# </ul>
# NOM "Noiret, Serge"
# MAIL  Serge.Noiret@EUI.eu
# : [DH] RE: Les Historiens et l'Informatique, u n métier à réinventer, actes du colloque de Rome
# "Noiret, Serge"
#
#
#  Serge.Noiret@EUI.eu
#
# ./DHFRsample/2011-07/msg00005.html
#
# _______________
#
# <li><strong>[DH] RE: Les Historiens et l'Informatique, u n métier à réinventer, actes du colloque de Rome</strong>, <em>Noiret, Serge, 07/19/2011</em>
# </li>
#
# 1
#
# ./DHFRsample/2011-07/msg00003.html
#
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: "Noiret, Serge" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Serge.Noiret" + "@" + "EUI.eu")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: "'M L'" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marionlame" + "@" + "gmail.com")
#  // -->
#  </script>&gt;,        "
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>"	&lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
# <li><strong>Cc</strong>: dh &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "cru.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: RE: [DH] Consultation de l'Union européenne su r le numérique</li>
# <li><strong>Date</strong>: Mon, 18 Jul 2011 02:06:06 -0700</li>
# <li><strong>Accept-language</strong>: fr-FR, en-US</li>
# <li><strong>Acceptlanguage</strong>: fr-FR, en-US</li>
# </ul>
# NOM "Noiret, Serge"
# MAIL  Serge.Noiret@EUI.eu
# : RE: [DH] Consultation de l'Union européenne su r le numérique
# "Noiret, Serge"
#
#
#  Serge.Noiret@EUI.eu
#
# ./DHFRsample/2011-07/msg00003.html
#
# _______________
#
# <li><strong>RE: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
#
# 1
# ZMA
# <li><strong>RE: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# <li><strong>RE: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
#
# 1
# ZMA
# <li><strong>RE: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# <li><strong>RE: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
#
# 1
# ZMA
# <li><strong>RE: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
#
# ./DHFRsample/2011-07/msg00001.html
#
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: dh &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "cru.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: [DH] Consultation de l'Union européenne sur le  numérique</li>
# <li><strong>Date</strong>: Sat, 16 Jul 2011 14:58:47 +0200</li>
# </ul>
# NOM Marin Dacos
# MAIL  marin.dacos@revues.org
# : [DH] Consultation de l'Union européenne sur le  numérique
# Marin Dacos
#
#
#  marin.dacos@revues.org
#
# ./DHFRsample/2011-07/msg00001.html
#
# _______________
#
# <li><strong>[DH] Consultation de l'Union européenne sur le  numérique</strong>, <em>Marin Dacos, 07/16/2011</em>
# <ul>
# <li><b><a href="msg00002.html" name="00002">Re: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>M L, 07/18/2011</em>
# <ul>
# <li><b><a href="msg00003.html" name="00003">RE: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>[DH] Consultation de l'Union européenne sur le  numérique</strong>, <em>Marin Dacos, 07/16/2011</em>
# <ul>
# <li><b><a href="msg00002.html" name="00002">Re: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>M L, 07/18/2011</em>
# <ul>
# <li><b><a href="msg00003.html" name="00003">RE: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# ./DHFRsample/2011-07/msg00004.html
#
# <li><strong>From</strong>: Laetitia Bontemps &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("laetitia.bontemps" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Laetitia Bontemps &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("laetitia.bontemps" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Laetitia Bontemps &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("laetitia.bontemps" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Laetitia Bontemps &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("laetitia.bontemps" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: "
#  <script type="text/javascript">
#  <!--
#  document.write("DH" + "@" + "cru.fr")
#  // -->
#  </script>" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("DH" + "@" + "cru.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: [DH] Stage initiation XML-TEI (Tours, octobre 2011)</li>
# <li><strong>Date</strong>: Tue, 19 Jul 2011 15:04:42 +0100 (BST)</li>
# </ul>
# NOM Laetitia Bontemps
# MAIL  laetitia.bontemps@univ-tours.fr
# : [DH] Stage initiation XML-TEI (Tours, octobre 2011)
# Laetitia Bontemps
#
#
#  laetitia.bontemps@univ-tours.fr
#
# ./DHFRsample/2011-07/msg00004.html
#
# _______________
#
# <li><strong>[DH] Stage initiation XML-TEI (Tours, octobre 2011)</strong>, <em>Laetitia Bontemps, 07/19/2011</em>
# </li>
#
# 1
#
# ./DHFRsample/2011-07/msg00002.html
#
# <li><strong>From</strong>: M L &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marionlame" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: M L &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marionlame" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: M L &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marionlame" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: M L &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marionlame" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script></li>
# <li><strong>Cc</strong>: dh &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "cru.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: Re: [DH] Consultation de l'Union européenne su r le numérique</li>
# <li><strong>Date</strong>: Mon, 18 Jul 2011 11:01:00 +0200</li>
# </ul>
# NOM M L
# MAIL  marionlame@gmail.com
# : Re: [DH] Consultation de l'Union européenne su r le numérique
# M L
#
#
#  marionlame@gmail.com
#
# ./DHFRsample/2011-07/msg00002.html
#
# _______________
#
# <li><strong>Re: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>M L, 07/18/2011</em>
# <ul>
# <li><b><a href="msg00003.html" name="00003">RE: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>M L, 07/18/2011</em>
# <ul>
# <li><b><a href="msg00003.html" name="00003">RE: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>M L, 07/18/2011</em>
# <ul>
# <li><b><a href="msg00003.html" name="00003">RE: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Consultation de l'Union européenne su r le numérique</strong>, <em>M L, 07/18/2011</em>
# <ul>
# <li><b><a href="msg00003.html" name="00003">RE: [DH] Consultation de l'Union européenne su r le numérique</a></b>, <em>Noiret, Serge, 07/18/2011</em>
# </li>
# </ul>
# </li>
#
# ./DHFRsample/2013-07/msg00030.html
#
# <li><strong>From</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("listes" + "@" + "ahicf.com")
#  // -->
#  </script></li>
#
# 1
# ZMA
# <li><strong>From</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("listes" + "@" + "ahicf.com")
#  // -->
#  </script></li>
# <li><strong>From</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("listes" + "@" + "ahicf.com")
#  // -->
#  </script></li>
# NEXT ELEM <ul>
# <li><strong>From</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("listes" + "@" + "ahicf.com")
#  // -->
#  </script></li>
# <li><strong>To</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("listes" + "@" + "ahicf.com")
#  // -->
#  </script></li>
# <li><strong>Subject</strong>: [DH] [STAGES] L'AHICF recrute - stages à p artir du 1er septembre 2013</li>
# <li><strong>Date</strong>: Thu, 18 Jul 2013 10:20:44 +0200</li>
# </ul>
# NOM
# MAIL  listes@ahicf.com
# : [DH] [STAGES] L'AHICF recrute - stages à p artir du 1er septembre 2013
#
#
#
#  listes@ahicf.com
#
# ./DHFRsample/2013-07/msg00030.html
#
# _______________
#
# <li><strong>[DH] [STAGES] L'AHICF recrute - stages à p artir du 1er septembre 2013</strong>, <em>listes, 07/18/2013</em>
# </li>
#
# 1
#
# ./DHFRsample/2013-07/msg00006.html
#
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: Stéphane Pouyllau &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("stephane.pouyllau" + "@" + "cnrs.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Cc</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script></li>
# <li><strong>Subject</strong>: Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</li>
# <li><strong>Date</strong>: Fri, 5 Jul 2013 12:13:22 +0200</li>
# </ul>
# NOM Pierre Mounier
# MAIL  pierre.mounier@ehess.fr
# : Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto
# Pierre Mounier
#
#
#  pierre.mounier@ehess.fr
#
# ./DHFRsample/2013-07/msg00006.html
#
# _______________
#
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Pierre Mounier, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00007.html" name="00007">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Pierre Mounier, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00007.html" name="00007">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Pierre Mounier, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00007.html" name="00007">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Pierre Mounier, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00007.html" name="00007">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Pierre Mounier, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00007.html" name="00007">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Pierre Mounier, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00007.html" name="00007">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# ./DHFRsample/2013-07/msg00018.html
#
# <li><strong>From</strong>: Eric Guichard &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Eric.Guichard" + "@" + "enssib.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Eric Guichard &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Eric.Guichard" + "@" + "enssib.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Eric Guichard &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Eric.Guichard" + "@" + "enssib.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Eric Guichard &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("Eric.Guichard" + "@" + "enssib.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script></li>
# <li><strong>Subject</strong>: [DH] école d'été Méthodes digital es pour SHS - Lyon - 16-20 septembre</li>
# <li><strong>Date</strong>: Wed, 10 Jul 2013 15:56:42 +0200</li>
# </ul>
# NOM Eric Guichard
# MAIL  Eric.Guichard@enssib.fr
# : [DH] école d'été Méthodes digital es pour SHS - Lyon - 16-20 septembre
# Eric Guichard
#
#
#  Eric.Guichard@enssib.fr
#
# ./DHFRsample/2013-07/msg00018.html
#
# _______________
#
# <li><strong>[DH] école d'été Méthodes digital es pour SHS - Lyon - 16-20 septembre</strong>, <em>Eric Guichard, 07/10/2013</em>
# </li>
#
# 1
#
# ./DHFRsample/2013-07/msg00028.html
#
# <li><strong>From</strong>: Frédéric Clavert &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("frederic" + "@" + "clavert.net")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Frédéric Clavert &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("frederic" + "@" + "clavert.net")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Frédéric Clavert &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("frederic" + "@" + "clavert.net")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Frédéric Clavert &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("frederic" + "@" + "clavert.net")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>:
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script></li>
# <li><strong>Subject</strong>: Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</li>
# <li><strong>Date</strong>: Tue, 16 Jul 2013 10:50:42 +0200</li>
# </ul>
# NOM Frédéric Clavert
# MAIL  frederic@clavert.net
# : Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities
# Frédéric Clavert
#
#
#  frederic@clavert.net
#
# ./DHFRsample/2013-07/msg00028.html
#
# _______________
#
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>(continued)</em>
# <ul>
# <ul>
# <ul>
# <ul>
# <li><b><a href="msg00014.html" name="00014">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Frédéric Clavert, 07/08/2013</em>
# <ul>
# <li><b><a href="msg00016.html" name="00016">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00017.html" name="00017">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
# </ul></li>
# <li><b><a href="msg00023.html" name="00023">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li><li><b><a href="msg00024.html" name="00024">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>antoine Courtin, 07/12/2013</em>
# </li><li><b><a href="msg00027.html" name="00027">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Paul Girard, 07/15/2013</em>
# </li>
# <li><b><a href="msg00026.html" name="00026">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Nicolas Legrand, 07/15/2013</em>
# </li><li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# </ul></li>
# </ul></ul></ul></ul></li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>(continued)</em>
# <ul>
# <ul>
# <ul>
# <ul>
# <li><b><a href="msg00014.html" name="00014">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Frédéric Clavert, 07/08/2013</em>
# <ul>
# <li><b><a href="msg00016.html" name="00016">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00017.html" name="00017">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
# </ul></li>
# <li><b><a href="msg00023.html" name="00023">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li><li><b><a href="msg00024.html" name="00024">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>antoine Courtin, 07/12/2013</em>
# </li><li><b><a href="msg00027.html" name="00027">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Paul Girard, 07/15/2013</em>
# </li>
# <li><b><a href="msg00026.html" name="00026">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Nicolas Legrand, 07/15/2013</em>
# </li><li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# </ul></li>
# </ul></ul></ul></ul></li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>(continued)</em>
# <ul>
# <ul>
# <ul>
# <ul>
# <li><b><a href="msg00014.html" name="00014">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Frédéric Clavert, 07/08/2013</em>
# <ul>
# <li><b><a href="msg00016.html" name="00016">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00017.html" name="00017">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
# </ul></li>
# <li><b><a href="msg00023.html" name="00023">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li><li><b><a href="msg00024.html" name="00024">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>antoine Courtin, 07/12/2013</em>
# </li><li><b><a href="msg00027.html" name="00027">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Paul Girard, 07/15/2013</em>
# </li>
# <li><b><a href="msg00026.html" name="00026">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Nicolas Legrand, 07/15/2013</em>
# </li><li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# </ul></li>
# </ul></ul></ul></ul></li>
#
# 2
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>(continued)</em>
# <ul>
# <ul>
# <ul>
# <ul>
# <li><b><a href="msg00014.html" name="00014">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Frédéric Clavert, 07/08/2013</em>
# <ul>
# <li><b><a href="msg00016.html" name="00016">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00017.html" name="00017">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
# </ul></li>
# <li><b><a href="msg00023.html" name="00023">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li><li><b><a href="msg00024.html" name="00024">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>antoine Courtin, 07/12/2013</em>
# </li><li><b><a href="msg00027.html" name="00027">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Paul Girard, 07/15/2013</em>
# </li>
# <li><b><a href="msg00026.html" name="00026">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Nicolas Legrand, 07/15/2013</em>
# </li><li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# </ul></li>
# </ul></ul></ul></ul></li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Frédéric Clavert, 07/16/2013</em>
# </li>
#
# ./DHFRsample/2013-07/msg00007.html
#
# <li><strong>From</strong>: Aurélien Berra &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("aurelien.berra" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Aurélien Berra &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("aurelien.berra" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Aurélien Berra &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("aurelien.berra" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Aurélien Berra &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("aurelien.berra" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: "
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>
# <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</li>
# <li><strong>Date</strong>: Fri, 5 Jul 2013 14:14:20 +0200</li>
# </ul>
# NOM Aurélien Berra
# MAIL  aurelien.berra@gmail.com
# : Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto
# Aurélien Berra
#
#
#  aurelien.berra@gmail.com
#
# ./DHFRsample/2013-07/msg00007.html
#
# _______________
#
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00008.html" name="00008">AW: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Mareike Koenig, 07/05/2013</em>
# </li>
# <li><b><a href="msg00009.html" name="00009">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# ./DHFRsample/2013-07/msg00009.html
#
# <li><strong>From</strong>: Nicolas Legrand &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("nicolas.legrand" + "@" + "obspm.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Nicolas Legrand &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("nicolas.legrand" + "@" + "obspm.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Nicolas Legrand &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("nicolas.legrand" + "@" + "obspm.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Nicolas Legrand &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("nicolas.legrand" + "@" + "obspm.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: Aurélien Berra &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("aurelien.berra" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
# <li><strong>Cc</strong>: "
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>
# <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</li>
# <li><strong>Date</strong>: Fri, 5 Jul 2013 14:59:58 +0200</li>
# </ul>
# NOM Nicolas Legrand
# MAIL  nicolas.legrand@obspm.fr
# : Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto
# Nicolas Legrand
#
#
#  nicolas.legrand@obspm.fr
#
# ./DHFRsample/2013-07/msg00009.html
#
# _______________
#
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# </li>
# </ul>
# </li>
# </ul>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</strong>, <em>Nicolas Legrand, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00010.html" name="00010">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Aurélien Berra, 07/05/2013</em>
# <ul>
# <li><b><a href="msg00011.html" name="00011">Re: [DH] Yes We Digital ! Young researchers in digital humanities : a Manifesto</a></b>, <em>Stéphane Pouyllau, 07/05/2013</em>
# ...
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Claire Clivaz, 07/09/2013</em>
# <ul>
# <li><b><a href="msg00020.html" name="00020">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Pierre Mounier, 07/12/2013</em>
# </li><li><b><a href="msg00021.html" name="00021">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Olivier Le Deuff, 07/12/2013</em>
# </li><li><b><a href="msg00022.html" name="00022">Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</a></b>, <em>Stéphane Pouyllau, 07/12/2013</em>
# </li>
# </ul></li>
#
# ./DHFRsample/2013-07/msg00015.html
#
# <li><strong>From</strong>: Sandrine Breuil &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("sandrine.breuil" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Sandrine Breuil &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("sandrine.breuil" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Sandrine Breuil &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("sandrine.breuil" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Sandrine Breuil &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("sandrine.breuil" + "@" + "univ-tours.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: "
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "cru.fr")
#  // -->
#  </script>" &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "cru.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: [DH] Formation XML-TEI - 28, 29 et 30 octobre 2013 - CESR, Tours</li>
# <li><strong>Date</strong>: Tue, 9 Jul 2013 08:45:06 +0100 (BST)</li>
# </ul>
# NOM Sandrine Breuil
# MAIL  sandrine.breuil@univ-tours.fr
# : [DH] Formation XML-TEI - 28, 29 et 30 octobre 2013 - CESR, Tours
# Sandrine Breuil
#
#
#  sandrine.breuil@univ-tours.fr
#
# ./DHFRsample/2013-07/msg00015.html
#
# _______________
#
# <li><strong>[DH] Formation XML-TEI - 28, 29 et 30 octobre 2013 - CESR, Tours</strong>, <em>Sandrine Breuil, 07/09/2013</em>
# </li>
#
# 1
#
# ./DHFRsample/2013-07/msg00002.html
#
# <li><strong>From</strong>: Marjorie Burghart &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marjorie.burghart" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Marjorie Burghart &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marjorie.burghart" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Marjorie Burghart &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marjorie.burghart" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Marjorie Burghart &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marjorie.burghart" + "@" + "ehess.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: dh &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</li>
# <li><strong>Date</strong>: Fri, 5 Jul 2013 01:35:31 +0200</li>
# </ul>
# NOM Marjorie Burghart
# MAIL  marjorie.burghart@ehess.fr
# : Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities
# Marjorie Burghart
#
#
#  marjorie.burghart@ehess.fr
#
# ./DHFRsample/2013-07/msg00002.html
#
# _______________
#
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Marjorie Burghart, 07/05/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Marjorie Burghart, 07/05/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Marjorie Burghart, 07/05/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Marjorie Burghart, 07/05/2013</em>
# </li>
#
# ./DHFRsample/2013-07/msg00020.html
#
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "openedition.org")
#  // -->
#  </script>&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "openedition.org")
#  // -->
#  </script>&gt;</li>
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "openedition.org")
#  // -->
#  </script>&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Pierre Mounier &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("pierre.mounier" + "@" + "openedition.org")
#  // -->
#  </script>&gt;</li>
# <li><strong>To</strong>: Claire Clivaz &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("claire.clivaz" + "@" + "unil.ch")
#  // -->
#  </script>&gt;</li>
# <li><strong>Cc</strong>: Frédéric Clavert &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("frederic" + "@" + "clavert.net")
#  // -->
#  </script>&gt;,        dh &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</li>
# <li><strong>Date</strong>: Fri, 12 Jul 2013 15:39:12 +0200</li>
# </ul>
# NOM Pierre Mounier
# MAIL  pierre.mounier@openedition.org
# : Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities
# Pierre Mounier
#
#
#  pierre.mounier@openedition.org
#
# ./DHFRsample/2013-07/msg00020.html
#
# _______________
#
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# 1
# ZMA
# <li><strong>Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities</strong>, <em>Pierre Mounier, 07/12/2013</em>
# </li>
#
# ./DHFRsample/2010-07/msg00000.html
#
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 1
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 2
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 3
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 4
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 5
# <li><strong>Emploi : informaticien pour développement orienté 	données lexicales et corpus textuels</strong>, <em>Marin Dacos, 07/05/2010</em>
# </li>
#
# 1
#
# ./DHFRsample/2010-07/msg00001.html
#
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 1
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 2
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 3
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 4
# <li><strong>From</strong>: Marin Dacos &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("marin.dacos" + "@" + "revues.org")
#  // -->
#  </script>&gt;</li>
#
# 5
# <li><strong>Nouvelles de Plume - Recrutements et logiciels ajout	és au catalogue</strong>, <em>Marin Dacos, 07/05/2010</em>
# </li>
#
# 1
#
# ./DHFRsample/2010-07/msg00002.html
#
# <li><strong>From</strong>: Muriel Foulonneau &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("muriel.foulonneau" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 1
# <li><strong>From</strong>: Muriel Foulonneau &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("muriel.foulonneau" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 2
# <li><strong>From</strong>: Muriel Foulonneau &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("muriel.foulonneau" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 3
# <li><strong>From</strong>: Muriel Foulonneau &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("muriel.foulonneau" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 4
# <li><strong>From</strong>: Muriel Foulonneau &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("muriel.foulonneau" + "@" + "gmail.com")
#  // -->
#  </script>&gt;</li>
#
# 5
# <li><strong>Fwd: [DIGLIB] Chicago Colloquium on Digital Humanities and Computer 	Science, November4 21-22</strong>, <em>Muriel Foulonneau, 07/16/2010</em>
# </li>
#
# 1
#
# ./DHFRsample/2016-07/msg00030.html
#
# <li><strong>From</strong>: Claire Clivaz &lt;claire.clivaz@sib.swiss&gt;</li>
#
# 1
# ZMA
# <li><strong>From</strong>: Claire Clivaz &lt;claire.clivaz@sib.swiss&gt;</li>
# <li><strong>From</strong>: Claire Clivaz &lt;claire.clivaz@sib.swiss&gt;</li>
# NEXT ELEM <ul>
# <li><strong>From</strong>: Claire Clivaz &lt;claire.clivaz@sib.swiss&gt;</li>
# <li><strong>To</strong>: dh &lt;
#  <script type="text/javascript">
#  <!--
#  document.write("dh" + "@" + "groupes.renater.fr")
#  // -->
#  </script>&gt;</li>
# <li><strong>Subject</strong>: [DH] Poste de senior technical officer (Maynooth University)</li>
# <li><strong>Date</strong>: Thu, 28 Jul 2016 15:54:10 +0200</li>
# <li><strong>Organization</strong>: SIB, VITAL-IT</li>
# </ul>
# ### ['Claire Clivaz']
#
# ./DHFRsample/2016-07/msg00030.html
#
# <li><strong>From</strong>: Claire Clivaz &lt;claire.clivaz@sib.swiss&gt;</li>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-2b7c2d6e403a> in <module>()
# ----> 1 soup=read_html_pages_in_dir("./DHFRsample")
#       2
#       3
#       4
#       5 print soup
#
# <ipython-input-30-749dea515a93> in read_html_pages_in_dir(pages_dir)
#      74                                 print "\n",os.path.join(subdir, file), "\n"
#      75                                 print zone_de_metadonnees_auteur
# ---> 76                                 next( ZC)
#      77
#      78                             print "NOM",nom
#
# TypeError: 'NavigableString' object is not callable
