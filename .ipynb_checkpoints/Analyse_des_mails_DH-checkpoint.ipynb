# %%
#some imports
from bs4 import BeautifulSoup
from dateutil import parser

import re,os
import glob

# %%
def read_html_pages_in_dir(pages_dir):
    dict_mails={}
    #rootdir="./DHFR_sample/"
    count_Cc=0
    count_message=0
    for subdir, dirs, files in os.walk(pages_dir):
#ON VA LIRE TOUS LES FICHIERS DU REP ROOTDIR
        
        for file in files:
    #V1     if file.endswith('.html') == True  and file != ("index.html") and not re.match("mail\d+.html",file) : 
           if re.match("msg\d+.html",file) : 
          
            # les index.html sont des recap, on pourrait les compter pour s'assurer du nombre de messages
                
                print "\n",os.path.join(subdir, file), "\n"
                champs_mail={}
                filename=os.path.join(subdir, file)
                soup=BeautifulSoup(open(filename, 'r').read(),'lxml')#, 'html.parser') 
#RECUPERER LE SUJET DU MESSAGE
                
                i=0
                for zone_cible in soup.findAll('ul'):
                    i+=1
                    sujet_messg = zone_cible.find(string=re.compile("\[DH\]"))
                    zone_de_metadonnees = None
                    special_auteur=0
##ON ISOLE LE CHAMPS AUTEUR
                    if '<li><strong>From</strong>:' in str(zone_cible) and '<li><strong>To</strong>:' in str(zone_cible) :
                        #print "FROM/TO DETECTED, i= ",i
                        count_message+=1
                        #print  zone_cible
                        nom_auteur= re.sub(r'<ul>\n<li><strong>From</strong>: ', '',str(zone_cible))
                        sep = "&lt;"
                        nom_auteur = nom_auteur.split(sep, 1)[0]
                        
                        mail1= re.sub(r'<ul>\n<li><strong>From</strong>:.+\n.+\n.+\n document\.write\(\"', '',str(zone_cible))
                        mail2=re.sub(r'<ul>\n<li><strong>From</strong>:.+\n.+\n.+\n document\.write\(\".+@\" \+ \"', '',str(zone_cible))
                        sep1 = "\" + \"@\" + "
                        sep2 = "\")"
                        mail1= mail1.split(sep1, 1)[0]
                        mail2= mail2.split(sep2, 1)[0]
                        mail_auteur= mail1+"@"+mail2
                        #print mail_auteur
                        if len(mail_auteur)>60:
                            try:
                                mail= re.sub(r'<ul>\n<li><strong>From</strong>:', '',str(zone_cible))
                                mail=re.search('&lt;(.*)&gt;',str(mail))
                                mail=mail.group(1)
                                #print "MAILBIS",mail
                                mail_auteur=mail
                                special_auteur=1
                            except:
                                print "BUG"
                                
                        if len(nom_auteur)>50:
                            #print zone_cible
                            nom_auteur=mail_auteur
                        print "nom_auteur ",nom_auteur+" mail_auteur "+mail_auteur,"\n"
                        champs_mail["nom_auteur"]=  nom_auteur
                        champs_mail["mail_auteur"]=  mail_auteur
                        champs_mail["ref_physique_de_l_article"]=  os.path.join(subdir, file)
                        champs_mail["sujet_du_message"] = sujet_messg
##ON ISOLE LE CHAMP DESTINATAIRES
                        #if special_auteur == 1:
                            #print "ZCspecAut",zone_cible
                        #else: 
                        
                        destinataires=re.sub(r'<ul>\n<li><strong>From</strong>:.+\n.+\n.+\n.+\n.+\n.+\n.+\n', '',str(zone_cible))
                        
                        sep3=";</li>"
                        destinataires= destinataires.split(sep3, 1)[0]
                        #print destinataires
                        dest=re.findall("<script type=.*\n.+\n.+\n.+\n.+/script>", destinataires)
                        #print dest
                        liste_destinataires=[]
                        for destinataire in dest:
                            #print destinataire,"\n___________________\n"
                            mail1= re.sub(r'<script type=\"text/javascript\">\n <!-- \n document\.write\(\"', '',str(destinataire))
                            mail2=re.sub(r'<script type=\"text/javascript\">\n <!-- \n document\.write\(\".+@\" \+ \"', '',str(destinataire))
                            sep1 = "\" + \"@\" + "
                            sep2 = "\")"
                            mail1= mail1.split(sep1, 1)[0]
                            mail2= mail2.split(sep2, 1)[0]
                            mail_destinataire= mail1+"@"+mail2
                            #print mail_destinataire,"\n___________\n"
                            if mail_destinataire not in liste_destinataires :
                                liste_destinataires.append(mail_destinataire)
                        if liste_destinataires==[]:
                            #print zone_cible
                            liste_destinataires=['dh@groupes.renater.fr']
                        print "destinataires: ",liste_destinataires,"\n"
                        champs_mail["liste_mails_dests"] = liste_destinataires
                       
                        if '<li><strong>Cc</strong>:' in str(zone_cible):
##ON ISOLE LE CHAMP CC
                            #print "CC DETECTED, i= ",i
                            #print zone_cible
                            count_Cc+=1
                            CCfield= re.search('<li><strong>Cc</strong>:(.*)<li><strong>Subject</strong>',str(zone_cible),flags=re.DOTALL)
                            CC= CCfield.group(1)
                            CC=str(CC)
                            CC=re.sub(r'^.+\n','',str(CC),flags=0)
                            CCs=re.findall("<script type=.*\n.+\n.+\n.+\n.+/script>", CC)
                            #sep1 = "\" + \"@\" + "
                            #mail1= mail1.split(sep1, 1)[0]
                            #print "CC FIELd\n"#,CCs
                            liste_CCs=[]
                            for CC in CCs:
                                #print CC,"\n___________________\n"
                                mail1= re.sub(r'<script type=\"text/javascript\">\n <!-- \n document\.write\(\"', '',str(CC))
                                mail2=re.sub(r'<script type=\"text/javascript\">\n <!-- \n document\.write\(\".+@\" \+ \"', '',str(CC))
                                sep1 = "\" + \"@\" + "
                                sep2 = "\")"
                                mail1= mail1.split(sep1, 1)[0]
                                mail2= mail2.split(sep2, 1)[0]
                                mail_CC= mail1+"@"+mail2
                                #print mail_CC,"\n___________\n"
                                if mail_CC not in liste_CCs :
                                    liste_CCs.append(mail_CC)
                            print "CCs: ",liste_CCs
                            champs_mail["liste_CCs"] = liste_CCs
##ON ISOLE LE CHAMP DATE                       
                        #print "ZONECIBLE",zone_cible
                        champs_datef=re.search('<li><strong>Date</strong>:(.+?)</li>',str(zone_cible),flags=re.DOTALL)
                        #print "CHAMPSDATEF",champs_datef
                        try :
                            champs_date=champs_datef.group(1)
                        except :
                            #print "ZCparent", zone_cible.parent
                            champs_date=re.search('<!--X-Date: (.*) -->',str(soup))
                            champs_date=champs_date.group(1)
                            #print champs_date
                            
                        #print champs_date
                        try : 
                            champs_date=parser.parse(champs_date)
                        except ValueError :
                            sep=" ("
                            champs_date=champs_date.split(sep, 1)[0]
                            
                        print  champs_date
                        champs_mail["date"] = champs_date
                        
                        
                        dict_mails[os.path.join(subdir, file)]= champs_mail
                        break
    print dict_mails
    print count_message
    print count_Cc
    ratiocount = float(count_Cc)/float(count_message)
    print "Taux_de_mail_avec_CC:",ratiocount

# %%
soup=read_html_pages_in_dir("./DHFRsample")

 

print soup
# Out:
# ./DHFRsample/2011-07/msg00000.html
#
# nom_auteur  Maud Ingarao  mail_auteur maud.ingarao@ens-lyon.fr
#
# destinataires:  ['schassan@hab.de', 'c.schoech@gmail.com']
#
# 2011-07-07 15:59:17+02:00
#
# ./DHFRsample/2011-07/msg00005.html
#
# nom_auteur  "Noiret, Serge"  mail_auteur Serge.Noiret@EUI.eu
#
# destinataires:  ['DH@cru.fr']
#
# 2011-07-19 08:04:41-07:00
#
# ./DHFRsample/2011-07/msg00003.html
#
# nom_auteur  "Noiret, Serge"  mail_auteur Serge.Noiret@EUI.eu
#
# destinataires:  ['marionlame@gmail.com', 'marin.dacos@revues.org']
#
# CCs:  ['dh@cru.fr']
# 2011-07-18 02:06:06-07:00
#
# ./DHFRsample/2011-07/msg00001.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@revues.org
#
# destinataires:  ['dh@cru.fr']
#
# 2011-07-16 14:58:47+02:00
#
# ./DHFRsample/2011-07/msg00004.html
#
# nom_auteur  Laetitia Bontemps  mail_auteur laetitia.bontemps@univ-tours.fr
#
# destinataires:  ['DH@cru.fr']
#
# 2011-07-19 15:04:42+01:00
#
# ./DHFRsample/2011-07/msg00002.html
#
# nom_auteur  M L  mail_auteur marionlame@gmail.com
#
# destinataires:  ['marin.dacos@revues.org', 'dh@cru.fr']
#
# CCs:  ['dh@cru.fr']
# 2011-07-18 11:01:00+02:00
#
# ./DHFRsample/2013-07/msg00030.html
#
# nom_auteur  listes@ahicf.com mail_auteur listes@ahicf.com
#
# destinataires:  ['listes@ahicf.com']
#
# 2013-07-18 10:20:44+02:00
#
# ./DHFRsample/2013-07/msg00006.html
#
# nom_auteur  Pierre Mounier  mail_auteur pierre.mounier@ehess.fr
#
# destinataires:  ['stephane.pouyllau@cnrs.fr']
#
# CCs:  ['dh@groupes.renater.fr']
# 2013-07-05 12:13:22+02:00
#
# ./DHFRsample/2013-07/msg00018.html
#
# nom_auteur  Eric Guichard  mail_auteur Eric.Guichard@enssib.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-10 15:56:42+02:00
#
# ./DHFRsample/2013-07/msg00028.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-16 10:50:42+02:00
#
# ./DHFRsample/2013-07/msg00007.html
#
# nom_auteur  Aurélien Berra  mail_auteur aurelien.berra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 14:14:20+02:00
#
# ./DHFRsample/2013-07/msg00009.html
#
# nom_auteur  Nicolas Legrand  mail_auteur nicolas.legrand@obspm.fr
#
# destinataires:  ['aurelien.berra@gmail.com']
#
# CCs:  ['dh@groupes.renater.fr']
# 2013-07-05 14:59:58+02:00
#
# ./DHFRsample/2013-07/msg00000.html
#
# nom_auteur  Thély Nicolas  mail_auteur nicolas.thely@univ-rennes2.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-02 14:15:54+02:00
#
# ./DHFRsample/2013-07/msg00005.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 10:46:22+02:00
#
# ./DHFRsample/2013-07/msg00022.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-12 17:57:32+02:00
#
# ./DHFRsample/2013-07/msg00010.html
#
# nom_auteur  Aurélien Berra  mail_auteur aurelien.berra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 15:41:00+02:00
#
# ./DHFRsample/2013-07/msg00033.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-18 11:56:40+02:00
#
# ./DHFRsample/2013-07/msg00037.html
#
# nom_auteur  Annaig Mahe  mail_auteur mahe.annaig@wanadoo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-26 15:37:16+02:00
#
# ./DHFRsample/2013-07/msg00008.html
#
# nom_auteur  Mareike Koenig  mail_auteur MKoenig@dhi-paris.fr
#
# destinataires:  ['aurelien.berra@gmail.com', 'dh@groupes.renater.fr']
#
# 2013-07-05 14:36:19+02:00
#
# ./DHFRsample/2013-07/msg00029.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-17 10:30:02+02:00
#
# ./DHFRsample/2013-07/msg00003.html
#
# nom_auteur  Pierre Mounier  mail_auteur pierre.mounier@openedition.org
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 10:09:24+02:00
#
# ./DHFRsample/2013-07/msg00025.html
#
# nom_auteur  Javier Espejo Surós  mail_auteur espejosuros.javier@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-12 22:12:37+02:00
#
# ./DHFRsample/2013-07/msg00036.html
#
# nom_auteur  Alexandre Moatti  mail_auteur alexandre.moatti@mines.org
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-24 19:28:45+02:00
#
# ./DHFRsample/2013-07/msg00024.html
#
# nom_auteur  antoine Courtin  mail_auteur antoine.courtin@mac.com
#
# destinataires:  ['stephane.pouyllau@huma-num.fr']
#
# CCs:  ['dh@groupes.renater.fr']
# 2013-07-12 20:19:16+02:00
#
# ./DHFRsample/2013-07/msg00034.html
#
# nom_auteur  "Ghislain SILLAUME"  mail_auteur ghislain.sillaume@cvce.eu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-18 17:36:42+02:00
#
# ./DHFRsample/2013-07/msg00026.html
#
# nom_auteur  Nicolas Legrand  mail_auteur nicolas.legrand@obspm.fr
#
# destinataires:  ['antoine.courtin@mac.com']
#
# CCs:  ['stephane.pouyllau@huma-num.fr', 'dh@groupes.renater.fr']
# 2013-07-15 10:46:43+02:00
#
# ./DHFRsample/2013-07/msg00001.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-04 15:30:48+02:00
#
# ./DHFRsample/2013-07/msg00014.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-08 14:22:18+02:00
#
# ./DHFRsample/2013-07/msg00035.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-23 14:09:26+02:00
#
# ./DHFRsample/2013-07/msg00012.html
#
# nom_auteur  Pierre Mounier  mail_auteur pierre.mounier@openedition.org
#
# destinataires:  ['stephane.pouyllau@huma-num.fr']
#
# CCs:  ['dh@groupes.renater.fr']
# 2013-07-07 22:56:21+02:00
#
# ./DHFRsample/2013-07/msg00011.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 15:56:40+02:00
#
# ./DHFRsample/2013-07/msg00027.html
#
# nom_auteur  Paul Girard  mail_auteur paul.girard@sciencespo.fr
#
# destinataires:  ['antoine.courtin@mac.com']
#
# CCs:  ['stephane.pouyllau@huma-num.fr', 'dh@groupes.renater.fr']
# 2013-07-15 09:34:39+02:00
#
# ./DHFRsample/2013-07/msg00031.html
#
# nom_auteur  Antoine Blanchard  mail_auteur antoine.blanchard@gmail.com
#
# destinataires:  ['Nicole.Dufournaud@laposte.net', 'dh@groupes.renater.fr']
#
# CCs:  ['marjorie.burghart@ehess.fr', 'jean-daniel.fekete@inria.fr']
# 2013-07-18 10:47:22+02:00
#
# ./DHFRsample/2013-07/msg00013.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@openedition.org
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-08 00:16:37+02:00
#
# ./DHFRsample/2013-07/msg00032.html
#
# nom_auteur  "Noiret, Serge"  mail_auteur Serge.Noiret@EUI.eu
#
# destinataires:  ['dh@cru.fr']
#
# 2013-07-18 08:57:09+00:00
#
# ./DHFRsample/2013-07/msg00019.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-12 14:40:29+02:00
#
# ./DHFRsample/2013-07/msg00004.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 10:28:47+02:00
#
# ./DHFRsample/2013-07/msg00023.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-12 18:03:14+02:00
#
# ./DHFRsample/2013-07/msg00021.html
#
# nom_auteur  Olivier Le Deuff  mail_auteur oledeuff@gmail.com
#
# destinataires:  ['pierre.mounier@openedition.org']
#
# CCs:  ['claire.clivaz@unil.ch', 'frederic@clavert.net', 'dh@groupes.renater.fr']
# 2013-07-12 15:54:35+02:00
#
# ./DHFRsample/2013-07/msg00016.html
#
# nom_auteur  Pierre Mounier  mail_auteur pierre.mounier@openedition.org
#
# destinataires:  ['frederic@clavert.net']
#
# CCs:  ['dh@groupes.renater.fr']
# 2013-07-09 15:14:50+02:00
#
# ./DHFRsample/2013-07/msg00017.html
#
# nom_auteur  Claire Clivaz  mail_auteur claire.clivaz@unil.ch
#
# destinataires:  ['pierre.mounier@openedition.org']
#
# CCs:  ['frederic@clavert.net', 'dh@groupes.renater.fr']
# 2013-07-09 15:28:26+02:00
#
# ./DHFRsample/2013-07/msg00015.html
#
# nom_auteur  Sandrine Breuil  mail_auteur sandrine.breuil@univ-tours.fr
#
# destinataires:  ['dh@cru.fr']
#
# 2013-07-09 08:45:06+01:00
#
# ./DHFRsample/2013-07/msg00002.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2013-07-05 01:35:31+02:00
#
# ./DHFRsample/2013-07/msg00020.html
#
# nom_auteur  Pierre Mounier  mail_auteur pierre.mounier@openedition.org
#
# destinataires:  ['claire.clivaz@unil.ch']
#
# CCs:  ['frederic@clavert.net', 'dh@groupes.renater.fr']
# 2013-07-12 15:39:12+02:00
#
# ./DHFRsample/2010-07/msg00000.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@revues.org
#
# destinataires:  ['dh@cru.fr']
#
# 2010-07-05 09:45:15+01:00
#
# ./DHFRsample/2010-07/msg00001.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@revues.org
#
# destinataires:  ['dh@cru.fr']
#
# 2010-07-05 13:38:38+01:00
#
# ./DHFRsample/2010-07/msg00002.html
#
# nom_auteur  Muriel Foulonneau  mail_auteur muriel.foulonneau@gmail.com
#
# destinataires:  ['dh@cru.fr']
#
# 2010-07-16 10:57:19+02:00
#
# ./DHFRsample/2016-07/msg00030.html
#
# nom_auteur  Claire Clivaz  mail_auteur claire.clivaz@sib.swiss
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-28 15:54:10+02:00
#
# ./DHFRsample/2016-07/msg00006.html
#
# nom_auteur  Laurent Romary  mail_auteur laurent.romary@inria.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 18:56:42+02:00
#
# ./DHFRsample/2016-07/msg00018.html
#
# nom_auteur  Fatiha IDMHAND  mail_auteur fatihaidmhand@yahoo.es
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-19 09:59:52+00:00
#
# ./DHFRsample/2016-07/msg00028.html
#
# nom_auteur  Elina Leblanc  mail_auteur elinaleblanc3007@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-26 16:20:06+02:00
#
# ./DHFRsample/2016-07/msg00007.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 18:59:36+02:00
#
# ./DHFRsample/2016-07/msg00009.html
#
# nom_auteur  Aurélien Berra  mail_auteur aurelien.berra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 19:03:07+02:00
#
# ./DHFRsample/2016-07/msg00000.html
#
# nom_auteur  Julia Bonaccorsi  mail_auteur julia.bonaccorsi@univ-lyon2.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-01 12:39:37+02:00
#
# ./DHFRsample/2016-07/msg00005.html
#
# nom_auteur  Isa  mail_auteur isabelle.thiebau@univ-lille2.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 18:52:24+02:00
#
# ./DHFRsample/2016-07/msg00022.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-19 19:27:55+02:00
#
# ./DHFRsample/2016-07/msg00010.html
#
# nom_auteur  Gérald KEMBELLEC  mail_auteur gerald.kembellec@lecnam.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 18:55:47+02:00
#
# ./DHFRsample/2016-07/msg00008.html
#
# nom_auteur  Laurent Romary  mail_auteur laurent.romary@inria.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 19:01:56+02:00
#
# ./DHFRsample/2016-07/msg00029.html
#
# nom_auteur  "aude.da-cruz-lima"  mail_auteur aude.da-cruz-lima@mae.u-paris10.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'archives-son-audiovisuel@groups.openedition.org']
#
# 2016-07-28 09:38:17+02:00
#
# ./DHFRsample/2016-07/msg00003.html
#
# nom_auteur  Stéphane Loret  mail_auteur stephane.loret@univ-nantes.fr
#
# destinataires:  ['quanti@groupes.renater.fr', 'dh@groupes.renater.fr', 'rbdd@services.cnrs.fr']
#
# 2016-07-06 00:16:37+02:00
#
# ./DHFRsample/2016-07/msg00025.html
#
# nom_auteur  Claire Clivaz  mail_auteur claire.clivaz@sib.swiss
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-20 16:54:26+02:00
#
# ./DHFRsample/2016-07/msg00024.html
#
# nom_auteur  Cadiou Colette  mail_auteur colette.cadiou@irstea.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-20 11:48:26+02:00
#
# ./DHFRsample/2016-07/msg00026.html
#
#
# ./DHFRsample/2016-07/msg00001.html
#
# nom_auteur  Mehdi Khamassi  mail_auteur mehdi.khamassi@upmc.fr
#
# destinataires:  ['dh@cru.fr']
#
# 2016-07-03 07:31:28+02:00
#
# ./DHFRsample/2016-07/msg00014.html
#
# nom_auteur  Richard Walter  mail_auteur richard.walter@ens.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-12 16:03:09+02:00
#
# ./DHFRsample/2016-07/msg00012.html
#
# nom_auteur  Frédéric Clavert  mail_auteur Frederic.Clavert@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-07 13:11:56+00:00
#
# ./DHFRsample/2016-07/msg00011.html
#
# nom_auteur  antoine Courtin  mail_auteur antoine.courtin@mac.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-07 08:16:53+02:00
#
# ./DHFRsample/2016-07/msg00027.html
#
# nom_auteur  CASANOVA Nathalie  mail_auteur ncasanova@mmsh.univ-aix.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-22 14:58:33+00:00
#
# ./DHFRsample/2016-07/msg00031.html
#
# nom_auteur  Christine Michel  mail_auteur Christine.michel@insa-lyon.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'cerisier@univ-poitiers.fr']
#
# CCs:  ['cerisier@univ-poitiers.fr']
# 2016-07-28 19:24:03+02:00
#
# ./DHFRsample/2016-07/msg00013.html
#
# nom_auteur  Caroline Muller  mail_auteur caroline.muller@univ-reims.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-11 20:40:08+02:00
#
# ./DHFRsample/2016-07/msg00032.html
#
# nom_auteur  Claire Clivaz  mail_auteur claire.clivaz@sib.swiss
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-29 13:21:16+02:00
#
# ./DHFRsample/2016-07/msg00019.html
#
# nom_auteur  Michael Bourgatte  mail_auteur m.bourgatte@icp.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-19 14:37:11+02:00
#
# ./DHFRsample/2016-07/msg00004.html
#
# nom_auteur  Martin Grandjean  mail_auteur martin.grandjean@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-06 16:01:43+02:00
#
# ./DHFRsample/2016-07/msg00023.html
#
# nom_auteur  Isa  mail_auteur isabelle.thiebau@univ-lille2.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-20 00:00:32+02:00
#
# ./DHFRsample/2016-07/msg00021.html
#
# nom_auteur  Isabelle Thiebau  mail_auteur isabelle.thiebau@univ-lille2.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-19 19:00:39+02:00
#
# ./DHFRsample/2016-07/msg00016.html
#
# nom_auteur  Elena González-Blanco  mail_auteur elenagonzalezblanco@yahoo.es
#
# destinataires:  ['humanist@lists.digitalhumanities.org', 'globaloutlookdh-l@uleth.ca', 'digitalclassicist@jiscmail.ac.uk', 'dm-l@uleth.ca', 'dhd@mailman.rrz.uni-hamburg.de', 'aiucd-l@humnet.unipi.it', 'air-l@aoir.org', 'institute@lists.uvic.ca', 'dh@groupes.renater.fr', 'tei-l@listserv.brown.edu', 'humanist-l@uleth.ca', 'centernet@lists.digitalhumanities.org', 'dhcarolina@listserv.unc.edu', 'humanidadesdigitais@gmail.com', 'website@hastac.org', 'southasia-dh@lists.globaloutlookdh.org', 'air-l@listserv.aoir.org', 'humanisticadh@gmail.com']
#
# 2016-07-18 00:53:35+00:00
#
# ./DHFRsample/2016-07/msg00017.html
#
# nom_auteur  Johann Holland  mail_auteur johann.holland@campus-condorcet.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-19 10:46:36+02:00
#
# ./DHFRsample/2016-07/msg00015.html
#
# nom_auteur  Sarah Cadorel  mail_auteur sarah.cadorel@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-13 15:27:26+02:00
#
# ./DHFRsample/2016-07/msg00002.html
#
# nom_auteur  Formation continue ENC  mail_auteur formation.continue@enc-sorbonne.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2016-07-05 15:46:59+02:00
#
# ./DHFRsample/2016-07/msg00020.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['tei-fr@cru.fr', 'dh@groupes.renater.fr']
#
# 2016-07-19 17:09:12+02:00
#
# ./DHFRsample/2012-07/msg00006.html
#
# nom_auteur  Alexandre Monnin  mail_auteur aamonnz@gmail.com
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-17 07:17:09+02:00
#
# ./DHFRsample/2012-07/msg00007.html
#
# nom_auteur  Alexandre Monnin  mail_auteur aamonnz@gmail.com
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-20 00:11:31+02:00
#
# ./DHFRsample/2012-07/msg00009.html
#
# nom_auteur   mail_auteur jf.omhover@histographe.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2012-07-24 17:45:29+02:00
#
# ./DHFRsample/2012-07/msg00000.html
#
# nom_auteur  Dominique Stutzmann  mail_auteur dominique.stutzmann@irht.cnrs.fr
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-02 08:25:19+02:00
#
# ./DHFRsample/2012-07/msg00005.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@openedition.org
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-16 15:51:56+02:00
#
# ./DHFRsample/2012-07/msg00010.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@openedition.org
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-25 13:34:30+01:00
#
# ./DHFRsample/2012-07/msg00008.html
#
# nom_auteur  Marin Dacos  mail_auteur marin.dacos@openedition.org
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-24 06:24:52+02:00
#
# ./DHFRsample/2012-07/msg00003.html
#
# nom_auteur  Enrico Natale  mail_auteur enrico.natale@infoclio.ch
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-10 14:08:20+02:00
#
# ./DHFRsample/2012-07/msg00001.html
#
# nom_auteur  Emilien RUIZ  mail_auteur emilien.ruiz@ehess.fr
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-02 14:47:31+02:00
#
# ./DHFRsample/2012-07/msg00012.html
#
# nom_auteur  Serge Heiden  mail_auteur slh@ens-lyon.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2012-07-26 21:21:27+02:00
#
# ./DHFRsample/2012-07/msg00011.html
#
# nom_auteur  stefanev  mail_auteur stefanev@club-internet.fr
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-26 18:39:41+02:00
#
# ./DHFRsample/2012-07/msg00004.html
#
# nom_auteur  Anne-Laure Brisac-Chraïbi  mail_auteur anne-laure.brisac@inha.fr
#
# destinataires:  ['dh@cru.fr']
#
#  Fri, 13 Jul 2012 09:56:18 +0100
#
# ./DHFRsample/2012-07/msg00002.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@cru.fr']
#
# 2012-07-10 10:39:11+02:00
#
# ./DHFRsample/2017-06/msg00030.html
#
# nom_auteur  Martin Grandjean  mail_auteur martin.grandjean@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-13 15:28:07+02:00
#
# ./DHFRsample/2017-06/msg00059.html
#
# nom_auteur  Alexandre Hocquet  mail_auteur alexandre.hocquet@univ-lorraine.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-27 14:19:29+02:00
#
# ./DHFRsample/2017-06/msg00006.html
#
# nom_auteur  Yosra Ghliss  mail_auteur yosra.ghliss17@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-06 17:17:31+02:00
#
# ./DHFRsample/2017-06/msg00048.html
#
# nom_auteur  ekergosien  mail_auteur eric.kergosien@univ-lille3.fr
#
# destinataires:  ['liste-egc@polytech.univ-nantes.fr', 'info-ic@listes.irisa.fr', 'magis@imag.fr', 'dh@groupes.renater.fr', 'bull-i3@irit.fr', 'ln@cines.fr', 'liste-proml@lri.fr', 'docs-ri@yahoogroupes.fr']
#
# 2017-06-21 18:12:58+02:00
#
# ./DHFRsample/2017-06/msg00018.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 15:17:08+02:00
#
# ./DHFRsample/2017-06/msg00028.html
#
# nom_auteur  Nicolas Thély  mail_auteur nicolasthelyrennes2@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-12 14:18:46+02:00
#
# ./DHFRsample/2017-06/msg00007.html
#
# nom_auteur  Clarisse Bardiot  mail_auteur clarisse_bardiot@mac.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-07 13:19:02+02:00
#
# ./DHFRsample/2017-06/msg00009.html
#
# nom_auteur  Aurélien Berra  mail_auteur aurelien.berra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-08 09:22:53+02:00
#
# ./DHFRsample/2017-06/msg00000.html
#
# nom_auteur  Sofia Papastamkou  mail_auteur stamkou@free.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-01 14:53:28+02:00
#
# ./DHFRsample/2017-06/msg00047.html
#
# nom_auteur  Rémi Jimenes  mail_auteur remi.jimenes@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-21 12:12:42+02:00
#
# ./DHFRsample/2017-06/msg00058.html
#
# nom_auteur  Dominique Stutzmann  mail_auteur dominique.stutzmann@irht.cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'dhd@mailman.rrz.uni-hamburg.de']
#
# 2017-06-27 14:18:48+02:00
#
# ./DHFRsample/2017-06/msg00005.html
#
# nom_auteur  Nicolas Larrousse  mail_auteur Nicolas.Larrousse@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-06 17:11:37+02:00
#
# ./DHFRsample/2017-06/msg00022.html
#
# nom_auteur  Jeanne Herzog  mail_auteur jea.herzog@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-10 07:37:15+02:00
#
# ./DHFRsample/2017-06/msg00010.html
#
# nom_auteur  Myriam TAZI  mail_auteur myriam.tazi@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-08 12:11:54+02:00
#
# ./DHFRsample/2017-06/msg00046.html
#
# nom_auteur  Eric Guichard  mail_auteur Eric.Guichard@enssib.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-19 19:07:45+02:00
#
# ./DHFRsample/2017-06/msg00033.html
#
# nom_auteur  Pablo Ruiz  mail_auteur pabloruizfabo@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-14 10:17:22+02:00
#
# ./DHFRsample/2017-06/msg00050.html
#
# nom_auteur  ekergosien  mail_auteur eric.kergosien@univ-lille3.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-26 00:20:00+02:00
#
# ./DHFRsample/2017-06/msg00037.html
#
# nom_auteur  Daniel Stoekl  mail_auteur Daniel.Stoekl@ephe.sorbonne.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-16 06:45:25+00:00
#
# ./DHFRsample/2017-06/msg00054.html
#
# nom_auteur  jerome valluy  mail_auteur jerome.valluy@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-26 18:36:17+02:00
#
# ./DHFRsample/2017-06/msg00040.html
#
# nom_auteur  Paquien-Séguy Françoise	 mail_auteur francoise.paquienseguy@sciencespo-lyon.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-16 18:12:58+00:00
#
# ./DHFRsample/2017-06/msg00042.html
#
#
# ./DHFRsample/2017-06/msg00008.html
#
# nom_auteur  Carmen Brando  mail_auteur carmen.brando@gmail.com
#
# destinataires:  ['liste-egc@polytech.univ-nantes.fr', 'bull-i3@irit.fr', 'info-ic@listes.irisa.fr', 'dh@groupes.renater.fr', 'ln@cines.fr', 'humanist@lists.digitalhumanities.org']
#
# CCs:  ['francesca.frontini@univ-montp3.fr']
# 2017-06-07 14:12:09+02:00
#
# ./DHFRsample/2017-06/msg00062.html
#
#
# ./DHFRsample/2017-06/msg00029.html
#
# nom_auteur  Béatrice Markhoff  mail_auteur beatrice.markhoff@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-13 14:27:18+02:00
#
# ./DHFRsample/2017-06/msg00003.html
#
# nom_auteur  François Théron  mail_auteur francois.theron@uvsq.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-02 12:36:14+02:00
#
# ./DHFRsample/2017-06/msg00025.html
#
# nom_auteur  Stéphane Vial  mail_auteur vial.stephane@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-11 14:29:59+00:00
#
# ./DHFRsample/2017-06/msg00036.html
#
#
# ./DHFRsample/2017-06/msg00024.html
#
# nom_auteur  Clarisse Bardiot  mail_auteur clarisse_bardiot@mac.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-10 09:19:04+02:00
#
# ./DHFRsample/2017-06/msg00034.html
#
# nom_auteur  Mareike Koenig  mail_auteur MKoenig@dhi-paris.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-14 14:57:17+02:00
#
# ./DHFRsample/2017-06/msg00026.html
#
# nom_auteur  Myriam TAZI  mail_auteur myriam.tazi@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-12 08:42:16+02:00
#
# ./DHFRsample/2017-06/msg00001.html
#
# nom_auteur  Jouni Tuominen  mail_auteur jouni.tuominen@helsinki.fi
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-01 20:00:43+03:00
#
# ./DHFRsample/2017-06/msg00052.html
#
#
# ./DHFRsample/2017-06/msg00051.html
#
# nom_auteur  "Wandl-Vogt, Eveline"  mail_auteur Eveline.Wandl-Vogt@oeaw.ac.at
#
# destinataires:  ['elenagonzalezblanco@yahoo.es', 'dhd@mailman.rrz.uni-hamburg.de', 'air-l@aoir.org', 'dh@groupes.renater.fr', 'institute@lists.uvic.ca', 'globaloutlookdh-l@uleth.ca', 'humanist-l@uleth.ca', 'dhcarolina@listserv.unc.edu', 'humanidadesdigitais@gmail.com', 'website@hastac.org', 'southasia-dh@lists.globaloutlookdh.org', 'air-l@listserv.aoir.org', 'humanisticadh@gmail.com', 'ahdig@googlegroups.com', 'textualscholarship@jiscmail.ac.uk']
#
# 2017-06-25 22:53:30+00:00
#
# ./DHFRsample/2017-06/msg00057.html
#
# nom_auteur  "Wandl-Vogt, Eveline"  mail_auteur Eveline.Wandl-Vogt@oeaw.ac.at
#
# destinataires:  ['exploreAT@oeaw.ac.at']
#
# 2017-06-26 20:54:38+00:00
#
# ./DHFRsample/2017-06/msg00053.html
#
# nom_auteur  Marie-laure Massot  mail_auteur marie-laure.massot@ens.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'Marie-Laure.Massot@ens.fr']
#
# CCs:  ['Marie-Laure.Massot@ens.fr']
# 2017-06-26 16:30:12+02:00
#
# ./DHFRsample/2017-06/msg00014.html
#
# nom_auteur  Paquien-Séguy Françoise	 mail_auteur francoise.paquienseguy@sciencespo-lyon.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# CCs:  ['julia.bonaccorsi@univ-lyon2.fr', 'sabine.loudcher@univ-lyon2.fr', 'sarah.cordonnier@gmail.com']
# 2017-06-09 08:05:48+00:00
#
# ./DHFRsample/2017-06/msg00061.html
#
# nom_auteur  beauguitte laurent  mail_auteur beauguittelaurent@hotmail.com
#
# destinataires:  ['geotamtam@unil.ch', 'dh@groupes.renater.fr']
#
# CCs:  ['martaseve@gmail.com']
# 2017-06-28 08:20:32+00:00
#
# ./DHFRsample/2017-06/msg00035.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['humanum-diffusion@listes.huma-num.fr', 'dh@groupes.renater.fr']
#
# CCs:  ['humanum-veille@listes.huma-num.fr']
# 2017-06-15 05:25:26+02:00
#
# ./DHFRsample/2017-06/msg00012.html
#
# nom_auteur  Stéphane Loret  mail_auteur stephane.loret@univ-nantes.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-08 15:40:03+02:00
#
# ./DHFRsample/2017-06/msg00011.html
#
# nom_auteur  Jorge Fins  mail_auteur jorge.fins@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-08 13:51:02+02:00
#
# ./DHFRsample/2017-06/msg00027.html
#
# nom_auteur  camille monnier  mail_auteur camillemonnier33@hotmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-12 09:19:59+00:00
#
# ./DHFRsample/2017-06/msg00031.html
#
# nom_auteur  delegue.general@adbu.fr mail_auteur delegue.general@adbu.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# CCs:  ['delegue.general@adbu.fr', 'helene.coste@univ-lehavre.fr', 'valerie.neouze@parisdescartes.fr']
# 2017-06-13 15:36:29+02:00
#
# ./DHFRsample/2017-06/msg00013.html
#
# nom_auteur  Clarisse Bardiot  mail_auteur clarisse_bardiot@mac.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 09:44:52+02:00
#
# ./DHFRsample/2017-06/msg00056.html
#
# nom_auteur  Francoise Blum  mail_auteur Francoise.Blum@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-26 17:04:56+02:00
#
# ./DHFRsample/2017-06/msg00039.html
#
# nom_auteur  CAROLINE ROSSI  mail_auteur caroline.rossi@univ-grenoble-alpes.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-16 15:27:11+02:00
#
# ./DHFRsample/2017-06/msg00032.html
#
# nom_auteur  jerome valluy  mail_auteur jerome.valluy@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-13 19:07:46+02:00
#
# ./DHFRsample/2017-06/msg00019.html
#
# nom_auteur  Nicolas Larrousse  mail_auteur Nicolas.Larrousse@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 15:47:07+02:00
#
# ./DHFRsample/2017-06/msg00004.html
#
# nom_auteur  Jean-Baptiste CAMPS  mail_auteur jbcamps@hotmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# CCs:  ['thibault.clerice@enc-sorbonne.fr']
# 2017-06-02 12:43:25+00:00
#
# ./DHFRsample/2017-06/msg00044.html
#
# nom_auteur  Jorge Fins  mail_auteur jorge.fins@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'huyghe.marie@gmail.com', 'laurent.cailly@univ-tours.fr']
#
# CCs:  ['huyghe.marie@gmail.com', 'laurent.cailly@univ-tours.fr']
# 2017-06-19 10:06:25+02:00
#
# ./DHFRsample/2017-06/msg00055.html
#
# nom_auteur  Florent Laroche  mail_auteur florent.laroche@ec-nantes.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-26 19:05:41+02:00
#
# ./DHFRsample/2017-06/msg00023.html
#
# nom_auteur  Sofia Papastamkou  mail_auteur stamkou@free.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-10 09:08:54+02:00
#
# ./DHFRsample/2017-06/msg00021.html
#
# nom_auteur  antoine Courtin  mail_auteur antoine.courtin@mac.com
#
# destinataires:  ['dh@groupes.renater.fr', 'ontologie-patrimoine@services.cnrs.fr']
#
# 2017-06-09 22:38:49+02:00
#
# ./DHFRsample/2017-06/msg00045.html
#
# nom_auteur  Nadine Dardenne  mail_auteur nadine.dardenne@cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-19 17:21:06+02:00
#
# ./DHFRsample/2017-06/msg00016.html
#
# nom_auteur  marta materni  mail_auteur marta.materni@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 10:25:58+02:00
#
# ./DHFRsample/2017-06/msg00038.html
#
# nom_auteur  dumouchel suzanne  mail_auteur dumouchelsuzanne@yahoo.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'legram@yahoogroupes.fr', 'culture.numerique@ml.free.fr']
#
# 2017-06-16 07:39:48+00:00
#
# ./DHFRsample/2017-06/msg00043.html
#
# nom_auteur  Olivier secardin  mail_auteur secardinolivier@yahoo.fr
#
# destinataires:  ['adherents-aipu-fr@groupes.renater.fr', 'afec-info@groupes.renater.fr', 'anstia-adherents@groupes.renater.fr', 'debuter-en-dh@groupes.renater.fr', 'dh@groupes.renater.fr', 'emploi-fle@groupes.renater.fr']
#
# 2017-06-18 21:48:44+00:00
#
# ./DHFRsample/2017-06/msg00017.html
#
# nom_auteur  Epron Benoît  mail_auteur benoit.epron@enssib.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 11:29:03+02:00
#
# ./DHFRsample/2017-06/msg00060.html
#
# nom_auteur  jerome valluy  mail_auteur jerome.valluy@univ-paris1.fr
#
# destinataires:  ['alexandre.hocquet@univ-lorraine.fr', 'dh@groupes.renater.fr']
#
# 2017-06-27 17:21:02+02:00
#
# ./DHFRsample/2017-06/msg00015.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 10:10:53+02:00
#
# ./DHFRsample/2017-06/msg00002.html
#
# nom_auteur  Vanessa Juloux  mail_auteur vanessa.juloux@ephe.sorbonne.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-01 18:59:10+00:00
#
# ./DHFRsample/2017-06/msg00020.html
#
# nom_auteur  Gilles Pansu  mail_auteur gpansu@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2017-06-09 16:32:46+02:00
#
# ./DHFRsample/2017-06/msg00041.html
#
# nom_auteur  ekergosien  mail_auteur eric.kergosien@univ-lille3.fr
#
# destinataires:  ['liste-egc@polytech.univ-nantes.fr', 'info-ic@listes.irisa.fr', 'ln@cines.fr', 'magis@imag.fr', 'bull-i3@irit.fr', 'inforsid@listes.insa-lyon.fr', 'dh@groupes.renater.fr']
#
# 2017-06-17 13:52:49+02:00
#
# ./DHFRsample/2017-06/msg00049.html
#
# nom_auteur  Guillaume Blum  mail_auteur Guillaume.Blum@design.ulaval.ca
#
# destinataires:  ['liste-egc@polytech.univ-nantes.fr', 'info-ic@listes.irisa.fr', 'magis@imag.fr', 'dh@groupes.renater.fr', 'bull-i3@irit.fr', 'ln@cines.fr', 'liste-proml@lri.fr', 'docs-ri@yahoogroupes.fr']
#
# 2017-06-21 17:16:28+00:00
#
# ./DHFRsample/2014-07/msg00006.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-07 14:57:45+02:00
#
# ./DHFRsample/2014-07/msg00018.html
#
# nom_auteur  BRUNET Michèle  mail_auteur iglouvremb@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-17 14:17:04+02:00
#
# ./DHFRsample/2014-07/msg00007.html
#
# nom_auteur  Lisette Calderan  mail_auteur lisette.calderan@inria.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-09 11:48:10+02:00
#
# ./DHFRsample/2014-07/msg00009.html
#
# nom_auteur  Cécile BOULAIRE  mail_auteur cecile.boulaire@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'tei-fr@groupes.renater.fr', 'christine.benevent@univ-tours.fr', 'laurent.gerbier@univ-tours.fr', 'sandrine.breuil@univ-tours.fr']
#
# CCs:  ['christine.benevent@univ-tours.fr', 'laurent.gerbier@univ-tours.fr', 'sandrine.breuil@univ-tours.fr']
# 2014-07-09 20:12:07+02:00
#
# ./DHFRsample/2014-07/msg00000.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@cru.fr']
#
# 2014-07-01 13:44:27+02:00
#
# ./DHFRsample/2014-07/msg00005.html
#
# nom_auteur  Antonio Casilli  mail_auteur antonio.casilli@googlemail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-07 11:23:08+02:00
#
# ./DHFRsample/2014-07/msg00022.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-19 21:59:18+02:00
#
# ./DHFRsample/2014-07/msg00010.html
#
# nom_auteur  Aurelie OLIVESI  mail_auteur aurelie.olivesi@wanadoo.fr
#
# destinataires:  ['diffusion@listes.ancmsp.com', 'dh@groupes.renater.fr', 'efigies-info@rezo.net', 'etudesfeministes-l@simone.univ-tlse2.fr']
#
# CCs:  ['aurelie.olivesi@univ-lyon1.fr']
# 2014-07-09 22:02:02+02:00
#
# ./DHFRsample/2014-07/msg00008.html
#
# nom_auteur  Michael Sinatra  mail_auteur michaelesinatra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-09 04:01:53-04:00
#
# ./DHFRsample/2014-07/msg00003.html
#
# nom_auteur  Johann Holland  mail_auteur johann.holland@campus-condorcet.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-06 14:32:27+02:00
#
# ./DHFRsample/2014-07/msg00025.html
#
# nom_auteur  "elisabeth.belmas"  mail_auteur elisabeth.belmas@wanadoo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-29 12:04:36+02:00
#
# ./DHFRsample/2014-07/msg00024.html
#
# nom_auteur  Laube Sylvain  mail_auteur sylvain.laube@univ-brest.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-25 22:53:36+02:00
#
# ./DHFRsample/2014-07/msg00026.html
#
# nom_auteur  Laurent Romary  mail_auteur laurent.romary@inria.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'gregory.grefenstette@inria.fr']
#
# CCs:  ['gregory.grefenstette@inria.fr']
# 2014-07-30 15:35:56+02:00
#
# ./DHFRsample/2014-07/msg00001.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-01 14:08:34+02:00
#
# ./DHFRsample/2014-07/msg00014.html
#
# nom_auteur  Enrica Salvatori  mail_auteur e.salvatori@mediev.unipi.it
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-11 10:00:21+02:00
#
# ./DHFRsample/2014-07/msg00012.html
#
# nom_auteur  Alexandre Monnin  mail_auteur aamonnz@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-10 05:14:24+02:00
#
# ./DHFRsample/2014-07/msg00011.html
#
# nom_auteur  Nancy Ottaviano  mail_auteur ottaviano.nancy@gmail.com
#
# destinataires:  ['diffusion@listes.ancmsp.com', 'dh@groupes.renater.fr']
#
# 2014-07-09 22:34:26+02:00
#
# ./DHFRsample/2014-07/msg00013.html
#
# nom_auteur  Michel Bernard  mail_auteur michel.bernard@univ-paris3.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-10 09:09:21+02:00
#
# ./DHFRsample/2014-07/msg00019.html
#
# nom_auteur  Cynthia Pedroja  mail_auteur cynthia.pedroja@meshs.fr
#
# destinataires:  ['dh@cru.fr']
#
# 2014-07-17 14:42:17+02:00
#
# ./DHFRsample/2014-07/msg00004.html
#
# nom_auteur  Soudan Cecile  mail_auteur cecile.soudan@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-06 15:51:49+02:00
#
# ./DHFRsample/2014-07/msg00023.html
#
# nom_auteur  emmanuel guez  mail_auteur emmanuelguez@yahoo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-22 17:24:51+02:00
#
# ./DHFRsample/2014-07/msg00021.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-18 16:54:31+02:00
#
# ./DHFRsample/2014-07/msg00016.html
#
# nom_auteur  "Viera Rebolledo-Dhuin"  mail_auteur viera.rebolledodhuin@free.fr
#
# destinataires:  ['viera.rebolledodhuin@free.fr']
#
# 2014-07-16 20:28:39+02:00
#
# ./DHFRsample/2014-07/msg00017.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@cru.fr']
#
# 2014-07-17 09:52:32+02:00
#
# ./DHFRsample/2014-07/msg00015.html
#
# nom_auteur  Claire Clivaz  mail_auteur claire.clivaz@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-12 12:31:28+02:00
#
# ./DHFRsample/2014-07/msg00002.html
#
# nom_auteur  Claire Clivaz  mail_auteur claire.clivaz@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2014-07-04 22:10:57+02:00
#
# ./DHFRsample/2014-07/msg00020.html
#
# nom_auteur  Equipe projet IGLouvre  mail_auteur projet.iglouvre@gmail.com
#
# destinataires:  ['dh@cru.fr']
#
# 2014-07-17 12:39:42+02:00
#
# ./DHFRsample/2018-03/msg00030.html
#
# nom_auteur  Frédéric CLAVERT  mail_auteur frederic.clavert@uni.lu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 11:53:38+00:00
#
# ./DHFRsample/2018-03/msg00059.html
#
# nom_auteur  Raphaëlle Bour  mail_auteur raphaelle.bour@irit.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-21 12:43:49+01:00
#
# ./DHFRsample/2018-03/msg00006.html
#
# nom_auteur  Béatrice Markhoff  mail_auteur beatrice.markhoff@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-04 11:39:36+01:00
#
# ./DHFRsample/2018-03/msg00048.html
#
# nom_auteur   mail_auteur inatheque@ina.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-15 17:28:55
#
# ./DHFRsample/2018-03/msg00070.html
#
# nom_auteur  Olfa Lamloum  mail_auteur olfa.lamloum@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 14:32:33+01:00
#
# ./DHFRsample/2018-03/msg00018.html
#
# nom_auteur  Cecile Rodrigues  mail_auteur cecile.rodrigues@cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-09 14:10:27+01:00
#
# ./DHFRsample/2018-03/msg00064.html
#
# nom_auteur  Joel Marchand  mail_auteur joel.marchand@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 09:00:20+02:00
#
# ./DHFRsample/2018-03/msg00028.html
#
# nom_auteur  Cristofoli Pascal  mail_auteur pascal.cristofoli@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'dh-request@groupes.renater.fr']
#
# CCs:  ['dh-request@groupes.renater.fr']
# 2018-03-12 12:39:06+01:00
#
# ./DHFRsample/2018-03/msg00007.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-05 02:07:12+01:00
#
# ./DHFRsample/2018-03/msg00009.html
#
# nom_auteur  Pierre Mounier  mail_auteur pierre.mounier@openedition.org
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-05 11:11:00+01:00
#
# ./DHFRsample/2018-03/msg00078.html
#
# nom_auteur  dumouchel suzanne  mail_auteur dumouchelsuzanne@yahoo.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'culture.numerique@ml.free.fr', 'legram@yahoogroupes.fr', 'listesocius@groups.openedition.org']
#
# 2018-03-29 06:51:33+00:00
#
# ./DHFRsample/2018-03/msg00000.html
#
# nom_auteur  Annael LE POULLENNEC  mail_auteur annael.le-poullennec@psl.eu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-01 14:03:55+00:00
#
# ./DHFRsample/2018-03/msg00047.html
#
# nom_auteur  Marie-laure Massot  mail_auteur marie-laure.massot@ens.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'digit_hum@ens.fr']
#
# CCs:  ['digit_hum@ens.fr']
# 2018-03-15 14:40:57+01:00
#
# ./DHFRsample/2018-03/msg00058.html
#
# nom_auteur  Sandrine Clérisse  mail_auteur sandrine.clerisse@cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-21 10:40:36+01:00
#
# ./DHFRsample/2018-03/msg00005.html
#
# nom_auteur  HANNOUN Judith  mail_auteur judith.hannoun@univ-amu.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-02 15:19:10+00:00
#
# ./DHFRsample/2018-03/msg00079.html
#
# nom_auteur  CAVALLO Delphine  mail_auteur delphine.cavallo@univ-amu.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-29 10:23:54+00:00
#
# ./DHFRsample/2018-03/msg00067.html
#
# nom_auteur  Rails &amp; Histoire  mail_auteur listes@ahicf.com
#
# destinataires:  ['histoire_eco-request@groupes.renater.fr', 'athena@services.cnrs.fr', 'archives-fr@yahoogroupes.fr', 'dh@groupes.renater.fr', 'nep-his@lists.repec.org', 'medici@listes.huma-num.fr', 'ferinterfrance@googlegroups.com']
#
# 2018-03-26 11:44:18+02:00
#
# ./DHFRsample/2018-03/msg00022.html
#
# nom_auteur  recherche.coordination@bnf.fr mail_auteur recherche.coordination@bnf.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'dh-request@groupes.renater.fr']
#
# CCs:  ['dh-request@groupes.renater.fr']
# 2018-03-12 08:39:00+01:00
#
# ./DHFRsample/2018-03/msg00010.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'tei-fr@groupes.renater.fr', 'tei-fr@cru.fr']
#
# CCs:  ['tei-fr@groupes.renater.fr', 'tei-fr@cru.fr']
# 2018-03-05 15:10:29+01:00
#
# ./DHFRsample/2018-03/msg00065.html
#
# nom_auteur  Thierry Poibeau  mail_auteur thierry.poibeau@ens.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 09:17:00+02:00
#
# ./DHFRsample/2018-03/msg00069.html
#
# nom_auteur  dbernhard@unistra.fr mail_auteur dbernhard@unistra.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 12:32:35+02:00
#
# ./DHFRsample/2018-03/msg00074.html
#
#
# ./DHFRsample/2018-03/msg00046.html
#
# nom_auteur  Serge Heiden  mail_auteur slh@ens-lyon.fr
#
# destinataires:  ['txm-users@groupes.renater.fr', 'dh@groupes.renater.fr']
#
# 2018-03-15 11:33:42+01:00
#
# ./DHFRsample/2018-03/msg00033.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 14:59:27+01:00
#
# ./DHFRsample/2018-03/msg00072.html
#
# nom_auteur  Frédéric CLAVERT  mail_auteur frederic.clavert@uni.lu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 18:25:30+00:00
#
# ./DHFRsample/2018-03/msg00066.html
#
# nom_auteur  Adeline Joffres  mail_auteur adeline.joffres@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 11:36:23+02:00
#
# ./DHFRsample/2018-03/msg00050.html
#
# nom_auteur  François Bavaud  mail_auteur francois.bavaud@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# CCs:  ['llist@unil.ch']
# 2018-03-16 08:05:59+00:00
#
# ./DHFRsample/2018-03/msg00073.html
#
# nom_auteur  Frédéric CLAVERT  mail_auteur frederic.clavert@uni.lu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-27 11:23:08+00:00
#
# ./DHFRsample/2018-03/msg00037.html
#
# nom_auteur  "Antonio A. Casilli"  mail_auteur antonio.casilli@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-13 07:55:52+01:00
#
# ./DHFRsample/2018-03/msg00054.html
#
# nom_auteur  Elena Pierazzo  mail_auteur pierazzo@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-20 12:33:07+01:00
#
# ./DHFRsample/2018-03/msg00040.html
#
# nom_auteur  jerome valluy  mail_auteur jerome.valluy@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-13 13:32:40+01:00
#
# ./DHFRsample/2018-03/msg00080.html
#
# nom_auteur  Seth van Hooland  mail_auteur svhoolan@ulb.ac.be
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-29 15:57:02+02:00
#
# ./DHFRsample/2018-03/msg00042.html
#
# nom_auteur  Frédéric CLAVERT  mail_auteur frederic.clavert@uni.lu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-13 21:31:01+00:00
#
# ./DHFRsample/2018-03/msg00008.html
#
# nom_auteur  Thierry Poibeau  mail_auteur thierry.poibeau@ens.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-05 07:56:29+01:00
#
# ./DHFRsample/2018-03/msg00062.html
#
# nom_auteur  Aurélien Berra  mail_auteur aurelien.berra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-23 09:48:03+01:00
#
# ./DHFRsample/2018-03/msg00029.html
#
# nom_auteur  "Anne Gresillon"  mail_auteur gresillon@cmb.hu-berlin.de
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-07 15:44:01+01:00
#
# ./DHFRsample/2018-03/msg00003.html
#
# nom_auteur  Anne Baillot  mail_auteur anne.baillot@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-02 12:53:08+01:00
#
# ./DHFRsample/2018-03/msg00025.html
#
# nom_auteur  Francesco Beretta  mail_auteur francesco.beretta@ish-lyon.cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 10:55:52+01:00
#
# ./DHFRsample/2018-03/msg00036.html
#
# nom_auteur  lamasse  mail_auteur stephane.lamasse@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 19:23:47+01:00
#
# ./DHFRsample/2018-03/msg00024.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 10:44:21+01:00
#
# ./DHFRsample/2018-03/msg00034.html
#
# nom_auteur  clémence jacquot  mail_auteur clemence.jacquot@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 15:15:16+01:00
#
# ./DHFRsample/2018-03/msg00026.html
#
# nom_auteur  Georges-Xavier Blary  mail_auteur georges-xavier.blary@unilim.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 11:00:23+01:00
#
# ./DHFRsample/2018-03/msg00001.html
#
# nom_auteur  Seth van Hooland  mail_auteur svhoolan@ulb.ac.be
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-02 11:01:59+01:00
#
# ./DHFRsample/2018-03/msg00052.html
#
# nom_auteur  Martin Grandjean  mail_auteur martin.grandjean@unil.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-19 14:06:02+01:00
#
# ./DHFRsample/2018-03/msg00051.html
#
# nom_auteur  Rails &amp; Histoire  mail_auteur listes@ahicf.com
#
# destinataires:  ['histoire_eco-request@groupes.renater.fr', 'athena@services.cnrs.fr', 'archives-fr@yahoogroupes.fr', 'dh@groupes.renater.fr', 'nep-his@lists.repec.org', 'medici@listes.huma-num.fr', 'ferinterfrance@googlegroups.com']
#
# 2018-03-16 12:51:02+01:00
#
# ./DHFRsample/2018-03/msg00057.html
#
# nom_auteur  Sandrine Clérisse  mail_auteur sclerisse@parisnanterre.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-21 10:33:06+01:00
#
# ./DHFRsample/2018-03/msg00053.html
#
# nom_auteur  RAPHAELLE BRANGIER  mail_auteur raphaelle.krummeich@univ-rouen.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-19 18:02:18+01:00
#
# ./DHFRsample/2018-03/msg00014.html
#
# nom_auteur  Amel Fraisse  mail_auteur amel.fraisse@univ-lille3.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-06 14:57:59+01:00
#
# ./DHFRsample/2018-03/msg00071.html
#
# nom_auteur  Gérald Kembellec  mail_auteur gerald.kembellec@cnam.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 19:12:16+02:00
#
# ./DHFRsample/2018-03/msg00061.html
#
# nom_auteur  Laube Sylvain  mail_auteur sylvain.laube@univ-brest.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-21 16:16:06+01:00
#
# ./DHFRsample/2018-03/msg00035.html
#
# nom_auteur  ekergosien  mail_auteur eric.kergosien@univ-lille3.fr
#
# destinataires:  ['ln@cines.fr', 'liste-egc@polytech.univ-nantes.fr', 'info-ic@listes.irisa.fr', 'dh@groupes.renater.fr', 'adbs-info@listes.adbs.fr', 'bull-i3@irit.fr', 'accesouvert@groupes.renater.fr', 'docs-ri@yahoogroupes.fr', 'doccitanist@services.cnrs.fr', 'info-aria@lsis.org', 'inforsid@listes.insa-lyon.fr']
#
# 2018-03-12 15:18:57+01:00
#
# ./DHFRsample/2018-03/msg00012.html
#
# nom_auteur  Olivier Le Deuff  mail_auteur oledeuff@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-06 11:48:01+01:00
#
# ./DHFRsample/2018-03/msg00076.html
#
# nom_auteur  Rails &amp; Histoire  mail_auteur listes@ahicf.com
#
# destinataires:  ['histoire_eco-request@groupes.renater.fr', 'athena@services.cnrs.fr', 'archives-fr@yahoogroupes.fr', 'dh@groupes.renater.fr', 'nep-his@lists.repec.org', 'medici@listes.huma-num.fr', 'ferinterfrance@googlegroups.com']
#
# 2018-03-28 16:43:54+02:00
#
# ./DHFRsample/2018-03/msg00011.html
#
# nom_auteur  dumouchel suzanne  mail_auteur dumouchelsuzanne@yahoo.fr
#
# destinataires:  ['legram@yahoogroupes.fr', 'culture.numerique@ml.free.fr', 'dh@groupes.renater.fr', 'listesocius@groups.openedition.org']
#
# 2018-03-06 08:37:07+00:00
#
# ./DHFRsample/2018-03/msg00027.html
#
# nom_auteur  "Antonio A. Casilli"  mail_auteur antonio.casilli@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 08:56:36+01:00
#
# ./DHFRsample/2018-03/msg00075.html
#
# nom_auteur  Elodie Faath  mail_auteur elodie.faath@openedition.org
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-28 15:32:23+02:00
#
# ./DHFRsample/2018-03/msg00031.html
#
# nom_auteur  Laurence Rageot  mail_auteur laurence.rageot@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 13:45:47+01:00
#
# ./DHFRsample/2018-03/msg00013.html
#
# nom_auteur  Stéphane Vial  mail_auteur vial.stephane@gmail.com
#
# destinataires:  ['recherche-design@listes.univ-paris1.fr', 'dh@groupes.renater.fr', 'projekt-membres@liste.unimes.fr', 'projekt@unimes.fr', 'info@design-fax.fr', 'athena@services.cnrs.fr', 'theuth@listes.univ-rennes1.fr', 'culture.numerique@ml.free.fr']
#
# 2018-03-06 10:58:35+00:00
#
# ./DHFRsample/2018-03/msg00068.html
#
# nom_auteur  Adeline Joffres  mail_auteur adeline.joffres@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-26 12:04:54+02:00
#
# ./DHFRsample/2018-03/msg00056.html
#
# nom_auteur  Caroline Cance  mail_auteur caroline.cance@univ-orleans.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-21 09:24:41+01:00
#
# ./DHFRsample/2018-03/msg00039.html
#
# nom_auteur  Jouni Tuominen  mail_auteur jouni.tuominen@aalto.fi
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-13 14:20:26+02:00
#
# ./DHFRsample/2018-03/msg00032.html
#
# nom_auteur  marc jahjah  mail_auteur jahjah.marc@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 14:46:23+01:00
#
# ./DHFRsample/2018-03/msg00019.html
#
# nom_auteur  Michel Bernard  mail_auteur michel.bernard@univ-paris3.fr
#
# destinataires:  ['litor@listes.univ-paris3.fr', 'dh@cru.fr', 'numeruniv-quotidien@cines.fr']
#
# 2018-03-09 17:52:54+01:00
#
# ./DHFRsample/2018-03/msg00004.html
#
# nom_auteur  florence.clavaud@free.fr mail_auteur florence.clavaud@free.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-02 15:36:05+01:00
#
# ./DHFRsample/2018-03/msg00044.html
#
# nom_auteur  "Epler, Jakob"  mail_auteur jakob.epler@dariah.eu
#
# destinataires:  ['jakob.epler@dariah.eu']
#
# 2018-03-14 14:36:16+00:00
#
# ./DHFRsample/2018-03/msg00063.html
#
# nom_auteur  Amélie VAIRELLES  mail_auteur amelie.vairelles@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-23 17:23:21+01:00
#
# ./DHFRsample/2018-03/msg00055.html
#
# nom_auteur  Anne Baillot  mail_auteur anne.baillot@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-20 13:59:42+01:00
#
# ./DHFRsample/2018-03/msg00023.html
#
# nom_auteur  Francesco Beretta  mail_auteur francesco.beretta@ish-lyon.cnrs.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 09:52:19+01:00
#
# ./DHFRsample/2018-03/msg00021.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-12 07:38:13+01:00
#
# ./DHFRsample/2018-03/msg00045.html
#
# nom_auteur  IRIHS  mail_auteur irihs@univ-rouen.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-15 09:12:21+01:00
#
# ./DHFRsample/2018-03/msg00077.html
#
# nom_auteur  Marie-Eglantine Lescasse  mail_auteur marie.e.lescasse@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-28 17:09:57+02:00
#
# ./DHFRsample/2018-03/msg00016.html
#
# nom_auteur  Rails &amp; Histoire  mail_auteur listes@ahicf.com
#
# destinataires:  ['histoire_eco-request@groupes.renater.fr', 'athena@services.cnrs.fr', 'archives-fr@yahoogroupes.fr', 'dh@groupes.renater.fr', 'nep-his@lists.repec.org', 'medici@listes.huma-num.fr', 'ferinterfrance@googlegroups.com']
#
# 2018-03-09 13:41:36+01:00
#
# ./DHFRsample/2018-03/msg00038.html
#
# nom_auteur  CAVALLO Delphine  mail_auteur delphine.cavallo@univ-amu.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-13 10:19:25+00:00
#
# ./DHFRsample/2018-03/msg00043.html
#
# nom_auteur  Claire Lemercier  mail_auteur claire.lemercier@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-14 10:03:02+01:00
#
# ./DHFRsample/2018-03/msg00017.html
#
# nom_auteur  Marjorie Burghart  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-09 13:52:33+01:00
#
# ./DHFRsample/2018-03/msg00060.html
#
# nom_auteur  René Audet  mail_auteur Rene.Audet@lit.ulaval.ca
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-21 14:11:14+00:00
#
# ./DHFRsample/2018-03/msg00015.html
#
# nom_auteur  Jérôme Darmont  mail_auteur jerome.darmont@univ-lyon2.fr
#
# destinataires:  ['madics-adoc@listes.univ-lyon2.fr', 'annonces@madics.fr']
#
# CCs:  ['dh@groupes.renater.fr', 'fil-tmd@groupes.renater.fr', 'liste-egc@polytech.univ-nantes.fr', 'eda-liste@listes.univ-lyon2.fr', 'gazettebd3@imag.fr', 'bull-i3@irit.fr']
# 2018-03-09 11:17:31+01:00
#
# ./DHFRsample/2018-03/msg00002.html
#
# nom_auteur  Florence Andreacola  mail_auteur florence.andreacola@univ-grenoble-alpes.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-02 11:55:28+01:00
#
# ./DHFRsample/2018-03/msg00020.html
#
# nom_auteur  lamasse  mail_auteur stephane.lamasse@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-09 19:46:27+01:00
#
# ./DHFRsample/2018-03/msg00041.html
#
# nom_auteur  jerome valluy  mail_auteur jerome.valluy@univ-paris1.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2018-03-13 18:57:33+01:00
#
# ./DHFRsample/2018-03/msg00049.html
#
# nom_auteur  Graham Ranger  mail_auteur graham.ranger@univ-avignon.fr
#
# destinataires:  ['corpora@uib.no', 'saes@univ-pau.fr', 'alaes_liste@yahoogroupes.fr', 'dh@groupes.renater.fr', 'parislinguists@yahoogroupes.fr', 'agorantic@listes.univ-avignon.fr']
#
# 2018-03-15 20:45:58+01:00
#
# ./DHFRsample/2015-07/msg00030.html
#
# nom_auteur  Marta Severo  mail_auteur martaseve@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-24 15:52:17+02:00
#
# ./DHFRsample/2015-07/msg00006.html
#
# nom_auteur  Elena González-Blanco  mail_auteur elenagonzalezblanco@yahoo.es
#
# destinataires:  ['tei-l@listserv.brown.edu', 'humanist@lists.digitalhumanities.org', 'digitalclassicist@jiscmail.ac.uk', 'dm-l@uleth.ca', 'dhd@mailman.rrz.uni-hamburg.de', 'globaloutlookdh-l@uleth.ca', 'iwetel@listserv.rediris.es', 'aiucd-l@humnet.unipi.it', 'air-l@aoir.org', 'institute@lists.uvic.ca', 'dh@groupes.renater.fr', 'INFOLING@LISTSERV.REDIRIS.ES', 'infoling@listserv.rediris.es', 'humanist-l@uleth.ca', 'redhd@humanidadesdigitales.net', 'centernet@lists.digitalhumanities.org', 'dhcarolina@listserv.unc.edu', 'website@hastac.org', 'humanidadesdigitais@gmail.com']
#
# 2015-07-07 23:20:18+00:00
#
# ./DHFRsample/2015-07/msg00018.html
#
# nom_auteur  Serge Heiden  mail_auteur slh@ens-lyon.fr
#
# destinataires:  ['corpus-ecrits@cru.fr', 'cahier@groupes.renater.fr', 'ln@cines.fr', 'dh@groupes.renater.fr']
#
# 2015-07-11 18:41:24+10:00
#
# ./DHFRsample/2015-07/msg00028.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-20 12:29:17+02:00
#
# ./DHFRsample/2015-07/msg00007.html
#
# nom_auteur  Enrico Natale  mail_auteur enrico.natale@infoclio.ch
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-08 15:08:24+02:00
#
# ./DHFRsample/2015-07/msg00009.html
#
# nom_auteur  Hélène de Foucaud  mail_auteur hdefouca@u-paris10.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-08 16:44:49+02:00
#
# ./DHFRsample/2015-07/msg00000.html
#
# nom_auteur  Stéphane Pouyllau  mail_auteur stephane.pouyllau@huma-num.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-02 06:24:24+02:00
#
# ./DHFRsample/2015-07/msg00005.html
#
# nom_auteur  AZ  mail_auteur arno.zucker@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-05 09:38:43+02:00
#
# ./DHFRsample/2015-07/msg00022.html
#
# nom_auteur  Sofia Papastamkou  mail_auteur stamkou@free.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-13 17:08:22+02:00
#
# ./DHFRsample/2015-07/msg00010.html
#
# nom_auteur  Valérie Beaugiraud  mail_auteur valerie.beaugiraud@ens-lyon.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-09 11:42:23+02:00
#
# ./DHFRsample/2015-07/msg00033.html
#
# nom_auteur  CHADIER Christine  mail_auteur christine.chadier@univ-lyon3.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-30 09:52:01+00:00
#
# ./DHFRsample/2015-07/msg00008.html
#
# nom_auteur  Laurence Rageot  mail_auteur laurence.rageot@univ-tours.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# CCs:  ['olivier.marlet@univ-tours.fr']
# 2015-07-08 15:10:16+02:00
#
# ./DHFRsample/2015-07/msg00029.html
#
# nom_auteur  Eric Guichard  mail_auteur Eric.Guichard@enssib.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-22 22:23:19+02:00
#
# ./DHFRsample/2015-07/msg00003.html
#
# nom_auteur  Frédéric Clavert  mail_auteur frederic@clavert.net
#
# destinataires:  ['dh@cru.fr']
#
# 2015-07-02 15:41:35+02:00
#
# ./DHFRsample/2015-07/msg00025.html
#
# nom_auteur  Aurélie Olivesi  mail_auteur aurelie.olivesi@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-16 00:22:43+02:00
#
# ./DHFRsample/2015-07/msg00024.html
#
# nom_auteur  YAMINA BENSAADOUNE  mail_auteur yamina.bensaadoune@univ-rouen.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-15 17:07:53+02:00
#
# ./DHFRsample/2015-07/msg00034.html
#
# nom_auteur  CHADIER Christine  mail_auteur christine.chadier@univ-lyon3.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-30 09:59:31+00:00
#
# ./DHFRsample/2015-07/msg00026.html
#
# nom_auteur  Elena Spadini  mail_auteur spadinielena@gmail.com
#
# destinataires:  ['TEXTUALSCHOLARSHIP@jiscmail.ac.uk']
#
# 2015-07-16 12:16:27+02:00
#
# ./DHFRsample/2015-07/msg00001.html
#
# nom_auteur  Aurélien Berra  mail_auteur aurelien.berra@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-02 09:52:36+00:00
#
# ./DHFRsample/2015-07/msg00014.html
#
# nom_auteur  Sylvain Laurens  mail_auteur laurens@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-09 11:45:25+02:00
#
# ./DHFRsample/2015-07/msg00035.html
#
# nom_auteur  Serge Heiden  mail_auteur slh@ens-lyon.fr
#
# destinataires:  ['txm-users@groupes.renater.fr', 'corpus-ecrits@cru.fr', 'ln@cines.fr', 'dh@groupes.renater.fr']
#
# 2015-07-31 15:47:01+02:00
#
# ./DHFRsample/2015-07/msg00012.html
#
# nom_auteur  Mathieu Andro  mail_auteur Mathieu.Andro@versailles.inra.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-09 12:05:28+02:00
#
# ./DHFRsample/2015-07/msg00011.html
#
# nom_auteur  Olivier Le Deuff  mail_auteur oledeuff@gmail.com
#
# destinataires:  ['valerie.beaugiraud@ens-lyon.fr', 'dh@groupes.renater.fr']
#
# CCs:  ['dh@groupes.renater.fr']
# 2015-07-09 11:45:18+02:00
#
# ./DHFRsample/2015-07/msg00027.html
#
# nom_auteur  Burghart Marjorie  mail_auteur marjorie.burghart@ehess.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-17 14:16:38+02:00
#
# ./DHFRsample/2015-07/msg00031.html
#
# nom_auteur  Anne Baillot  mail_auteur anne.baillot@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-26 16:15:52+02:00
#
# ./DHFRsample/2015-07/msg00013.html
#
# nom_auteur  Clarisse Bardiot  mail_auteur clarisse_bardiot@me.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-09 14:46:14+02:00
#
# ./DHFRsample/2015-07/msg00032.html
#
# nom_auteur  Audrey Baneyx - Sciences Po  mail_auteur audrey.baneyx@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr', 'info-ic@listes.irisa.fr']
#
# 2015-07-27 14:16:20+02:00
#
# ./DHFRsample/2015-07/msg00019.html
#
# nom_auteur  Emmanuelle Morlock  mail_auteur emmanuelle.morlock@gmail.com
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-11 19:24:29+02:00
#
# ./DHFRsample/2015-07/msg00004.html
#
# nom_auteur  "Noiret, Serge"  mail_auteur Serge.Noiret@EUI.eu
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-03 10:17:19+00:00
#
# ./DHFRsample/2015-07/msg00023.html
#
# nom_auteur  Michel Bernard  mail_auteur michel.bernard@univ-paris3.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-14 11:43:26+02:00
#
# ./DHFRsample/2015-07/msg00021.html
#
# nom_auteur  Gérald Kembellec  mail_auteur gerald.kembellec@cnam.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-13 12:46:15+02:00
#
# ./DHFRsample/2015-07/msg00016.html
#
# nom_auteur  Emmanuelle Duwez  mail_auteur emmanuelle.duwez@sciencespo.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-10 18:33:17+02:00
#
# ./DHFRsample/2015-07/msg00017.html
#
# nom_auteur  Pierre-Edouard Barrault  mail_auteur pe.barrault@gmail.com
#
# destinataires:  ['emmanuelle.duwez@sciencespo.fr']
#
# CCs:  ['dh@groupes.renater.fr']
# 2015-07-10 19:43:36+02:00
#
# ./DHFRsample/2015-07/msg00015.html
#
# nom_auteur  Stéphane Loret  mail_auteur stephane.loret@univ-nantes.fr
#
# destinataires:  ['dh@groupes.renater.fr']
#
# 2015-07-10 10:55:45+02:00
#
# ./DHFRsample/2015-07/msg00002.html
#
# nom_auteur  marie-noelle.polino@ahicf.com mail_auteur marie-noelle.polino@ahicf.com
#
# destinataires:  ['marie-noelle.polino@ahicf.com']
#
# 2015-07-02 14:10:25+02:00
#
# ./DHFRsample/2015-07/msg00020.html
#
# nom_auteur  "Manuel Zacklad"  mail_auteur manuel.zacklad@cnam.fr
#
# destinataires:  ['Mathieu.Andro@versailles.inra.fr', 'dh@groupes.renater.fr']
#
# CCs:  ['lisa.chupin@gmail.com']
# 2015-07-12 18:26:27+02:00
# {'./DHFRsample/2017-06/msg00011.html': {'nom_auteur': 'Jorge Fins ', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'jorge.fins@univ-tours.fr', 'ref_physique_de_l_article': './DHFRsample/2017-06/msg00011.html', 'sujet_du_message': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'date': datetime.datetime(2017, 6, 8, 13, 51, 2, tzinfo=tzlocal())}, './DHFRsample/2018-03/msg00011.html': {'nom_auteur': 'dumouchel suzanne ', 'liste_mails_dests': ['legram@yahoogroupes.fr', 'culture.numerique@ml.free.fr', 'dh@groupes.renater.fr', 'listesocius@groups.openedition.org'], 'mail_auteur': 'dumouchelsuzanne@yahoo.fr', 'ref_physique_de_l_article': './DHFRsample/2018-03/msg00011.html', 'sujet_du_message': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'date': datetime.datetime(2018, 3, 6, 8, 37, 7, tzinfo=tzutc())}, './DHFRsample/2017-06/msg00021.html': {'nom_auteur': 'antoine Courtin ', 'liste_mails_dests': ['dh@groupes.renater.fr', 'ontologie-patrimoine@services.cnrs.fr'], 'mail_auteur': 'antoine.courtin@mac.com', 'ref_physique_de_l_article': './DHFRsample/2017-06/msg00021.html', 'sujet_du_message': u": [DH] [#LundisNum \xe0 l'INHA] Onoma : un r\xe9f\xe9rentiel d'acteurs du minist\xe8re de la Culture ancr\xe9 dans le Web s\xe9mantique - 12 juin \xe0 18h", 'date': datetime.datetime(2017, 6, 9, 22, 38, 49, tzinfo=tzoffset(None, 7200))}, './DHFRsample/2011-07/msg00004.html': {'nom_auteur': 'Laetitia Bontemps ', 'liste_mails_dests': ['DH@cru.fr'], 'mail_auteur': 'laetitia.bontemps@univ-tours.fr', 'ref_physique_de_l_article': './DHFRsample/2011-07/msg00004.html', 'sujet_du_message': u': [DH] Stage initiation XML-TEI (Tours, octobre 2011)', 'date': datetime.datetime(2011, 7, 19, 15, 4, 42, tzinfo=tzoffset(u'BST', 3600))}, './DHFRsample/2013-07/msg00022.html': {'nom_auteur': 'St\xc3\xa9phane Pouyllau ', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'stephane.pouyllau@huma-num.fr', 'ref_physique_de_l_article': './DHFRsample/2013-07/msg00022.html', 'sujet_du_message': u': Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities', 'date': datetime.datetime(2013, 7, 12, 17, 57, 32, tzinfo=tzoffset(None, 7200))}, './DHFRsample/2018-03/msg00026.html': {'nom_auteur': 'Georges-Xavier Blary ', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'georges-xavier.blary@unilim.fr', 'ref_physique_de_l_article': './DHFRsample/2018-03/msg00026.html', 'sujet_du_message': u': Re: [DH] Un atelier de prosopographie', 'date': datetime.datetime(2018, 3, 12, 11, 0, 23, tzinfo=tzoffset(None, 3600))}, './DHFRsample/2017-06/msg00057.html': {'nom_auteur': '"Wandl-Vogt, Eveline" ', 'liste_mails_dests': ['exploreAT@oeaw.ac.at'], 'mail_auteur': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'ref_physique_de_l_article': './DHFRsample/2017-06/msg00057.html', 'sujet_du_message': u': [DH] exploreAT! job offer @ vienna: citizen science & DIY science; cultural lexicographer', 'date': datetime.datetime(2017, 6, 26, 20, 54, 38, tzinfo=tzutc())}, './DHFRsample/2018-03/msg00027.html': {'nom_auteur': '"Antonio A. Casilli" ', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'antonio.casilli@ehess.fr', 'ref_physique_de_l_article': './DHFRsample/2018-03/msg00027.html', 'sujet_du_message': u': [DH] Offre de stage INRIA 6 mois r\xe9mun\xe9r\xe9 (projet DiPLab)', 'date': datetime.datetime(2018, 3, 12, 8, 56, 36, tzinfo=tzlocal())}, './DHFRsample/2013-07/msg00029.html': {'nom_auteur': 'Fr\xc3\xa9d\xc3\xa9ric Clavert ', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'frederic@clavert.net', 'ref_physique_de_l_article': './DHFRsample/2013-07/msg00029.html', 'sujet_du_message': u': [DH] Fwd: Appel \xe0 communication : \xab The Hi stories of Digital Art \xbb (10-12 avril 2014, AAH, L ondres)', 'date': datetime.datetime(2013, 7, 17, 10, 30, 2, tzinfo=tzoffset(None, 7200))}, './DHFRsample/2013-07/msg00031.html': {'nom_auteur': 'Antoine Blanchard ', 'liste_mails_dests': ['Nicole.Dufournaud@ ...
# 294
# 35
# Taux_de_mail_avec_CC: 0.119047619048
# None
