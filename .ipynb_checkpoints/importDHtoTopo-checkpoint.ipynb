# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
# setup mongo
client = MongoClient()
db = client["bandstour"]
bandsintown =  db["minedArtists"]

# credentials
TOPOGRAM_URL = "https://app.topogram.io"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
title = "Foo Fighters bandstour 0.1"
my_nodesdict = {}
my_nodes= []
my_edges = []


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'

#retrieve trip coords for each artist
dict_coords={}

for artist in db.minedArtists.find({"name":"Foo Fighters"}) :
    print artist["name"]
    #print artist
    dates_coords = []
    dates = artist.get("gigs")
    dateini = 0
    for date in dates:
        #print date.get("datetime")
        venue = date.get("venue")
        latitude = venue.get("latitude")
        longitude = venue.get("longitude")
        #print venue
        ###concat key
        idd= venue["name"]+str(int(venue["latitude"]))+str(int(venue["longitude"]))
        
        if idd not in my_nodesdict:
            node = {
                "id" : idd,
                "name" : venue["name"],
                "lat" : float(venue["latitude"]),
                "lng" : float(venue["longitude"]),
                "weight" : float(1),
                "start" : date.get("datetime").isoformat(),
                "end" : (date.get("datetime")+timedelta(days=1)).isoformat()
                }
        else:
            
            node = {
                "id" : idd,
                "name" : venue["name"],
                "lat" : float(venue["latitude"]),
                "lng" : float(venue["longitude"]),
                "weight" : float(my_nodesdict[idd]["data"].get("weight"))+1 ,
                "start" : my_nodesdict[idd]["data"].get("start"),
                "end" : date.get("datetime").isoformat()
                }
        if dateini == 0:
            dateini =1
        else:
            #print my_nodes[-1]["data"]["id"]
            edge = {
                "source" : my_nodes[-1]["data"]["id"],
                "target" : node["id"],
#                "weight" : float(e["weight"])
            }
            #print edge
            my_edges.append({ "data" : edge })
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
    print my_nodes
    print "<=============================================>"
    print my_nodesdict
    print "<=============================================>"
    print my_edges

        #print "coords",latitude,"/",longitude
# Out:
# Foo Fighters
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-9a52d6f744cc> in <module>()
#      72         my_nodes.append({ "data" : node })
#      73         my_nodesdict[node["id"]]= { "data" : node }
# ---> 74     print my_modes
#      75     print "<=============================================>"
#      76     print my_nodesdict
#
# NameError: name 'my_modes' is not defined

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'smfTNnOoupf0fkEVkh2cUP7ZQ5174r4a3Vr4_iaJQqC', u'userId': u'DaofbRenqYpqqNmtz'}}

# %%
print my_nodesdictList
# Out:
# [{'data': {'end': '2006-06-13T19:00:00', 'name': u'Regent Theatre', 'weight': 1.0, 'start': '2006-06-12T19:00:00', 'lat': 52.057152, 'lng': 1.160702, 'id': u'Regent Theatre521'}}, {'data': {'end': '2001-03-16T19:00:00', 'name': u'House Of Blues', 'weight': 1.0, 'start': '2001-03-15T19:00:00', 'lat': 28.367735, 'lng': -81.519822, 'id': u'House Of Blues28-81'}}, {'data': {'end': '2015-10-04T19:00:00', 'name': u'Centennial Olympic Park', 'weight': 2.0, 'start': '2015-10-04T19:00:00', 'lat': 33.7603812, 'lng': -84.393292, 'id': u'Centennial Olympic Park33-84'}}, {'data': {'end': '2011-06-23T18:30:00', 'name': u'Stockholms Stadion', 'weight': 1.0, 'start': '2011-06-22T18:30:00', 'lat': 59.3333333, 'lng': 18.05, 'id': u'Stockholms Stadion5918'}}, {'data': {'end': '2007-07-06T19:00:00', 'name': u'Dingwalls', 'weight': 1.0, 'start': '2007-07-05T19:00:00', 'lat': 51.541508, 'lng': -0.145892, 'id': u'Dingwalls510'}}, {'data': {'end': '2000-05-02T19:00:00', 'name': u'Barton Coliseum', 'weight': 1.0, 'start': '2000-05-01T19:00:00', 'lat': 34.724111, 'lng': -92.298869, 'id': u'Barton Coliseum34-92'}}, {'data': {'end': '2011-11-17T19:00:00', 'name': u'TD Garden', 'weight': 1.0, 'start': '2011-11-16T19:00:00', 'lat': 42.3583333, 'lng': -71.0602778, 'id': u'TD Garden42-71'}}, {'data': {'end': '2006-06-18T19:00:00', 'name': u'Hyde Park', 'weight': 1.0, 'start': '2006-06-17T19:00:00', 'lat': 51.507432, 'lng': -0.165708, 'id': u'Hyde Park510'}}, {'data': {'end': '1995-08-01T19:00:00', 'name': u'Electric Ballroom', 'weight': 1.0, 'start': '1995-07-31T19:00:00', 'lat': 33.4483333, 'lng': -112.0733333, 'id': u'Electric Ballroom33-112'}}, {'data': {'end': '2017-08-20T00:00:00', 'name': u'Maishima Sports Island', 'weight': 1.0, 'start': '2017-08-19T00:00:00', 'lat': 34.66692, 'lng': 135.396744, 'id': u'Maishima Sports Island34135'}}, {'data': {'end': '2008-01-20T19:00:00', 'name': u'Pensacola Civic Center', 'weight': 2.0, 'start': '2000-05-05T19:00:00', 'lat': 30.4211111, 'lng': -87.2169444, 'id': u'Pensacola Civic Center30-87'}}, {'data': {'end': '2004-05-02T19:00:00', 'name': u'Music Midtown', 'weight': 1.0, 'start': '2004-05-01T19:00:00', 'lat': 33.7906777, 'lng': -84.36718, 'id': u'Music Midtown33-84'}}, {'data': {'end': '1997-08-14T19:00:00', 'name': u'Live Music Hall', 'weight': 2.0, 'start': '1995-08-31T19:00:00', 'lat': 50.9552, 'lng': 6.90867, 'id': u'Live Music Hall506'}}, {'data': {'end': '2012-08-19T20:00:00', 'name': u'Pukkelpop', 'weight': 1.0, 'start': '2012-08-18T20:00:00', 'lat': 50.9405403, 'lng': 5.3418798, 'id': u'Pukkelpop505'}}, {'data': {'end': '2005-05-15T19:00:00', 'name': u'M&T Bank Stadium', 'weight': 1.0, 'start': '2005-05-14T19:00:00', 'lat': 39.2777786, 'lng': -76.6226654, 'id': u'M&T Bank Stadium39-76'}}, {'data': {'end': '2008-01-24T20:00:00', 'name': u'American Airlines Center', 'weight': 1.0, 'start': '2008-01-23T20:00:00', 'lat': 32.7833333, 'lng': -96.8, 'id': u'American Airlines Center32-96'}}, {'data': {'end': '2000-12-14T19:00:00', 'name': u'Barrowlands', 'weight': 4.0, 'start': '1995-11-11T19:00:00', 'lat': 55.8333333, 'lng': -4.25, 'id': u'Barrowlands55-4'}}, {'data': {'end': '2007-08-19T00:00:00', 'name': u'Weston Park', 'weight': 2.0, 'start': '2001-08-18T19:00:00', 'lat': 52.8, 'lng': -2.1, 'id': u'Weston Park52-2'}}, {'data': {'end': '2000-02-05T19:00:00', 'name': u'RA&HS Showgrounds', 'weight': 1.0, 'start': '2000-02-04T19:00:00', 'lat': -34.9333333, 'lng': 138.6, 'id': u'RA&HS Showgrounds-34138'}}, {'data': {'end': '2015-08-26T19:00:00', 'name': u'First Niagara Pavilion', 'weight': 1.0, 'start': '2015-08-25T19:00:00', 'lat': 40.4405556, 'lng': -79.9961111, 'id': u'First Niagara Pavilion40-79'}}, {'data': {'end': '2002-09-05T19:00:00', 'name': u'Le Trabendo', 'weight': 1.0, 'start': '2002-09-04T19:00:00', 'lat': 48.9011778, 'lng': 2.3892697, 'id': u'Le Trabendo482'}}, {'data': {'end': '2008-07-09T19:00:00', 'name': u'Key Arena', 'weight': 3.0, 'start': '1999-12-09T19:00:00', 'lat': 47.6063889, 'lng': -122 ...

# %%
create_topogram(title, my_nodesdictList, my_edges)
# Out:
# Creating topogram 'Foo Fighters bandstour 0.1'
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'Foo Fighters bandstour 0.1', u'userId': u'DaofbRenqYpqqNmtz', u'_id': u'8ctJm2R2vYqi8X9er', u'slug': u'foo-fighters-bandstour-01', u'createdAt': u'2017-10-12T12:35:59.771Z'}, u'statusCode': 200}
# topogram ID : 8ctJm2R2vYqi8X9er
# {u'status': u'success', 'status_code': 200, u'data': [u'TfzQPMv8sLn4QRML6', u'BrBRAsRuEPG7KizbS', u'mmTE4kSYygFqxsTwu', u'vdkQvEiW2mLM3W8nW', u'u6raE9wjS3PPvKXfQ', u'jbW6p4gqxJANRQ5j4', u'2X4nPAFN6PdfrqXKc', u'PehHKHfWkDeF7xLhH', u'TJurJMxGxSAHHxQ36', u'Rr32syvDt9TQSuvLJ', u'NDYmgtBjxHQLsbqt6', u'XMa7u5ZfDZwFp75j9', u'uffeevw6LWssHG5Dy', u'uR2gzEF3cHXQAZgFC', u'3PAfLRDMPQAnQEXx8', u'soYPLBLvxd3gHq4zA', u'afnbzxsHEtjGQtrgz', u'xu9yGf2Qxthg9rsmC', u'nRihFP5ydzbCxfYjK', u'rFjPFtZqehc6N6Bcf', u'DzN9KFYMQYBZT5Gbc', u'v4P3gKGd5JzZG5k9b', u'hWvsLuDjhmvEeeSLR', u'WaMHRf5CXkauX75a8', u'7iLpcTtDJ3qteLxi3', u'ktt68WmiSpphyiwCA', u'wDywi5RuwvGQKWyTc', u'MNqFLfgGb324kibzZ', u'4ZaAcmRHsKNypoJqX', u'8zDNP4RpPF6bYBarv', u'TppLxok6cG299dPjp', u'fad5zQ5G5ezs7xwWQ', u'y6daWmE7bZKGjKeDr', u'kprxzKZKpf6gx27Bd', u'YxBwrgsWfYyGCnwiF', u'b4YnQ56uuq4znRTSN', u'6sDDDpmphRsQcx5Sp', u'9HruPYCLcfRJ4YKoj', u'hkPrBRP364KoHKKBd', u'ugh8b6yspR9A3GtTG', u'mbndPoK8o387Lgoph', u'S5RBLqJagDfz9X7PN', u'drMHy5rZBFbT5ihk3', u'yJjv7fTHJD9fuyuSW', u'cMZSJ8shDAeReTsS9', u'xjLyfWwrdCqmgBQZj', u'WQYw9ZfLXnu3NGDXd', u'sfwyFaTaEsrTAFiPc', u'LMRXXGoKHkfTPMJ9F', u'MgC7PHCD4rKSXNZcs', u'sreyrj5a9MLgMnmvb', u'RwbsNsYLuwfnqQ9is', u'CBeGXate78xCAMPWf', u'69iauRB4J5Wuw2cCZ', u'MXgp2rhHTz872Ao3y', u'YeL9gMD4hivr9rywb', u'RAnbqg6fXxD3AEEER', u'groDucG5L2Hrinx7H', u'MLmBqWQNYseLm4L7g', u'vwS5MmtXGT6SCEwsb', u'3Wc5zGYqQQh3pJh3w', u'LXdAYgeWXkEWnXiS2', u'F7oYsdqNpQ7ojm3mB', u'EWRc6GHzDA9FqKDMo', u'PYFMe97N6MYErvkwN', u'rHE8LRNjhxJrDjPqq', u'GMWQd7teiThTBzNyL', u'ZJqLLkyJdMfttgCAy', u'S6eaKLF2cXPtiZoT7', u'cu9xeabzAEZYt6DeM', u'wZBWeWACeGFqPwqsr', u'Pkg6Hs5nNBkcK8x6p', u'ibdTXQCBtbKxhKy8z', u'LQqKMs6EqbE45HS6p', u'2xdRemjWtEqSHd6Lr', u'DRWEM8ZF8WzSY44na', u'A4Z7L6Xey9EzdJ2Sd', u'giusckh6Xv6pydoz8', u'7guY5L6FMKzYz6QjQ', u'vur5ooAvCycC2iP2s', u'LJTixav425zscBp7S', u'aFgYuTnvwuCwninE7', u'832KjCLBxWZRsZYid', u'2ADDpRg6giZSJerde', u'3ZERa3wGKHsaocc39', u'o3omCjMTbbY8dcBX6', u'JY7sgn6gF68cTieEt', u'vn55MnpZRmdznYx8Y', u'tmfu2AKEpwi8MxvWC', u'eYB7h5h3Zc8haiW3v', u'X4vAQebRkmCKv646k', u'e6zM8garmHENRzGX3', u'4LBSS4qRxMfsPkY2d', u'NMKwaCayeStGiNhgD', u'eGwrANiegmcib4cNb', u'C3Bv52hgoLT3G8iMt', u'7wFPZWB74Prs5PQuQ', u'njjS6kxLmKTEmh2o7', u'DGCRCpBstPsCiC7kF', u'6WbumDzr8Gyf8tQMZ', u'XorH9gqFsE9dLT8ET', u'JoZMErBa43Bp87oFW', u'SdFcmqYuhGcib3LHS', u'5GD5sWLGfy5pCwWZ6', u'3Tdn5QrASJAdesrxk', u'ounCouRhdsnC8zbFR', u'AtCSD8CHiaMMAJfuW', u'YGZb974FMsqoQTcLd', u'GCnET4STvTP6fi9Pw', u'AEHLjfJ4xuDutsihW', u'g7GuDwfjvLbtKDpz6', u'zA38wcZAtLpHwesMh', u'v6K7JWd6ZL9CtGH24', u'8oPpuuJQMHjsQgQPv', u'kJfSXRGBdKDPX7hDw', u'DBNNRDtcfR5BPQ26c', u'pGZsFevBpxWErYBhX', u'H5o3cwLc6F98jh3Tk', u'Y2LG5WW74WHmSmeqE', u'ezeXqqmRJbCMN5Pgr', u'hZRWJEQ8xFtCNRGHQ', u'hyWH43QagCTHTGKFj', u'JgsKKxNJiND7ZawQC', u'bWip8jWvhMH62T2n6', u'4DNpZAvWYRdxAfwyZ', u'mn3Jhkka36GKhDtxD', u'kxYj5vi4eYzs7A5cH', u'xuHJS4BWMmPYsXfnq', u'tTPDRYkityqJFKSZt', u'd25LwFSaoPXWX84rD', u'E43kJiz7a5f5RdkCW', u'XTwbfZFjscAdD268X', u'5vAKNn2woCoFXG9uP', u'hEswAjtkEyZ2FJLgj', u'bcowQJhQmwZb3Fe86', u'7zmN8mmTFDnwYi9mv', u'y9TozCfLnS3nHfCK4', u'2Tk8TwDckJkXCt8kN', u'zb5omjYGBtmLx9nW2', u'g9FziD9p2p6MsRmFB', u'fbiQRNR4CsdQpB67S', u'D3QRF2PvAESaQhTd6', u'fcgvDHc8maB87zD5C', u'gHNjy9vQTzQTG427j', u'5iMwEJo6kgr2geGHC', u'Wr2miHyFs4S3AA7uq', u'2TkWub3AR24mjX5ww', u'vXA7LohzTqbdu4gDv', u'kdkS7BGEDsPnqq87r', u'CCqEts2NDfeRu9msp', u'u77Ri5AQcwD4PqPBL', u'GYNJCj5WrDJMhqtWJ', u'xQfhpRjKkzJa7m2ig', u'frgAyPkbia49AhzzQ', u'eRthTdbMkxX8pwHJQ', u'J9RRg6yArJndWacqR', u'EmZTZAsxWifAL8vbt', u'af4XLDxmBABLgbpPa', u'B4QDRWNfhRLrhEFHz', u'BsZW3FLetfJo7JrQF', u'yti55iWAvWk76rukT', u'CeAmnwyv9trqJeKKj', u'u4v3Z28P7DQq9gp5N', u'CDfiXAi7KfHFkJukf', u'ZQzXEfGu8LG5Nxu7T', u'Fg28unHtK2aW2yyEm', u'zGQLYTt6XAKvn9mHT', u'GySrKa2cuN25kGEsh', u'orHDkMoM8YghFF8yD', u'uMQz7Rga7GbkttR7Z', u'e9zt6SGFKNphMEg3o', u'QtboQTdKPMkpj4qXc', u'72EGENP4oRZBs6iyZ', u'pFpWKsAPet97SzL4Q', u'tJzYsoSzACf9R75om', u'esnwGy4CZp2uWeChb', u'JSwJmEdgkr6mKhh4B', u'hWqhEudBi4Lrp45H6', u'mmM7zYFMJEkF6n5NB', u'm2eNu3 ...
# 643 nodes created.
# 940 edges created.
# done. Topogram has been updated. Check it at https://app.topogram.io/topograms/8ctJm2R2vYqi8X9er

# %%
    #print artist
    

        dates_coords.append( [latitude,longitude])
    #print "datec",date_coords
    datapushed={}
    datapushed["dates_coords_lat_long"]=dates_coords
    datapushed["id"]=artist["_id"]
    datapushed["slug"]=artist["slug"]
    print datapushed
    dict_coords[artist["slug"]]=datapushed
print dict_coords



with open('data/test_data_nodes.csv') as f :
    reader = DictReader(f)
    for n in reader :
        node = {
            "id" : n["id"],
            "name" : n["name"],
            "lat" : float(n["lat"]),
            "lng" : float(n["lng"]),
            "weight" : float(n["weight"]),
            "start" : n["year_start"],
            "end" : n["year_stop"]
            }
        my_nodes.append({ "data" : node })

print my_nodes

with open('data/test_data_edges.csv') as f :
    reader = DictReader(f)
    for e in reader :
        edge = {
            "source" : e["source"],
            "target" : e["target"],
            "weight" : float(e["weight"])
        }
        my_edges.append({ "data" : edge })

# print my_edges

def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)

    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)

create_topogram("Geo-time network", my_nodes, my_edges)
