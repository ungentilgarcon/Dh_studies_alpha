# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
#import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
import pickle
with open('dict_corrected_DH.obj', 'rb') as handle:
    dict_corrected_DH = pickle.load(handle)
with open('geocoded_locs.obj', 'rb') as handle:
    geocoded_locs = pickle.load(handle)

with open('corpus_mails_DH.obj', 'rb') as handle:
    corpus_mails_DH = pickle.load(handle)

with open('dict_noms_mails_debut_fin.obj', 'rb') as handle:
    dict_noms_mails_debut_fin = pickle.load(handle)
    

with open('liste_de_tous_les_mails.obj', 'rb') as handle:
    liste_de_tous_les_mails = pickle.load(handle)

# %%
    
print str(dict_corrected_DH)[:1000],"\n"
print str(geocoded_locs)[:1000],"\n"
print str(corpus_mails_DH)[:1000],"\n"
print str(dict_noms_mails_debut_fin)[:1000],"\n"
print str(liste_de_tous_les_mails)[:1000],"\n"
# Out:
# {'googlegroups.com': {u'geometry': {u'location': {u'lat': '43.8424986', u'lng': '4.354806'}}}, 'lecnam.net': {u'geometry': {u'location': {u'lat': '43.8424986', u'lng': '4.354806'}}}, 'jiscmail.ac.uk': {u'geometry': {u'location': {u'lat': '43.8424986', u'lng': '4.354806'}}}, 'design.ulaval.ca': {u'geometry': {u'location': {u'lat': 46.812707, u'lng': -71.225985}, u'viewport': {u'northeast': {u'lat': 46.8140559802915, u'lng': -71.2246360197085}, u'southwest': {u'lat': 46.8113580197085, u'lng': -71.2273339802915}}, u'location_type': u'GEOMETRIC_CENTER'}, u'address_components': [{u'long_name': u'Qu\xe9bec', u'types': [u'locality', u'political'], u'short_name': u'Qu\xe9bec'}, {u'long_name': u'Qu\xe9bec', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'QC'}, {u'long_name': u'Canada', u'types': [u'country', u'political'], u'short_name': u'CA'}, {u'long_name': u'G1K 3G8', u'types': [u'postal_code'], u'short_name': u'G1K 3G8'}], u'place_id': u'ChIJDWgVp3GWuEwRKa5K0WLTY
#
# {'googlegroups.com': 'TO8BE8MANUALLY8EDITED', 'lecnam.net': 'TO8BE8MANUALLY8EDITED', 'jiscmail.ac.uk': 'TO8BE8MANUALLY8EDITED', 'design.ulaval.ca': {u'geometry': {u'location': {u'lat': 46.812707, u'lng': -71.225985}, u'viewport': {u'northeast': {u'lat': 46.8140559802915, u'lng': -71.2246360197085}, u'southwest': {u'lat': 46.8113580197085, u'lng': -71.2273339802915}}, u'location_type': u'GEOMETRIC_CENTER'}, u'address_components': [{u'long_name': u'Qu\xe9bec', u'types': [u'locality', u'political'], u'short_name': u'Qu\xe9bec'}, {u'long_name': u'Qu\xe9bec', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'QC'}, {u'long_name': u'Canada', u'types': [u'country', u'political'], u'short_name': u'CA'}, {u'long_name': u'G1K 3G8', u'types': [u'postal_code'], u'short_name': u'G1K 3G8'}], u'place_id': u'ChIJDWgVp3GWuEwRKa5K0WLTYnk', u'formatted_address': u'295 Boulevard Charest Est, bureau 090, Qu\xe9bec, QC G1K 3G8, Canada', u'types': [u'establishment', u'point_of_interes
#
# {'./DHFRsample/2017-06/msg00011.html': {'Geo_Topic': {'content': '\nbonjour,j&#39;ai eu une tr\xc3\xa8s bonne exp\xc3\xa9rience avec eux sous drupal 7, il y a quelques ann\xc3\xa9es : http://www.supersoniks.com/je ne sais pas comment ils g\xc3\xa8rent le passage actuel \xc3\xa0 drupal 8, en revanche.cordialement,jorge finsie msh val de loirede: &quot;myriam tazi&quot; &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n &gt;\xc3\x80: \n \n <!-- \n document.write("dh" + "@" + "groupes.renater.fr")\n // -->\n envoy\xc3\xa9: jeudi 8 juin 2017 12:11:54objet: [dh] prestation de d\xc3\xa9veloppement sous drupalbonjour,la biblioth\xc3\xa8que de sciences po va d\xc3\xa9velopper un site sous drupal avec un prestataire dans le cadre d&#39;un projet de valorisation. auriez vous des prestataires \xc3\xa0 conseiller ? avec qui vous avez eu une bonne exp\xc3\xa9rience ou des bons retours ?merci d&#39;avance,-- myriam taziservice appui \xc3\xa0 la recherche et outils num
#
# {'Pierre Mounier': [['pierre.mounier@openedition.org', datetime.datetime(2013, 7, 5, 10, 9, 24, tzinfo=tzoffset(None, 7200)), datetime.datetime(2018, 3, 5, 11, 11, tzinfo=tzoffset(None, 3600))], ['pierre.mounier@ehess.fr', datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200)), datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200))]], 'aude.da-cruz-lima': [['aude.da-cruz-lima@mae.u-paris10.fr', datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200))]], 'Thierry Poibeau': [['thierry.poibeau@ens.fr', datetime.datetime(2018, 3, 5, 7, 56, 29, tzinfo=tzoffset(None, 3600)), datetime.datetime(2018, 3, 26, 9, 17, tzinfo=tzoffset(None, 7200))]], 'delegue.general@adbu.fr': [['delegue.general@adbu.fr', datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200)), datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200))]], 'Dominique Stutzmann': [['domini
#
# ['mehdi.khamassi@upmc.fr', 'dh@cru.fr', 'isabelle.thiebau@univ-lille2.fr', 'dh@groupes.renater.fr', 'colette.cadiou@irstea.fr', 'claire.clivaz@sib.swiss', 'johann.holland@campus-condorcet.fr', 'christine.michel@insa-lyon.fr', 'cerisier@univ-poitiers.fr', 'marjorie.burghart@ehess.fr', 'tei-fr@cru.fr', 'stephane.loret@univ-nantes.fr', 'quanti@groupes.renater.fr', 'rbdd@services.cnrs.fr', 'stephane.pouyllau@huma-num.fr', 'formation.continue@enc-sorbonne.fr', 'elenagonzalezblanco@yahoo.es', 'humanist@lists.digitalhumanities.org', 'globaloutlookdh-l@uleth.ca', 'digitalclassicist@jiscmail.ac.uk', 'dm-l@uleth.ca', 'dhd@mailman.rrz.uni-hamburg.de', 'aiucd-l@humnet.unipi.it', 'air-l@aoir.org', 'institute@lists.uvic.ca', 'tei-l@listserv.brown.edu', 'humanist-l@uleth.ca', 'centernet@lists.digitalhumanities.org', 'dhcarolina@listserv.unc.edu', 'humanidadesdigitais@gmail.com', 'website@hastac.org', 'southasia-dh@lists.globaloutlookdh.org', 'air-l@listserv.aoir.org', 'humanisticadh@gmail.com', 'caro

# %%
from datetime import timedelta
import datetime
# credentials
TOPOGRAM_URL = "http://localhost:3000"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
title = "DH_studies_map"
my_nodesdict = {}
my_nodes= []
my_edges = []


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'



###FOR NODES
print len(dict_noms_mails_debut_fin)
print dict_noms_mails_debut_fin['Claire Clivaz']
#claire.clivaz@unil.ch
# Out:
# 167
# [['claire.clivaz@unil.ch', datetime.datetime(2013, 7, 9, 15, 28, 26, tzinfo=tzoffset(None, 7200)), datetime.datetime(2014, 7, 12, 12, 31, 28, tzinfo=tzoffset(None, 7200))], ['claire.clivaz@sib.swiss', datetime.datetime(2016, 7, 20, 16, 54, 26, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 29, 13, 21, 16, tzinfo=tzoffset(None, 7200))]]

# %%
# Out:
# googlegroups.com
# lecnam.net
# jiscmail.ac.uk
# design.ulaval.ca
# imag.fr
# lists.globaloutlookdh.org
# dhi-paris.fr
# listserv.brown.edu
# services.cnrs.fr
# univ-paris3.fr
# unimes.fr
# design-fax.fr
# univ-lyon1.fr
# irht.cnrs.fr
# simone.univ-tlse2.fr
# uvsq.fr
# adbu.fr
# histographe.com
# univ-reims.fr
# upmc.fr
# cmb.hu-berlin.de
# gmail.com
# laposte.net
# dariah.eu
# huma-num.fr
# univ-lyon2.fr
# versailles.inra.fr
# mmsh.univ-aix.fr
# listes.univ-avignon.fr
# humnet.unipi.it
# me.com
# univ-lille2.fr
# cines.fr
# yahoo.fr
# uni.lu
# ens-lyon.fr
# listes.univ-rennes1.fr
# ahicf.com
# enssib.fr
# madics.fr
# univ-brest.fr
# lri.fr
# listserv.unc.edu
# inria.fr
# mailman.rrz.uni-hamburg.de
# univ-tours.fr
# univ-rouen.fr
# liste.unimes.fr
# icp.fr
# univ-paris1.fr
# yahoo.es
# univ-lyon3.fr
# lists.repec.org
# listes.univ-paris1.fr
# univ-grenoble-alpes.fr
# ec-nantes.fr
# uib.no
# univ-orleans.fr
# lsis.org
# club-internet.fr
# groupes.renater.fr
# aalto.fi
# cru.fr
# listes.irisa.fr
# listserv.aoir.org
# insa-lyon.fr
# parisdescartes.fr
# ml.free.fr
# hab.de
# listes.univ-lyon2.fr
# ish-lyon.cnrs.fr
# univ-montp3.fr
# bnf.fr
# parisnanterre.fr
# unil.ch
# cnam.fr
# irstea.fr
# univ-nantes.fr
# mac.com
# free.fr
# univ-lorraine.fr
# u-paris10.fr
# aoir.org
# sciencespo-lyon.fr
# wanadoo.fr
# eui.eu
# listes.univ-paris3.fr
# obspm.fr
# univ-lille3.fr
# rezo.net
# cnrs.fr
# ulb.ac.be
# hotmail.com
# openedition.org
# uleth.ca
# polytech.univ-nantes.fr
# helsinki.fi
# ina.fr
# lit.ulaval.ca
# ens.fr
# groups.openedition.org
# meshs.fr
# mines.org
# ephe.sorbonne.fr
# yahoogroupes.fr
# listserv.rediris.es
# lists.digitalhumanities.org
# campus-condorcet.fr
# mae.u-paris10.fr
# irit.fr
# listes.ancmsp.com
# univ-lehavre.fr
# oeaw.ac.at
# univ-pau.fr
# enc-sorbonne.fr
# hastac.org
# unilim.fr
# psl.eu
# cvce.eu
# clavert.net
# ehess.fr
# univ-rennes2.fr
# unistra.fr
# sciencespo.fr
# humanidadesdigitales.net
# googlemail.com
# infoclio.ch
# revues.org
# univ-poitiers.fr
# univ-avignon.fr
# listes.adbs.fr
# univ-amu.fr
# listes.insa-lyon.fr
# sib.swiss
# lists.uvic.ca
# listes.huma-num.fr
# mediev.unipi.it
# inha.fr

# %%
cnt=0
cnt_not_in_dict=0
for maill in liste_de_tous_les_mails:
    trouve=0
    #print maill
    for y in dict_noms_mails_debut_fin :
        for i,arr in enumerate(dict_noms_mails_debut_fin[y][0]):
            #rint "y", dict_noms_mails_debut_fin[y][0][i]
            if isinstance(dict_noms_mails_debut_fin[y][0][i], list) == True:
                print "!!!!!!list_in_arra",dict_noms_mails_debut_fin[y][0][i]
            else:
                if dict_noms_mails_debut_fin[y][0][i] == maill :
                        cnt+=1
                        trouve +=1


                        print "mail",maill.lower()
                        print "start",dict_noms_mails_debut_fin[y][0][i+1]
                        print "end",dict_noms_mails_debut_fin[y][0][i+2]
                        print "name",y.lower()



                        mail_address_suffix=dict_noms_mails_debut_fin[y][0][i].lower().split("@",1)[1]
                        print mail_address_suffix
                        lat=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lat"]
                        lng=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lng"]
                        print "lat/lng ",lat," ",lng
                        print "________________"

                        try: 
                #print start
                #print end
                            node = {
                            "id" : maill.lower(),
                            "name" : y.lower(),
                           "lat" : float(lat),
                           "lng" : float(lng),
                           "weight" : float(4),
                            #"start" : start.isoformat(),

                           #"end" : (end+timedelta(days=1)).isoformat()
                            }
                        except AttributeError as e:
                            print "STARTSTART",start
                            #print datetime.datetime(start[:-5])
                            print e

                            node = {
                                        "id" : maill.lower(),
                                        "name" : y.lower(),
                                       "lat" : float(lat),
                                       "lng" : float(lng),
                                       "weight" : float(4),
                                        #"start" : datetime.datetime(2012, 3, 2, 15, 19, 10).isoformat(),

                                       #"end" : datetime.datetime(2018, 3, 2, 15, 19, 10).isoformat()
                                        }
                            print node
                        my_nodes.append({ "data" : node })   
                        my_nodesdict[node["id"]]= { "data" : node }
                    
    #SI LE MAIL N EST PAS DANS LE DICT DE NOMS(DONC QUE CE N EST PAS UN EXPEDITEUR)
    if trouve == 0:
        print "MAIL NOT IN NAME DICT: ", maill,"\n_________________"
        cnt_not_in_dict+=1
        mail_address_suffix=maill.lower().split("@",1)[1]
        print mail_address_suffix
        lat=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lat"]
        lng=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lng"]
        print "lat/lng ",lat," ",lng
        print "________________"
                    
        try: 
            #print start
            #print end
                        node = {
                        "id" : dict_noms_mails_debut_fin[y][0][i].lower(),
                        "name" : y.lower(),
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),
                        #"start" : start.isoformat(),

                       #"end" : (end+timedelta(days=1)).isoformat()
                        }
        except AttributeError as e:
                        print "STARTSTART",start
                        #print datetime.datetime(start[:-5])
                        print e

                        node = {
                                    "id" : maill.lower(),
                                    "name" : y.lower(),
                                   "lat" : float(lat),
                                   "lng" : float(lng),
                                   "weight" : float(4),
                                    #"start" : datetime.datetime(2012, 3, 2, 15, 19, 10).isoformat(),

                                   #"end" : datetime.datetime(2018, 3, 2, 15, 19, 10).isoformat()
                                    }
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
        print node,"\n----------------\n"

        
        
        
        
        
        
        
        
        
        
        
        
    
    
print len(my_nodesdict)
    
                    
                    
                    
                
print "<<<<<<<<<<<COUNT NODES>>>>>>>>>>>>>",cnt
print "<<<<<<COUNT NODES NOT IN DICT>>>>>>",cnt_not_in_dict
print "<<<<<<<<<TOTAL>>>>>>>",cnt_not_in_dict+cnt


    
print len(my_nodesdict)
# Out:
# mail mehdi.khamassi@upmc.fr
# start 2016-07-03 07:31:28+02:00
# end 2016-07-03 07:31:28+02:00
# name mehdi khamassi
# upmc.fr
# lat/lng  48.8471036   2.357499
# ________________
# MAIL NOT IN NAME DICT:  dh@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.8594257, 'lng': 2.3465053, 'id': 'dh@cru.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail isabelle.thiebau@univ-lille2.fr
# start 2016-07-06 18:52:24+02:00
# end 2016-07-20 00:00:32+02:00
# name isabelle.thiebau@univ-lille2.fr
# univ-lille2.fr
# lat/lng  50.63166   3.0751371
# ________________
# mail isabelle.thiebau@univ-lille2.fr
# start 2016-07-06 18:52:24+02:00
# end 2016-07-20 00:00:32+02:00
# name isabelle thiebau
# univ-lille2.fr
# lat/lng  50.63166   3.0751371
# ________________
# MAIL NOT IN NAME DICT:  dh@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'dh@groupes.renater.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail colette.cadiou@irstea.fr
# start 2016-07-20 11:48:26+02:00
# end 2016-07-20 11:48:26+02:00
# name cadiou colette
# irstea.fr
# lat/lng  45.7627097   3.1110909
# ________________
# MAIL NOT IN NAME DICT:  claire.clivaz@sib.swiss
# _________________
# sib.swiss
# lat/lng  46.1935442   6.1489695
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 46.1935442, 'lng': 6.1489695, 'id': 'claire.clivaz@sib.swiss', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail johann.holland@campus-condorcet.fr
# start 2014-07-06 14:32:27+02:00
# end 2016-07-19 10:46:36+02:00
# name johann holland
# campus-condorcet.fr
# lat/lng  48.9081455   2.3665891
# ________________
# MAIL NOT IN NAME DICT:  christine.michel@insa-lyon.fr
# _________________
# insa-lyon.fr
# lat/lng  45.782938   4.878273
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45.782938, 'lng': 4.878273, 'id': 'christine.michel@insa-lyon.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  cerisier@univ-poitiers.fr
# _________________
# univ-poitiers.fr
# lat/lng  46.5859908   0.3460479
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 46.5859908, 'lng': 0.3460479, 'id': 'cerisier@univ-poitiers.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail marjorie.burghart@ehess.fr
# start 2013-07-05 01:35:31+02:00
# end 2018-03-09 13:52:33+01:00
# name burghart marjorie
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# mail marjorie.burghart@ehess.fr
# start 2013-07-05 01:35:31+02:00
# end 2018-03-09 13:52:33+01:00
# name marjorie burghart
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# MAIL NOT IN NAME DICT:  tei-fr@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.8594257, 'lng': 2.3465053, 'id': 'tei-fr@cru.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail stephane.loret@univ-nantes.fr
# start 2015-07-10 10:55:45+02:00
# end 2017-06-08 15:40:03+02:00
# name stéphane loret
# univ-nantes.fr
# lat/lng  47.2095499   -1.5559718
# ________________
# MAIL NOT IN NAME DICT:  quanti@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'quanti@groupes.renater.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  rbdd@services.cnrs.fr
# _________________
# services.cnrs.fr
# lat/lng  45.203453   5.700236
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45.203453, 'lng': 5.700235999999999, 'id': 'rbdd@services.cnrs.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  stephane.pouyllau@huma-num.fr
# _________________
# huma-num.fr
# lat/lng  48.850142   2.3269827
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.850142, 'lng': 2.3269827, 'id': 'stephane.pouyllau@huma-num.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail formation.continue@enc-sorbonne.fr
# start 2016-07-05 15:46:59+02:00
# end 2016-07-05 15:46:59+02:00
# name formation continue enc
# enc-sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# mail elenagonzalezblanco@yahoo.es
# start 2015-07-07 23:20:18+00:00
# end 2016-07-18 00:53:35+00:00
# name elena gonzález-blanco
# yahoo.es
# lat/lng  43.8424986   4.354806
# ________________
# MAIL NOT IN NAME DICT:  humanist@lists.digitalhumanities.org
# _________________
# lists.digitalhumanities.org
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'humanist@lists.digitalhumanities.org', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  globaloutlookdh-l@uleth.ca
# _________________
# uleth.ca
# lat/lng  49.6786156   -112.8601177
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 49.6786156, 'lng': -112.8601177, 'id': 'globaloutlookdh-l@uleth.ca', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  digitalclassicist@jiscmail.ac.uk
# _________________
# jiscmail.ac.uk
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'digitalclassicist@jiscmail.ac.uk', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  dm-l@uleth.ca
# _________________
# uleth.ca
# lat/lng  49.6786156   -112.8601177
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 49.6786156, 'lng': -112.8601177, 'id': 'dm-l@uleth.ca', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  dhd@mailman.rrz.uni-hamburg.de
# _________________
# mailman.rrz.uni-hamburg.de
# lat/lng  53.5696044   9.9865943
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 53.5696044, 'lng': 9.986594300000002, 'id': 'dhd@mailman.rrz.uni-hamburg.de', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  aiucd-l@humnet.unipi.it
# _________________
# humnet.unipi.it
# lat/lng  43.7167235   10.3988593
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# mail aurelien.berra@gmail.com
# start 2013-07-05 14:14:20+02:00
# end 2018-03-23 09:48:03+01:00
# name aurélien berra
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# mail antoine.courtin@mac.com
# start 2013-07-12 20:19:16+02:00
# end 2017-06-09 22:38:49+02:00
# name antoine courtin
# mac.com
# lat/lng  37.3316756   -122.030189
# ________________
# mail m.bourgatte@icp.fr
# start 2016-07-19 14:37:11+02:00
# end 2016-07-19 14:37:11+02:00
# name michael bourgatte
# icp.fr
# lat/lng  48.8480625   2.3300993
# ________________
# mail aude.da-cruz-lima@mae.u-paris10.fr
# start 2016-07-28 09:38:17+02:00
# end 2016-07-28 09:38:17+02:00
# name aude.da-cruz-lima
# mae.u-paris10.fr
# lat/lng  48.9041663   2.2098627
# ________________
# MAIL NOT IN NAME DICT:  archives-son-audiovisuel@groups.openedition.org
# _________________
# groups.openedition.org
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'archives-son-audiovisuel@groups.openedition.org', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail fatihaidmhand@yahoo.es
# start 2016-07-19 09:59:52+00:00
# end 2016-07-19 09:59:52+00:00
# name fatiha idmhand
# yahoo.es
# lat/lng  43.8424986   4.354806
# ________________
# mail emilien.ruiz@ehess.fr
# start 2012-07-02 14:47:31+02:00
# end 2012-07-02 14:47:31+02:00
# name emilien ruiz
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# mail marin.dacos@openedition.org
# start 2012-07-16 15:51:56+02:00
# end 2013-07-08 00:16:37+02:00
# name marin dacos
# openedition.org
# lat/lng  43.8424986   4.354806
# ________________
# mail enrico.natale@infoclio.ch
# start 2012-07-10 14:08:20+02:00
# end 2015-07-08 15:08:24+02:00
# name enrico natale
# infoclio.ch
# lat/lng  43.8424986   4.354806
# ________________
# mail aamonnz@gmail.com
# start 2012-07-17 07:17:09+02:00
# end 2014-07-10 05:14:24+02:00
# name alexandre monnin
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# MAIL NOT IN NAME DICT:  frederic@clavert.net
# _________________
# clavert.net
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'frederic@clavert.net', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail slh@ens-lyon.fr
# start 2012-07-26 21:21:27+02:00
# end 2018-03-15 11:33:42+01:00
# name serge heiden
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# mail dominique.stutzmann@irht.cnrs.fr
# start 2012-07-02 08:25:19+02:00
# end 2017-06-27 14:18:48+02:00
# name dominique stutzmann
# irht.cnrs.fr
# lat/lng  48.8664818   2.2954043
# ________________
# mail anne-laure.brisac@inha.fr
# start  Fri, 13 Jul 2012 09:56:18 +0100
# end  Fri, 13 Jul 2012 09:56:18 +0100
# name anne-laure brisac-chraïbi
# inha.fr
# lat/lng  48.8663364   2.3388561
# ________________
# mail jf.omhover@histographe.com
# start 2012-07-24 17:45:29+02:00
# end 2012-07-24 17:45:29+02:00
# name jf.omhover@histographe.com
# histographe.com
# lat/lng  43.8424986   4.354806
# ________________
# mail stefanev@club-internet.fr
# start 2012-07-26 18:39:41+02:00
# end 2012-07-26 18:39:41+02:00
# name stefanev
# club-internet.fr
# lat/lng  48.8961335   2.3812061
# ________________
# MAIL NOT IN NAME DICT:  marin.dacos@revues.org
# _________________
# revues.org
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'marin.dacos@revues.org', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  serge.noiret@eui.eu
# _________________
# eui.eu
# lat/lng  43.803079   11.282959
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# mail eric.kergosien@univ-lille3.fr
# start 2017-06-17 13:52:49+02:00
# end 2018-03-12 15:18:57+01:00
# name ekergosien
# univ-lille3.fr
# lat/lng  50.627577   3.126726
# ________________
# MAIL NOT IN NAME DICT:  liste-egc@polytech.univ-nantes.fr
# _________________
# polytech.univ-nantes.fr
# lat/lng  47.2820804   -1.5160328
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 47.2820804, 'lng': -1.5160328, 'id': 'liste-egc@polytech.univ-nantes.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  info-ic@listes.irisa.fr
# _________________
# listes.irisa.fr
# lat/lng  48.1163181   -1.6397024
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.1163181, 'lng': -1.6397024, 'id': 'info-ic@listes.irisa.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  magis@imag.fr
# _________________
# imag.fr
# lat/lng  45.1905967   5.767242
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45.1905967, 'lng': 5.767242, 'id': 'magis@imag.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  bull-i3@irit.fr
# _________________
# irit.fr
# lat/lng  43.5617391   1.4680172
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.5617391, 'lng': 1.4680172, 'id': 'bull-i3@irit.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  ln@cines.fr
# _________________
# cines.fr
# lat/lng  43.6362031   3.8418738
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.6362031, 'lng': 3.8418738, 'id': 'ln@cines.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  liste-proml@lri.fr
# _________________
# lri.fr
# lat/lng  48.7124995   2.1682591
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.7124995, 'lng': 2.1682591, 'id': 'liste-proml@lri.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  docs-ri@yahoogroupes.fr
# _________________
# yahoogroupes.fr
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'docs-ri@yahoogroupes.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail marie-laure.massot@ens.fr
# start 2017-06-26 16:30:12+02:00
# end 2018-03-15 14:40:57+01:00
# name marie-laure massot
# ens.fr
# lat/lng  48.8422058   2.3451689
# ________________
# mail gpansu@gmail.com
# start 2017-06-09 16:32:46+02:00
# end 2017-06-09 16:32:46+02:00
# name gilles pansu
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# mail francois.theron@uvsq.fr
# start 2017-06-02 12:36:14+02:00
# end 2017-06-02 12:36:14+02:00
# name françois théron
# uvsq.fr
# lat/lng  48.799627   2.1415644
# ________________
# MAIL NOT IN NAME DICT:  humanum-diffusion@listes.huma-num.fr
# _________________
# listes.huma-num.fr
# lat/lng  48.850142   2.3269827
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.850142, 'lng': 2.3269827, 'id': 'humanum-diffusion@listes.huma-num.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  humanum-veille@listes.huma-num.fr
# _________________
# listes.huma-num.fr
# lat/lng  48.850142   2.3269827
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.850142, 'lng': 2.3269827, 'id': 'humanum-veille@listes.huma-num.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  eveline.wandl-vogt@oeaw.ac.at
# _________________
# oeaw.ac.at
# lat/lng  48.2088405   16.3771845
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.2088405, 'lng': 16.3771845, 'id': 'eveline.wandl-vogt@oeaw.ac.at', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  ahdig@googlegroups.com
# _________________
# googlegroups.com
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'ahdig@googlegroups.com', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  textualscholarship@jiscmail.ac.uk
# _________________
# jiscmail.ac.uk
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'textualscholarship@jiscmail.ac.uk', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail francoise.paquienseguy@sciencespo-lyon.fr
# start 2017-06-09 08:05:48+00:00
# end 2017-06-16 18:12:58+00:00
# name paquien-séguy françoise
# sciencespo-lyon.fr
# lat/lng  45.7470623   4.8357091
# ________________
# mail vanessa.juloux@ephe.sorbonne.fr
# start 2017-06-01 18:59:10+00:00
# end 2017-06-01 18:59:10+00:00
# name vanessa juloux
# ephe.sorbonne.fr
# lat/lng  48.8483803   2.3434592
# ________________
# MAIL NOT IN NAME DICT:  ontologie-patrimoine@services.cnrs.fr
# _________________
# services.cnrs.fr
# lat/lng  45.203453   5.700236
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# mail pierazzo@gmail.com
# start 2018-03-20 12:33:07+01:00
# end 2018-03-20 12:33:07+01:00
# name elena pierazzo
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# mail clemence.jacquot@gmail.com
# start 2018-03-12 15:15:16+01:00
# end 2018-03-12 15:15:16+01:00
# name clémence jacquot
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# MAIL NOT IN NAME DICT:  sclerisse@parisnanterre.fr
# _________________
# parisnanterre.fr
# lat/lng  48.903399   2.211274
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.90339900000001, 'lng': 2.211274, 'id': 'sclerisse@parisnanterre.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  listesocius@groups.openedition.org
# _________________
# groups.openedition.org
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'listesocius@groups.openedition.org', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  digit_hum@ens.fr
# _________________
# ens.fr
# lat/lng  48.8422058   2.3451689
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 48.8422058, 'lng': 2.3451689, 'id': 'digit_hum@ens.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail florence.clavaud@free.fr
# start 2018-03-02 15:36:05+01:00
# end 2018-03-02 15:36:05+01:00
# name florence.clavaud@free.fr
# free.fr
# lat/lng  46.8051945   1.6860012
# ________________
# mail amel.fraisse@univ-lille3.fr
# start 2018-03-06 14:57:59+01:00
# end 2018-03-06 14:57:59+01:00
# name amel fraisse
# univ-lille3.fr
# lat/lng  50.627577   3.126726
# ________________
# MAIL NOT IN NAME DICT:  jouni.tuominen@aalto.fi
# _________________
# aalto.fi
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'jouni.tuominen@aalto.fi', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail georges-xavier.blary@unilim.fr
# start 2018-03-12 11:00:23+01:00
# end 2018-03-12 11:00:23+01:00
# name georges-xavier blary
# unilim.fr
# lat/lng  45.826307   1.258409
# ________________
# MAIL NOT IN NAME DICT:  rene.audet@lit.ulaval.ca
# _________________
# lit.ulaval.ca
# lat/lng  46.7817463   -71.2747424
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 46.78174629999999, 'lng': -71.2747424, 'id': 'rene.audet@lit.ulaval.ca', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail jakob.epler@dariah.eu
# start 2018-03-14 14:36:16+00:00
# end 2018-03-14 14:36:16+00:00
# name epler, jakob
# dariah.eu
# lat/lng  50.5546212   6.7628843
# ________________
# mail jerome.darmont@univ-lyon2.fr
# start 2018-03-09 11:17:31+01:00
# end 2018-03-09 11:17:31+01:00
# name jérôme darmont
# univ-lyon2.fr
# lat/lng  45.7507518   4.8371866
# ________________
# MAIL NOT IN NAME DICT:  madics-adoc@listes.univ-lyon2.fr
# _________________
# listes.univ-lyon2.fr
# lat/lng  45.7507518   4.8371866
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45.7507518, 'lng': 4.8371866, 'id': 'madics-adoc@listes.univ-lyon2.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  annonces@madics.fr
# _________________
# madics.fr
# lat/lng  42.3919145   -71.1521088
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 42.3919145, 'lng': -71.1521088, 'id': 'annonces@madics.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  fil-tmd@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'fil-tmd@groupes.renater.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  eda-liste@listes.univ-lyon2.fr
# _________________
# listes.univ-lyon2.fr
# lat/lng  45.7507518   4.8371866
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45.7507518, 'lng': 4.8371866, 'id': 'eda-liste@listes.univ-lyon2.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  gazettebd3@imag.fr
# _________________
# imag.fr
# lat/lng  45.1905967   5.767242
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 45.1905967, 'lng': 5.767242, 'id': 'gazettebd3@imag.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# m
fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail marie-noelle.polino@ahicf.com
# start 2015-07-02 14:10:25+02:00
# end 2015-07-02 14:10:25+02:00
# name marie-noelle.polino@ahicf.com
# ahicf.com
# lat/lng  43.8424986   4.354806
# ________________
# mail clarisse_bardiot@me.com
# start 2015-07-09 14:46:14+02:00
# end 2015-07-09 14:46:14+02:00
# name clarisse bardiot
# me.com
# lat/lng  37.3316756   -122.030189
# ________________
# mail christine.chadier@univ-lyon3.fr
# start 2015-07-30 09:52:01+00:00
# end 2015-07-30 09:59:31+00:00
# name chadier christine
# univ-lyon3.fr
# lat/lng  45.748149   4.860553
# ________________
# mail valerie.beaugiraud@ens-lyon.fr
# start 2015-07-09 11:42:23+02:00
# end 2015-07-09 11:42:23+02:00
# name valérie beaugiraud
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# mail laurens@ehess.fr
# start 2015-07-09 11:45:25+02:00
# end 2015-07-09 11:45:25+02:00
# name sylvain laurens
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# MAIL NOT IN NAME DICT:  iwetel@listserv.rediris.es
# _________________
# listserv.rediris.es
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'iwetel@listserv.rediris.es', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  infoling@listserv.rediris.es
# _________________
# listserv.rediris.es
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'infoling@listserv.rediris.es', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  redhd@humanidadesdigitales.net
# _________________
# humanidadesdigitales.net
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'redhd@humanidadesdigitales.net', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail spadinielena@gmail.com
# start 2015-07-16 12:16:27+02:00
# end 2015-07-16 12:16:27+02:00
# name elena spadini
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# mail hdefouca@u-paris10.fr
# start 2015-07-08 16:44:49+02:00
# end 2015-07-08 16:44:49+02:00
# name hélène de foucaud
# u-paris10.fr
# lat/lng  48.903399   2.211274
# ________________
# MAIL NOT IN NAME DICT:  olivier.marlet@univ-tours.fr
# _________________
# univ-tours.fr
# lat/lng  47.3838055   0.6738728
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 47.3838055, 'lng': 0.6738727999999999, 'id': 'olivier.marlet@univ-tours.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail emmanuelle.morlock@gmail.com
# start 2015-07-11 19:24:29+02:00
# end 2015-07-11 19:24:29+02:00
# name emmanuelle morlock
# gmail.com
# lat/lng  43.8424986   4.354806
# ________________
# MAIL NOT IN NAME DICT:  cahier@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  43.8424986   4.354806
# ________________
# STARTSTART 2011-07-18 11:01:00+02:00
# 'datetime.datetime' object has no attribute 'lower'
# {'lat': 43.8424986, 'lng': 4.354806, 'id': 'cahier@groupes.renater.fr', 'weight': 4.0, 'name': 'marionlame@gmail.com'}
# ----------------
#
# mail audrey.baneyx@sciencespo.fr
# start 2015-07-27 14:16:20+02:00
# end 2015-07-27 14:16:20+02:00
# name audrey baneyx - sciences po
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# 290
# <<<<<<<<<<<COUNT NODES>>>>>>>>>>>>> 155
# <<<<<<COUNT NODES NOT IN DICT>>>>>> 126
# <<<<<<<<<TOTAL>>>>>>> 281
# 290

# %%
print len(my_nodesdict)
# Out:
# 290

# %%
import random
def my_edges_list_singled() :
    my_edges=[]
    extra_nodes_non_autor_list=[]
    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                if maild not in dict_noms_mails_debut_fin:
                    if maild not in extra_nodes_non_autor_list:
                        print "OHOH NO, NO maild in liste_mail", maild
                        extra_nodes_non_autor_list.append(maild)
                        print corpus_mails_DH[mail]["sujet_du_message"]
                        if "sujet_du_message" in corpus_mails_DH[mail]:
                            edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"],
                        "target" : maild,
                        "weight" : float(2),
                        "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                    }
                        else:
                            edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"],
                        "target" : maild,
                        "weight" : float(2),
                       
                    }
                            
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            if maild not in dict_noms_mails_debut_fin:
                    if maild not in extra_nodes_non_autor_list:
                        #print "OHOH NO, NO maild in liste_mail", maild
                        extra_nodes_non_autor_list.append(maild)
            
                        if "sujet_du_message" in corpus_mails_DH[mail]:
                            edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"],
                        "target" : maild,
                        "weight" : float(2),
                        "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                    }
                        else:
                            edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"],
                        "target" : maild,
                        "weight" : float(2),
                       
                    }
            
            my_edges.append({ "data" : edge })



    #print len(my_edges)
    #print extra_nodes_non_autor_list
    #print len(extra_nodes_non_autor_list)
    return [my_edges,extra_nodes_non_autor_list]

my_edges_singled=my_edges_list_singled()[0]
extra_nodes=my_edges_list_singled()[1]
# Out:
# OHOH NO, NO maild in liste_mail marjorie.burghart@ehess.fr
# : [dh] recherche reproductible et dh (was: collo que sur les digital humanities : appel à contribution )
# OHOH NO, NO maild in liste_mail jean-daniel.fekete@inria.fr
# : [dh] recherche reproductible et dh (was: collo que sur les digital humanities : appel à contribution )
# OHOH NO, NO maild in liste_mail claire.clivaz@unil.ch
# : re: [dh] thatcamp saint-malo - association francophone des digital humanities
# OHOH NO, NO maild in liste_mail frederic@clavert.net
# : re: [dh] thatcamp saint-malo - association francophone des digital humanities
# OHOH NO, NO maild in liste_mail francesca.frontini@univ-montp3.fr
# : [dh] second cfp: workshop on language, ontology, terminology and knowledge structures (lotks - 2017)
# OHOH NO, NO maild in liste_mail humanum-veille@listes.huma-num.fr
# : [dh] fwd: comité programme semweb.pro 2017
# OHOH NO, NO maild in liste_mail thibault.clerice@enc-sorbonne.fr
# : [dh] candidatures aux masters humanités numériques et recherche et technologies numériques appliquées à l'histoire
# OHOH NO, NO maild in liste_mail lisa.chupin@gmail.com
# : re: [dh] question ocr
# OHOH NO, NO maild in liste_mail helene.coste@univ-lehavre.fr
# : [dh] urgent - recherche personne pour animation d'atelier datavisualisation / adbu bibliovizz
# OHOH NO, NO maild in liste_mail valerie.neouze@parisdescartes.fr
# : [dh] urgent - recherche personne pour animation d'atelier datavisualisation / adbu bibliovizz
# OHOH NO, NO maild in liste_mail gregory.grefenstette@inria.fr
# : [dh] computational linguistics; semantics: post doc, inria, palaiseau, near paris, france
# OHOH NO, NO maild in liste_mail martaseve@gmail.com
# : [dh] appel à communications : luttes de territoire et représentations sociales - rouen, 22-23 mars 2018
# OHOH NO, NO maild in liste_mail christine.benevent@univ-tours.fr
# : [dh] il reste encore quelques places dans une form ation de master aux humanités numériques
# OHOH NO, NO maild in liste_mail laurent.gerbier@univ-tours.fr
# : [dh] il reste encore quelques places dans une form ation de master aux humanités numériques
# OHOH NO, NO maild in liste_mail sandrine.breuil@univ-tours.fr
# : [dh] il reste encore quelques places dans une form ation de master aux humanités numériques
# OHOH NO, NO maild in liste_mail julia.bonaccorsi@univ-lyon2.fr
# : re: [dh] labos dh
# OHOH NO, NO maild in liste_mail sabine.loudcher@univ-lyon2.fr
# : re: [dh] labos dh
# OHOH NO, NO maild in liste_mail sarah.cordonnier@gmail.com
# : re: [dh] labos dh
# OHOH NO, NO maild in liste_mail aurelie.olivesi@univ-lyon1.fr
# : [dh] appel à contributions - journées d ’études " ancrer le discours sur le genre : co mmentaires en ligne et fouille d'opinion" -  lyon 1  – 27/28 novembre 2014
# OHOH NO, NO maild in liste_mail huyghe.marie@gmail.com
# : [dh] recrutement ingénieur d'études - octobre 2016
# OHOH NO, NO maild in liste_mail laurent.cailly@univ-tours.fr
# : [dh] recrutement ingénieur d'études - octobre 2016
# OHOH NO, NO maild in liste_mail marie-laure.massot@ens.fr
# : [dh] atelier digit_hum 2017 "data deluge quelles compétences pour quelles données ?" : 5 octobre 2017, ens paris
# OHOH NO, NO maild in liste_mail llist@unil.ch
# : [dh] cfp: workshop on computational methods in the humanities 2018 (comhum 2018)
# OHOH NO, NO maild in liste_mail dh-request@groupes.renater.fr
# : re: [dh] un atelier de prosopographie
# OHOH NO, NO maild in liste_mail cerisier@univ-poitiers.fr
# : [dh] appel à contributions - atelier "evolution des méthodes et pratiques d’analyse des usages pour les dispositifs d’apprentissage complexes" lors des orphee-rdv
# OHOH NO, NO maild in liste_mail tei-fr@cru.fr
# : re: [dh] last chance de s'enregistrer pour une formation tei unique !
# OHOH NO, NO maild in liste_mail olivier.marlet@univ-tours.fr
# : [dh] journées « ontologie en sciences humaines et sociales » - du 9 au 10 novembre 2015 - tours
# OHOH NO, NO maild in liste_mail digit_hum@ens.fr
# : [dh] ouverture du site digit_hum
# OHOH NO, NO maild in liste_mail fil-tmd@groupes.renater.fr
# : [dh] appel à contributions : journée "variété des données shs"
# OHOH NO, NO maild in liste_mail eda-liste@listes.univ-lyon2.fr
# : [dh] appel à contributions : journée "variété des données shs"
# OHOH NO, NO maild in liste_mail gazettebd3@imag.fr
# : [dh] appel à contributions : journée "variété des données shs"
# OHOH NO, NO maild in liste_mail marjorie.burghart@ehess.fr
# : [dh] recherche reproductible et dh (was: collo que sur les digital humanities : appel à contribution )
# OHOH NO, NO maild in liste_mail jean-daniel.fekete@inria.fr
# : [dh] recherche reproductible et dh (was: collo que sur les digital humanities : appel à contribution )
# OHOH NO, NO maild in liste_mail claire.clivaz@unil.ch
# : re: [dh] thatcamp saint-malo - association francophone des digital humanities
# OHOH NO, NO maild in liste_mail frederic@clavert.net
# : re: [dh] thatcamp saint-malo - association francophone des digital humanities
# OHOH NO, NO maild in liste_mail francesca.frontini@univ-montp3.fr
# : [dh] second cfp: workshop on language, ontology, terminology and knowledge structures (lotks - 2017)
# OHOH NO, NO maild in liste_mail humanum-veille@listes.huma-num.fr
# : [dh] fwd: comité programme semweb.pro 2017
# OHOH NO, NO maild in liste_mail thibault.clerice@enc-sorbonne.fr
# : [dh] candidatures aux masters humanités numériques et recherche et technologies numériques appliquées à l'histoire
# OHOH NO, NO maild in liste_mail lisa.chupin@gmail.com
# : re: [dh] question ocr
# OHOH NO, NO maild in liste_mail helene.coste@univ-lehavre.fr
# : [dh] urgent - recherche personne pour animation d'atelier datavisualisation / adbu bibliovizz
# OHOH NO, NO maild in liste_mail valerie.neouze@parisdescartes.fr
# : [dh] urgent - recherche personne pour animation d'atelier datavisualisation / adbu bibliovizz
# OHOH NO, NO maild in liste_mail gregory.grefenstette@inria.fr
# : [dh] computational linguistics; semantics: post doc, inria, palaiseau, near paris, france
# OHOH NO, NO maild in liste_mail martaseve@gmail.com
# : [dh] appel à communications : luttes de territoire et représentations sociales - rouen, 22-23 mars 2018
# OHOH NO, NO maild in liste_mail christine.benevent@univ-tours.fr
# : [dh] il reste encore quelques places dans une form ation de master aux humanités numériques
# OHOH NO, NO maild in liste_mail laurent.gerbier@univ-tours.fr
# : [dh] il reste encore quelques places dans une form ation de master aux humanités numériques
# OHOH NO, NO maild in liste_mail sandrine.breuil@univ-tours.fr
# : [dh] il reste encore quelques places dans une form ation de master aux humanités numériques
# OHOH NO, NO maild in liste_mail julia.bonaccorsi@univ-lyon2.fr
# : re: [dh] labos dh
# OHOH NO, NO maild in liste_mail sabine.loudcher@univ-lyon2.fr
# : re: [dh] labos dh
# OHOH NO, NO maild in liste_mail sarah.cordonnier@gmail.com
# : re: [dh] labos dh
# OHOH NO, NO maild in liste_mail aurelie.olivesi@univ-lyon1.fr
# : [dh] appel à contributions - journées d ’études " ancrer le discours sur le genre : co mmentaires en ligne et fouille d'opinion" -  lyon 1  – 27/28 novembre 2014
# OHOH NO, NO maild in liste_mail huyghe.marie@gmail.com
# : [dh] recrutement ingénieur d'études - octobre 2016
# OHOH NO, NO maild in liste_mail laurent.cailly@univ-tours.fr
# : [dh] recrutement ingénieur d'études - octobre 2016
# OHOH NO, NO maild in liste_mail marie-laure.massot@ens.fr
# : [dh] atelier digit_hum 2017 "data deluge quelles compétences pour quelles données ?" : 5 octobre 2017, ens paris
# OHOH NO, NO maild in liste_mail llist@unil.ch
# : [dh] cfp: workshop on computational methods in the humanities 2018 (comhum 2018)
# OHOH NO, NO maild in liste_mail dh-request@groupes.renater.fr
# : re: [dh] un atelier de prosopographie
# OHOH NO, NO maild in liste_mail cerisier@univ-poitiers.fr
# : [dh] appel à contributions - atelier "evolution des méthodes et pratiques d’analyse des usages pour les dispositifs d’apprentissage complexes" lors des orphee-rdv
# OHOH NO, NO maild in liste_mail tei-fr@cru.fr
# : re: [dh] last chance de s'enregistrer pour une formation tei unique !
# OHOH NO, NO maild in liste_mail olivier.marlet@univ-tours.fr
# : [dh] journées « ontologie en sciences humaines et sociales » - du 9 au 10 novembre 2015 - tours
# OHOH NO, NO maild in liste_mail digit_hum@ens.fr
# : [dh] ouverture du site digit_hum
# OHOH NO, NO maild in liste_mail fil-tmd@groupes.renater.fr
# : [dh] appel à contributions : journée "variété des données shs"
# OHOH NO, NO maild in liste_mail eda-liste@listes.univ-lyon2.fr
# : [dh] appel à contributions : journée "variété des données shs"
# OHOH NO, NO maild in liste_mail gazettebd3@imag.fr
# : [dh] appel à contributions : journée "variété des données shs"

# %%
#print extra_nodes


for mail in extra_nodes:
    
        print mail
        
#        start= mail_array[1]
#        end= mail_array[2]
        mail_address_suffix=mail.split("@",1)[1]
        print mail_address_suffix
        if mail_address_suffix in dict_corrected_DH  :
            
            lat=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lat"]
            lng=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lng"]
            node = {
                        "id" : mail,
                        "name" : mail,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),

                        }
        else: 
            
        
            node = {
                        "id" : mail,
                        "name" : mail,
                       "weight" : float(4),
                        
                        }
        
            print node
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
    
print len(my_nodesdict)
# Out:
# dh@groupes.renater.fr
# groupes.renater.fr
# legram@yahoogroupes.fr
# yahoogroupes.fr
# culture.numerique@ml.free.fr
# ml.free.fr
# listesocius@groups.openedition.org
# groups.openedition.org
# stephane.pouyllau@cnrs.fr
# cnrs.fr
# exploreat@oeaw.ac.at
# oeaw.ac.at
# humanist@lists.digitalhumanities.org
# lists.digitalhumanities.org
# globaloutlookdh-l@uleth.ca
# uleth.ca
# digitalclassicist@jiscmail.ac.uk
# jiscmail.ac.uk
# dm-l@uleth.ca
# uleth.ca
# dhd@mailman.rrz.uni-hamburg.de
# mailman.rrz.uni-hamburg.de
# aiucd-l@humnet.unipi.it
# humnet.unipi.it
# air-l@aoir.org
# aoir.org
# institute@lists.uvic.ca
# lists.uvic.ca
# tei-l@listserv.brown.edu
# listserv.brown.edu
# humanist-l@uleth.ca
# uleth.ca
# centernet@lists.digitalhumanities.org
# lists.digitalhumanities.org
# dhcarolina@listserv.unc.edu
# listserv.unc.edu
# humanidadesdigitais@gmail.com
# gmail.com
# website@hastac.org
# hastac.org
# southasia-dh@lists.globaloutlookdh.org
# lists.globaloutlookdh.org
# air-l@listserv.aoir.org
# listserv.aoir.org
# humanisticadh@gmail.com
# gmail.com
# marjorie.burghart@ehess.fr
# ehess.fr
# jean-daniel.fekete@inria.fr
# inria.fr
# nicole.dufournaud@laposte.net
# laposte.net
# claire.clivaz@unil.ch
# unil.ch
# frederic@clavert.net
# clavert.net
# pierre.mounier@openedition.org
# openedition.org
# archives-son-audiovisuel@groups.openedition.org
# groups.openedition.org
# alexandre.hocquet@univ-lorraine.fr
# univ-lorraine.fr
# francesca.frontini@univ-montp3.fr
# univ-montp3.fr
# liste-egc@polytech.univ-nantes.fr
# polytech.univ-nantes.fr
# bull-i3@irit.fr
# irit.fr
# info-ic@listes.irisa.fr
# listes.irisa.fr
# ln@cines.fr
# cines.fr
# humanum-veille@listes.huma-num.fr
# listes.huma-num.fr
# humanum-diffusion@listes.huma-num.fr
# listes.huma-num.fr
# thibault.clerice@enc-sorbonne.fr
# enc-sorbonne.fr
# adherents-aipu-fr@groupes.renater.fr
# groupes.renater.fr
# afec-info@groupes.renater.fr
# groupes.renater.fr
# anstia-adherents@groupes.renater.fr
# groupes.renater.fr
# debuter-en-dh@groupes.renater.fr
# groupes.renater.fr
# emploi-fle@groupes.renater.fr
# groupes.renater.fr
# histoire_eco-request@groupes.renater.fr
# groupes.renater.fr
# athena@services.cnrs.fr
# services.cnrs.fr
# valerie.beaugiraud@ens-lyon.fr
# ens-lyon.fr
# digit_hum@ens.fr
# ens.fr
# corpora@uib.no
# uib.no
# saes@univ-pau.fr
# univ-pau.fr
# alaes_liste@yahoogroupes.fr
# yahoogroupes.fr
# parislinguists@yahoogroupes.fr
# yahoogroupes.fr
# agorantic@listes.univ-avignon.fr
# listes.univ-avignon.fr
# iwetel@listserv.rediris.es
# listserv.rediris.es
# infoling@listserv.rediris.es
# listserv.rediris.es
# redhd@humanidadesdigitales.net
# humanidadesdigitales.net
# fil-tmd@groupes.renater.fr
# groupes.renater.fr
# eda-liste@listes.univ-lyon2.fr
# listes.univ-lyon2.fr
# gazettebd3@imag.fr
# imag.fr
# madics-adoc@listes.univ-lyon2.fr
# listes.univ-lyon2.fr
# annonces@madics.fr
# madics.fr
# viera.rebolledodhuin@free.fr
# free.fr
# adbs-info@listes.adbs.fr
# listes.adbs.fr
# accesouvert@groupes.renater.fr
# groupes.renater.fr
# doccitanist@services.cnrs.fr
# services.cnrs.fr
# info-aria@lsis.org
# lsis.org
# 290

# %%
my_edges=my_edges_singled
print len(my_edges)
print my_edges
# Out:
# 526
# [{'data': {'source': 'jorge.fins@univ-tours.fr', 'name': u': re: [dh] prestation de d\xe9veloppement sous drupal', 'id': u'./DHFRsample/2017-06/msg00011.html jorge.fins@univ-tours.frdh@groupes.renater.fr0.767090015678', 'weight': 2.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [dh] conf\xe9rence de marcello vitali-rosati [s\xe9minaire ephn]', 'id': u'./DHFRsample/2018-03/msg00011.html dumouchelsuzanne@yahoo.frlegram@yahoogroupes.fr0.792815403509', 'weight': 2.0, 'target': 'legram@yahoogroupes.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [dh] conf\xe9rence de marcello vitali-rosati [s\xe9minaire ephn]', 'id': u'./DHFRsample/2018-03/msg00011.html dumouchelsuzanne@yahoo.frculture.numerique@ml.free.fr0.0651368516258', 'weight': 2.0, 'target': 'culture.numerique@ml.free.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [dh] conf\xe9rence de marcello vitali-rosati [s\xe9minaire ephn]', 'id': u'./DHFRsample/2018-03/msg00011.html dumouchelsuzanne@yahoo.frculture.numerique@ml.free.fr0.0651368516258', 'weight': 2.0, 'target': 'culture.numerique@ml.free.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [dh] conf\xe9rence de marcello vitali-rosati [s\xe9minaire ephn]', 'id': u'./DHFRsample/2018-03/msg00011.html dumouchelsuzanne@yahoo.frlistesocius@groups.openedition.org0.357212403736', 'weight': 2.0, 'target': 'listesocius@groups.openedition.org'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [dh] conf\xe9rence de marcello vitali-rosati [s\xe9minaire ephn]', 'id': u'./DHFRsample/2018-03/msg00011.html dumouchelsuzanne@yahoo.frlistesocius@groups.openedition.org0.357212403736', 'weight': 2.0, 'target': 'listesocius@groups.openedition.org'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [dh] conf\xe9rence de marcello vitali-rosati [s\xe9minaire ephn]', 'id': u'./DHFRsample/2018-03/msg00011.html dumouchelsuzanne@yahoo.frlistesocius@groups.openedition.org0.357212403736', 'weight': 2.0, 'target': 'listesocius@groups.openedition.org'}}, {'data': {'source': 'pierre.mounier@ehess.fr', 'name': u': re: [dh] yes we digital ! young researchers in digital humanities : a manifesto', 'id': u'./DHFRsample/2013-07/msg00006.html pierre.mounier@ehess.frstephane.pouyllau@cnrs.fr0.0824094946453', 'weight': 2.0, 'target': 'stephane.pouyllau@cnrs.fr'}}, {'data': {'source': 'pierre.mounier@ehess.fr', 'name': u': re: [dh] yes we digital ! young researchers in digital humanities : a manifesto', 'id': u'./DHFRsample/2013-07/msg00006.html pierre.mounier@ehess.frstephane.pouyllau@cnrs.fr0.0824094946453', 'weight': 2.0, 'target': 'stephane.pouyllau@cnrs.fr'}}, {'data': {'source': 'pierre.mounier@ehess.fr', 'name': u': re: [dh] yes we digital ! young researchers in digital humanities : a manifesto', 'id': u'./DHFRsample/2013-07/msg00006.html pierre.mounier@ehess.frstephane.pouyllau@cnrs.fr0.0824094946453', 'weight': 2.0, 'target': 'stephane.pouyllau@cnrs.fr'}}, {'data': {'source': 'eveline.wandl-vogt@oeaw.ac.at', 'name': u': [dh] exploreat! job offer @ vienna: citizen science & diy science; cultural lexicographer', 'id': u'./DHFRsample/2017-06/msg00057.html eveline.wandl-vogt@oeaw.ac.atexploreat@oeaw.ac.at0.379416538706', 'weight': 2.0, 'target': 'exploreat@oeaw.ac.at'}}, {'data': {'source': 'eveline.wandl-vogt@oeaw.ac.at', 'name': u': [dh] exploreat! job offer @ vienna: citizen science & diy science; cultural lexicographer', 'id': u'./DHFRsample/2017-06/msg00057.html eveline.wandl-vogt@oeaw.ac.atexploreat@oeaw.ac.at0.379416538706', 'weight': 2.0, 'target': 'exploreat@oeaw.ac.at'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [dh] post-doctoral 4 years dh position in madrid at linhd-uned', 'id': u'./DHFRsample/2016-07/msg00016.html elenagonzalezblanco@yahoo.eshumanist@lists.digitalhumanities.org0.92849229006', 'weight': 2.0, 'target': 'humanist@lists.digitalhumanities.org'}}, {'data': {'source': 'elenagonza ...

# %%
def my_edges_list_by_source_dest() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    "weight" : float(2),
                    #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])+" "+
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(5),
                #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)
    return my_edges

my_edges_duped=my_edges_list_by_source_dest()
# Out:
# 527

# %%
def my_edges_list_with_subject() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    #"weight" : float(2),
                    "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                #"weight" : float(5),
                "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)

    return my_edges

my_edges_duped_with_subject=my_edges_list_with_subject()
# Out:
# 527

# %%
#WE HAVE TO TEST THE EDGES, BUT IT IS AN ARRAY OF DICTS,SO WE NEED TO FLATTEN THEM TO COUNT THEM SIMPLY

import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
def list_flattener_and_finder(edges_list_singled,edges_list_duped):
    from collections import Counter
    import ast
    my_edges_replacement_deduped=[]
    receiver=[]
    for i,dic in enumerate(edges_list_duped):
        #print my_edges[i]
        dicto=flatten(edges_list_duped[i])
    #    print dicto
        receiver.append(str(dicto))

    #print receiver
    CREE= Counter(receiver).iteritems()
    total=0
    dups=0
    dups_cnt=0
    
    print edges_list_singled[:1]
    for key, value in CREE:
        #print key
        #print value
        keyB={'data':{}}
        total+=1
        
        #print ast.literal_eval(key)["data_source"]
        #print ast.literal_eval(key)["data_target"]        
        keyB={'data':{"source":ast.literal_eval(key)["data_source"],"target": ast.literal_eval(key)["data_target"]}}
        #print "SUP",key, value
        dups+=value
        dups_cnt+=1
        #print ">>",keyB
        #print ast.literal_eval(key)["data_weight"]    
        keyB["data"]["weight"]= float(value*float(ast.literal_eval(key)["data_weight"]))
        #print "KEYB____",keyB
        my_edges_replacement_deduped.append(keyB)


            





    print "total",total

    print "dups",dups
    print "dups_cnt",dups_cnt
    return my_edges_replacement_deduped

listor=list_flattener_and_finder(my_edges,my_edges_duped)
print listor
# Out:
# []
# total 368
# dups 527
# dups_cnt 368
# [{'data': {'source': 'e.salvatori@mediev.unipi.it', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'delegue.general@adbu.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'graham.ranger@univ-avignon.fr', 'target': 'parislinguists@yahoogroupes.fr', 'weight': 5.0}}, {'data': {'source': 'Guillaume.Blum@design.ulaval.ca', 'target': 'docs-ri@yahoogroupes.fr', 'weight': 5.0}}, {'data': {'source': 'jahjah.marc@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'gpansu@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'liste-proml@lri.fr', 'weight': 5.0}}, {'data': {'source': 'emmanuelle.morlock@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'claire.lemercier@sciencespo.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'yamina.bensaadoune@univ-rouen.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'aurelie.olivesi@wanadoo.fr', 'target': 'efigies-info@rezo.net', 'weight': 5.0}}, {'data': {'source': 'oledeuff@gmail.com', 'target': 'valerie.beaugiraud@ens-lyon.fr', 'weight': 5.0}}, {'data': {'source': 'jorge.fins@univ-tours.fr', 'target': 'dh@groupes.renater.fr', 'weight': 10.0}}, {'data': {'source': 'jbcamps@hotmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'enrico.natale@infoclio.ch', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'pe.barrault@gmail.com', 'target': 'emmanuelle.duwez@sciencespo.fr', 'weight': 5.0}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'target': 'air-l@listserv.aoir.org', 'weight': 5.0}}, {'data': {'source': 'michel.bernard@univ-paris3.fr', 'target': 'litor@listes.univ-paris3.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'docs-ri@yahoogroupes.fr', 'weight': 10.0}}, {'data': {'source': 'marionlame@gmail.com', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'target': 'air-l@listserv.aoir.org', 'weight': 5.0}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'target': 'humanisticadh@gmail.com', 'weight': 5.0}}, {'data': {'source': 'Guillaume.Blum@design.ulaval.ca', 'target': 'liste-proml@lri.fr', 'weight': 5.0}}, {'data': {'source': 'listes@ahicf.com', 'target': 'athena@services.cnrs.fr', 'weight': 20.0}}, {'data': {'source': 'cecile.boulaire@univ-tours.fr', 'target': 'christine.benevent@univ-tours.fr', 'weight': 2.0}}, {'data': {'source': 'oledeuff@gmail.com', 'target': 'claire.clivaz@unil.ch', 'weight': 2.0}}, {'data': {'source': 'pierre.mounier@openedition.org', 'target': 'frederic@clavert.net', 'weight': 5.0}}, {'data': {'source': 'espejosuros.javier@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'vial.stephane@gmail.com', 'target': 'theuth@listes.univ-rennes1.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'info-ic@listes.irisa.fr', 'weight': 15.0}}, {'data': {'source': 'beauguittelaurent@hotmail.com', 'target': 'martaseve@gmail.com', 'weight': 2.0}}, {'data': {'source': 'vial.stephane@gmail.com', 'target': 'projekt-membres@liste.unimes.fr', 'weight': 5.0}}, {'data': {'source': 'muriel.foulonneau@gmail.com', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'aurelie.olivesi@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'ottaviano.nancy@gmail.com', 'target': 'diffusion@listes.ancmsp.com', 'weight': 5.0}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'target': 'legram@yahoogroupes.fr', 'weight': 15.0}}, {'data': {'source': 'carmen.brando@gmail.com', 'target': 'humanist@lists.digitalhumanities.org', 'weight': 5.0}}, {'data': {'source': 'jorge.fins@univ-tours.fr', 'target': 'huyghe.marie@gmail.com', 'weight': 5.0}}, {'data': {'source': 'marionlame@gmail.com', 'target': 'dh@cru.fr', 'weight': 2.0}},  ...

# %%
res=dups/dups_cnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-92eb4abda3ae> in <module>()
# ----> 1 res=dups/dups_cnt
#       2
#
# NameError: name 'dups' is not defined

# %%
my_edges=listor

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'qVtLO4WgiTrwOsj_lJia7Y9IWXdBQMrwfouGFCHAJTN', u'userId': u'MSreQEjksjoK2igp5'}}

# %%
#print my_edges
list_nodes_id=[] 
for nodes in  my_nodesdictList:
    if nodes['data']['id'] not in list_nodes_id:
        list_nodes_id.append(nodes['data']['id'])
    
print len(list_nodes_id)

print list_nodes_id
for edge in my_edges:
    source= edge['data']['source']
    target= edge['data']['target']
    if source not in list_nodes_id:
        print "NO!"
        print source
    if target not in list_nodes_id:
        print "NO2!"
        print target
# Out:
# 279
.free.fr', 'jouni.tuominen@helsinki.fi', 'nicolas.legrand@obspm.fr', 'archives-fr@yahoogroupes.fr', 'fil-tmd@groupes.renater.fr', 'stephane.loret@univ-nantes.fr', 'humanum-veille@listes.huma-num.fr', 'jahjah.marc@gmail.com', 'inforsid@listes.insa-lyon.fr', 'isabelle.thiebau@univ-lille2.fr', 'jouni.tuominen@aalto.fi', 'centernet@lists.digitalhumanities.org', 'raphaelle.bour@irit.fr', 'florent.laroche@ec-nantes.fr', 'marin.dacos@revues.org', 'stephane.pouyllau@huma-num.fr', 'cecile.rodrigues@cnrs.fr', 'projet.iglouvre@gmail.com', 'Rene.Audet@lit.ulaval.ca', 'marjorie.burghart@ehess.fr', 'Nicolas.Larrousse@huma-num.fr', 'dumouchelsuzanne@yahoo.fr', 'projekt@unimes.fr', 'muriel.foulonneau@gmail.com', 'olivier.marlet@univ-tours.fr', 'martin.grandjean@unil.ch', 'antoine.blanchard@gmail.com', 'sarah.cadorel@sciencespo.fr', 'tei-fr@groupes.renater.fr', 'listes@ahicf.com', 'recherche.coordination@bnf.fr', 'beauguittelaurent@hotmail.com', 'amel.fraisse@univ-lille3.fr', 'MKoenig@dhi-paris.fr', 'sandrine.breuil@univ-tours.fr', 'benoit.epron@enssib.fr', 'southasia-dh@lists.globaloutlookdh.org', 'gerald.kembellec@cnam.fr', 'nicolas.thely@univ-rennes2.fr', 'Francoise.Blum@univ-paris1.f ...
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# serge.noiret@eui.eu
# NO!
# serge.noiret@eui.eu
# NO!
# serge.noiret@eui.eu
# NO!
# serge.noiret@eui.eu
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# mkoenig@dhi-paris.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# christine.michel@insa-lyon.fr
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at
# NO!
# eveline.wandl-vogt@oeaw.ac.at

# %%
TOPOGRAM_URL = "http://localhost:3000"

# %%
TOPOGRAM_URL = "https://app.topogram.io"

# %%
title = "alphaDH22"
create_topogram(title, my_nodesdictList, my_edges)
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# Creating topogram 'alphaDH22'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'alphaDH22', u'userId': u'MSreQEjksjoK2igp5', u'_id': u'yyuQJBNa5RayJhxpp', u'slug': u'alphadh22', u'createdAt': u'2018-04-27T07:56:42.613Z'}, u'statusCode': 200}
# topogram ID : yyuQJBNa5RayJhxpp
# {u'status': u'success', 'status_code': 200, u'data': [u'nAfkoDmTjcMSQANqd', u'qQH7HA6tE8qbRreS6', u'CsgmGArCkjG6RP2N4', u'QrL2gMXe6C3sDFxYh', u'9fXPcPKwGFdre3eek', u'oAJgohp2seJq4qqMN', u'bTpZAgQhKrmCxSpLY', u'Y4Cn6Qga8xSpit7LA', u'6L9jy5entWgYpxxkG', u'TE3wxpGR4SvoTjXCy', u'abTj3x6w5bCfC9QcC', u'9rsvYXjuc9tpTGxev', u'HtHhWPumzLPWhmhXu', u'NiHzrTw4DXm9tXafL', u'd726YM2ZwgJ2eHLCj', u'gegjRCcr3Mrtgewrg', u'qSL6MWGBJ3G