# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
#import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
import pickle
with open('dict_corrected_DH.obj', 'rb') as handle:
    dict_corrected_DH = pickle.load(handle)
with open('geocoded_locs.obj', 'rb') as handle:
    geocoded_locs = pickle.load(handle)

with open('corpus_mails_DH.obj', 'rb') as handle:
    corpus_mails_DH = pickle.load(handle)

with open('dict_noms_mails_debut_fin.obj', 'rb') as handle:
    dict_noms_mails_debut_fin = pickle.load(handle)
    

with open('liste_de_tous_les_mails.obj', 'rb') as handle:
    liste_de_tous_les_mails = pickle.load(handle)

# %%
    
print str(dict_corrected_DH)[:1000],"\n"
print str(geocoded_locs)[:1000],"\n"
print str(corpus_mails_DH)[:1000],"\n"
print str(dict_noms_mails_debut_fin)[:1000],"\n"
print str(liste_de_tous_les_mails)[:1000],"\n"
# Out:
# {'googlegroups.com': {u'geometry': {u'location': {u'lat': '43.8424986', u'lng': '4.354806'}}}, 'lecnam.net': {u'geometry': {u'location': {u'lat': '43.8424986', u'lng': '4.354806'}}}, 'jiscmail.ac.uk': {u'geometry': {u'location': {u'lat': '43.8424986', u'lng': '4.354806'}}}, 'design.ulaval.ca': {u'geometry': {u'location': {u'lat': 46.812707, u'lng': -71.225985}, u'viewport': {u'northeast': {u'lat': 46.8140559802915, u'lng': -71.2246360197085}, u'southwest': {u'lat': 46.8113580197085, u'lng': -71.2273339802915}}, u'location_type': u'GEOMETRIC_CENTER'}, u'address_components': [{u'long_name': u'Qu\xe9bec', u'types': [u'locality', u'political'], u'short_name': u'Qu\xe9bec'}, {u'long_name': u'Qu\xe9bec', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'QC'}, {u'long_name': u'Canada', u'types': [u'country', u'political'], u'short_name': u'CA'}, {u'long_name': u'G1K 3G8', u'types': [u'postal_code'], u'short_name': u'G1K 3G8'}], u'place_id': u'ChIJDWgVp3GWuEwRKa5K0WLTY
#
# {'googlegroups.com': 'TO8BE8MANUALLY8EDITED', 'lecnam.net': 'TO8BE8MANUALLY8EDITED', 'jiscmail.ac.uk': 'TO8BE8MANUALLY8EDITED', 'design.ulaval.ca': {u'geometry': {u'location': {u'lat': 46.812707, u'lng': -71.225985}, u'viewport': {u'northeast': {u'lat': 46.8140559802915, u'lng': -71.2246360197085}, u'southwest': {u'lat': 46.8113580197085, u'lng': -71.2273339802915}}, u'location_type': u'GEOMETRIC_CENTER'}, u'address_components': [{u'long_name': u'Qu\xe9bec', u'types': [u'locality', u'political'], u'short_name': u'Qu\xe9bec'}, {u'long_name': u'Qu\xe9bec', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'QC'}, {u'long_name': u'Canada', u'types': [u'country', u'political'], u'short_name': u'CA'}, {u'long_name': u'G1K 3G8', u'types': [u'postal_code'], u'short_name': u'G1K 3G8'}], u'place_id': u'ChIJDWgVp3GWuEwRKa5K0WLTYnk', u'formatted_address': u'295 Boulevard Charest Est, bureau 090, Qu\xe9bec, QC G1K 3G8, Canada', u'types': [u'establishment', u'point_of_interes
#
# {'./DHFRsample/2017-06/msg00011.html': {'Geo_Topic': {'content': '\nbonjour,j&#39;ai eu une tr\xc3\xa8s bonne exp\xc3\xa9rience avec eux sous drupal 7, il y a quelques ann\xc3\xa9es : http://www.supersoniks.com/je ne sais pas comment ils g\xc3\xa8rent le passage actuel \xc3\xa0 drupal 8, en revanche.cordialement,jorge finsie msh val de loirede: &quot;myriam tazi&quot; &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n &gt;\xc3\x80: \n \n <!-- \n document.write("dh" + "@" + "groupes.renater.fr")\n // -->\n envoy\xc3\xa9: jeudi 8 juin 2017 12:11:54objet: [dh] prestation de d\xc3\xa9veloppement sous drupalbonjour,la biblioth\xc3\xa8que de sciences po va d\xc3\xa9velopper un site sous drupal avec un prestataire dans le cadre d&#39;un projet de valorisation. auriez vous des prestataires \xc3\xa0 conseiller ? avec qui vous avez eu une bonne exp\xc3\xa9rience ou des bons retours ?merci d&#39;avance,-- myriam taziservice appui \xc3\xa0 la recherche et outils num
#
# {'Pierre Mounier': [['pierre.mounier@openedition.org', datetime.datetime(2013, 7, 5, 10, 9, 24, tzinfo=tzoffset(None, 7200)), datetime.datetime(2018, 3, 5, 11, 11, tzinfo=tzoffset(None, 3600))], ['pierre.mounier@ehess.fr', datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200)), datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200))]], 'aude.da-cruz-lima': [['aude.da-cruz-lima@mae.u-paris10.fr', datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200))]], 'Thierry Poibeau': [['thierry.poibeau@ens.fr', datetime.datetime(2018, 3, 5, 7, 56, 29, tzinfo=tzoffset(None, 3600)), datetime.datetime(2018, 3, 26, 9, 17, tzinfo=tzoffset(None, 7200))]], 'delegue.general@adbu.fr': [['delegue.general@adbu.fr', datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200)), datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200))]], 'Dominique Stutzmann': [['domini
#
# ['mehdi.khamassi@upmc.fr', 'dh@cru.fr', 'isabelle.thiebau@univ-lille2.fr', 'dh@groupes.renater.fr', 'colette.cadiou@irstea.fr', 'claire.clivaz@sib.swiss', 'johann.holland@campus-condorcet.fr', 'christine.michel@insa-lyon.fr', 'cerisier@univ-poitiers.fr', 'marjorie.burghart@ehess.fr', 'tei-fr@cru.fr', 'stephane.loret@univ-nantes.fr', 'quanti@groupes.renater.fr', 'rbdd@services.cnrs.fr', 'stephane.pouyllau@huma-num.fr', 'formation.continue@enc-sorbonne.fr', 'elenagonzalezblanco@yahoo.es', 'humanist@lists.digitalhumanities.org', 'globaloutlookdh-l@uleth.ca', 'digitalclassicist@jiscmail.ac.uk', 'dm-l@uleth.ca', 'dhd@mailman.rrz.uni-hamburg.de', 'aiucd-l@humnet.unipi.it', 'air-l@aoir.org', 'institute@lists.uvic.ca', 'tei-l@listserv.brown.edu', 'humanist-l@uleth.ca', 'centernet@lists.digitalhumanities.org', 'dhcarolina@listserv.unc.edu', 'humanidadesdigitais@gmail.com', 'website@hastac.org', 'southasia-dh@lists.globaloutlookdh.org', 'air-l@listserv.aoir.org', 'humanisticadh@gmail.com', 'caro

# %%
from datetime import timedelta
import datetime
# credentials
TOPOGRAM_URL = "http://localhost:3000"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
title = "DH_studies_map"
my_nodesdict = {}
my_nodes= []
my_edges = []


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'



###FOR NODES
print len(dict_noms_mails_debut_fin)
print dict_noms_mails_debut_fin['Claire Clivaz']
#claire.clivaz@unil.ch
# Out:
# 167
# [['claire.clivaz@unil.ch', datetime.datetime(2013, 7, 9, 15, 28, 26, tzinfo=tzoffset(None, 7200)), datetime.datetime(2014, 7, 12, 12, 31, 28, tzinfo=tzoffset(None, 7200))], ['claire.clivaz@sib.swiss', datetime.datetime(2016, 7, 20, 16, 54, 26, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 29, 13, 21, 16, tzinfo=tzoffset(None, 7200))]]

# %%
for name in dict_noms_mails_debut_fin:
    
    for mail_array in dict_noms_mails_debut_fin[name]:
        print mail_array[0]
        mail_address=mail_array[0]
        start= mail_array[1]
        end= mail_array[2]
        mail_address_suffix=mail_address.split("@",1)[1]
        print mail_address_suffix
        lat=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lat"]
        lng=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lng"]
        print  lat,lng
        
        print "-------"
         
        try: 
            #print start
            #print end
            node = {
                        "id" : mail_address,
                        "name" : name,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),
                        #"start" : start.isoformat(),

                       #"end" : (end+timedelta(days=1)).isoformat()
                        }
        except AttributeError as e:
            print "STARTSTART",start
            #print datetime.datetime(start[:-5])
            print e

            node = {
                        "id" : mail_address,
                        "name" : name,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),
                        #"start" : datetime.datetime(2012, 3, 2, 15, 19, 10).isoformat(),

                       #"end" : datetime.datetime(2018, 3, 2, 15, 19, 10).isoformat()
                        }
            print node
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
    
print len(my_nodesdict)
# Out:
# pierre.mounier@openedition.org
# openedition.org
# 46.9464269 7.4360048
# -------
# pierre.mounier@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# aude.da-cruz-lima@mae.u-paris10.fr
# mae.u-paris10.fr
# 48.9041663 2.2098627
# -------
# thierry.poibeau@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# delegue.general@adbu.fr
# adbu.fr
# 46.9464269 7.4360048
# -------
# dominique.stutzmann@irht.cnrs.fr
# irht.cnrs.fr
# 48.8664818 2.2954043
# -------
# martin.grandjean@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# francois.theron@uvsq.fr
# uvsq.fr
# 48.799627 2.1415644
# -------
# florent.laroche@ec-nantes.fr
# ec-nantes.fr
# 47.248066 -1.5501304
# -------
# johann.holland@campus-condorcet.fr
# campus-condorcet.fr
# 48.9081455 2.3665891
# -------
# listes@ahicf.com
# ahicf.com
# 46.9464269 7.4360048
# -------
# sandrine.breuil@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# laurens@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# maud.ingarao@ens-lyon.fr
# ens-lyon.fr
# 45.7298448 4.8285332
# -------
# pabloruizfabo@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# valerie.beaugiraud@ens-lyon.fr
# ens-lyon.fr
# 45.7298448 4.8285332
# -------
# marie.e.lescasse@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# marie-laure.massot@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# Eric.Guichard@enssib.fr
# enssib.fr
# 45.7801398 4.8625124
# -------
# pe.barrault@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# aurelien.berra@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# florence.andreacola@univ-grenoble-alpes.fr
# univ-grenoble-alpes.fr
# 45.1914198 5.7672724
# -------
# m.bourgatte@icp.fr
# icp.fr
# 48.8480625 2.3300993
# -------
# jakob.epler@dariah.eu
# dariah.eu
# 50.5546212 6.7628843
# -------
# Rene.Audet@lit.ulaval.ca
# lit.ulaval.ca
# 46.7817463 -71.2747424
# -------
# frederic.clavert@uni.lu
# uni.lu
# 46.9464269 7.4360048
# -------
# eric.kergosien@univ-lille3.fr
# univ-lille3.fr
# 50.627577 3.126726
# -------
# marionlame@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# 282

# %%
print len(my_nodesdict)
# Out:
# 173

# %%
def my_edges_list_singled() :
    my_edges=[]
    extra_nodes_non_autor_list=[]
    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                if maild not in dict_noms_mails_debut_fin:
                    if maild not in extra_nodes_non_autor_list:
                        #print "OHOH NO, NO maild in liste_mail", maild
                        extra_nodes_non_autor_list.append(maild)
                edge = {
                    "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    "weight" : float(2),
                    "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            if maild not in dict_noms_mails_debut_fin:
                    if maild not in extra_nodes_non_autor_list:
                        #print "OHOH NO, NO maild in liste_mail", maild
                        extra_nodes_non_autor_list.append(maild)
            edge = {
                "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(5),
                "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    #print len(my_edges)
    #print extra_nodes_non_autor_list
    #print len(extra_nodes_non_autor_list)
    return [my_edges,extra_nodes_non_autor_list]

my_edges_singled=my_edges_list_singled()[0]
extra_nodes=my_edges_list_singled()[1]

# %%
#print extra_nodes


for mail in extra_nodes:
    
        print mail
        
#        start= mail_array[1]
#        end= mail_array[2]
        mail_address_suffix=mail.split("@",1)[1]
        print mail_address_suffix
        if mail_address_suffix in dict_corrected_DH  :
            
            lat=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lat"]
            lng=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lng"]
            node = {
                        "id" : mail,
                        "name" : mail,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),

                        }
        else: 
            
        
            node = {
                        "id" : mail,
                        "name" : mail,
                       "weight" : float(4),
                        
                        }
        
            print node
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
    
print len(my_nodesdict)
# Out:
# dh@groupes.renater.fr
# groupes.renater.fr
# {'id': 'dh@groupes.renater.fr', 'weight': 4.0, 'name': 'dh@groupes.renater.fr'}
# legram@yahoogroupes.fr
# yahoogroupes.fr
# {'id': 'legram@yahoogroupes.fr', 'weight': 4.0, 'name': 'legram@yahoogroupes.fr'}
# culture.numerique@ml.free.fr
# ml.free.fr
# {'id': 'culture.numerique@ml.free.fr', 'weight': 4.0, 'name': 'culture.numerique@ml.free.fr'}
# listesocius@groups.openedition.org
# groups.openedition.org
# {'id': 'listesocius@groups.openedition.org', 'weight': 4.0, 'name': 'listesocius@groups.openedition.org'}
# DH@cru.fr
# cru.fr
# {'id': 'DH@cru.fr', 'weight': 4.0, 'name': 'DH@cru.fr'}
# exploreAT@oeaw.ac.at
# oeaw.ac.at
# humanist@lists.digitalhumanities.org
# lists.digitalhumanities.org
# {'id': 'humanist@lists.digitalhumanities.org', 'weight': 4.0, 'name': 'humanist@lists.digitalhumanities.org'}
# globaloutlookdh-l@uleth.ca
# uleth.ca
# {'id': 'globaloutlookdh-l@uleth.ca', 'weight': 4.0, 'name': 'globaloutlookdh-l@uleth.ca'}
# digitalclassicist@jiscmail.ac.uk
# jiscmail.ac.uk
# {'id': 'digitalclassicist@jiscmail.ac.uk', 'weight': 4.0, 'name': 'digitalclassicist@jiscmail.ac.uk'}
# dm-l@uleth.ca
# uleth.ca
# {'id': 'dm-l@uleth.ca', 'weight': 4.0, 'name': 'dm-l@uleth.ca'}
# dhd@mailman.rrz.uni-hamburg.de
# mailman.rrz.uni-hamburg.de
# {'id': 'dhd@mailman.rrz.uni-hamburg.de', 'weight': 4.0, 'name': 'dhd@mailman.rrz.uni-hamburg.de'}
# aiucd-l@humnet.unipi.it
# humnet.unipi.it
# {'id': 'aiucd-l@humnet.unipi.it', 'weight': 4.0, 'name': 'aiucd-l@humnet.unipi.it'}
# air-l@aoir.org
# aoir.org
# {'id': 'air-l@aoir.org', 'weight': 4.0, 'name': 'air-l@aoir.org'}
# institute@lists.uvic.ca
# lists.uvic.ca
# {'id': 'institute@lists.uvic.ca', 'weight': 4.0, 'name': 'institute@lists.uvic.ca'}
# tei-l@listserv.brown.edu
# listserv.brown.edu
# {'id': 'tei-l@listserv.brown.edu', 'weight': 4.0, 'name': 'tei-l@listserv.brown.edu'}
# humanist-l@uleth.ca
# uleth.ca
# {'id': 'humanist-l@uleth.ca', 'weight': 4.0, 'name': 'humanist-l@uleth.ca'}
# centernet@lists.digitalhumanities.org
# lists.digitalhumanities.org
# {'id': 'centernet@lists.digitalhumanities.org', 'weight': 4.0, 'name': 'centernet@lists.digitalhumanities.org'}
# dhcarolina@listserv.unc.edu
# listserv.unc.edu
# {'id': 'dhcarolina@listserv.unc.edu', 'weight': 4.0, 'name': 'dhcarolina@listserv.unc.edu'}
# humanidadesdigitais@gmail.com
# gmail.com
# website@hastac.org
# hastac.org
# {'id': 'website@hastac.org', 'weight': 4.0, 'name': 'website@hastac.org'}
# southasia-dh@lists.globaloutlookdh.org
# lists.globaloutlookdh.org
# {'id': 'southasia-dh@lists.globaloutlookdh.org', 'weight': 4.0, 'name': 'southasia-dh@lists.globaloutlookdh.org'}
# air-l@listserv.aoir.org
# listserv.aoir.org
# {'id': 'air-l@listserv.aoir.org', 'weight': 4.0, 'name': 'air-l@listserv.aoir.org'}
# humanisticadh@gmail.com
# gmail.com
# marjorie.burghart@ehess.fr
# ehess.fr
# jean-daniel.fekete@inria.fr
# inria.fr
# Nicole.Dufournaud@laposte.net
# laposte.net
# {'id': 'Nicole.Dufournaud@laposte.net', 'weight': 4.0, 'name': 'Nicole.Dufournaud@laposte.net'}
# dh@cru.fr
# cru.fr
# {'id': 'dh@cru.fr', 'weight': 4.0, 'name': 'dh@cru.fr'}
# claire.clivaz@unil.ch
# unil.ch
# frederic@clavert.net
# clavert.net
# pierre.mounier@openedition.org
# openedition.org
# archives-son-audiovisuel@groups.openedition.org
# groups.openedition.org
# {'id': 'archives-son-audiovisuel@groups.openedition.org', 'weight': 4.0, 'name': 'archives-son-audiovisuel@groups.openedition.org'}
# alexandre.hocquet@univ-lorraine.fr
# univ-lorraine.fr
# francesca.frontini@univ-montp3.fr
# univ-montp3.fr
# {'id': 'francesca.frontini@univ-montp3.fr', 'weight': 4.0, 'name': 'francesca.frontini@univ-montp3.fr'}
# liste-egc@polytech.univ-nantes.fr
# polytech.univ-nantes.fr
# {'id': 'liste-egc@polytech.univ-nantes.fr', 'weight': 4.0, 'name': 'liste-egc@polytech.univ-nantes.fr'}
# bull-i3@irit.fr
# irit.fr
# info-ic@listes.irisa.fr
# listes.irisa.fr
# {'id': 'info-ic@listes.irisa.fr', 'weight': 4.0, 'name': 'info-ic@listes.irisa.fr'}
# ln@cines.fr
# cines.fr
# {'id': 'ln@cines.fr', 'weight': 4.0, 'name': 'ln@cines.fr'}
# humanum-veille@listes.huma-num.fr
# listes.huma-num.fr
# {'id': 'humanum-veille@listes.huma-num.fr', 'weight': 4.0, 'name': 'humanum-veille@listes.huma-num.fr'}
# humanum-diffusion@listes.huma-num.fr
# listes.huma-num.fr
# {'id': 'humanum-diffusion@listes.huma-num.fr', 'weight': 4.0, 'name': 'humanum-diffusion@listes.huma-num.fr'}
# thibault.clerice@enc-sorbonne.fr
# enc-sorbonne.fr
# adherents-aipu-fr@groupes.renater.fr
# groupes.renater.fr
# {'id': 'adherents-aipu-fr@groupes.renater.fr', 'weight': 4.0, 'name': 'adherents-aipu-fr@groupes.renater.fr'}
# afec-info@groupes.renater.fr
# groupes.renater.fr
# {'id': 'afec-info@groupes.renater.fr', 'weight': 4.0, 'name': 'afec-info@groupes.renater.fr'}
# anstia-adherents@groupes.renater.fr
# groupes.renater.fr
# {'id': 'anstia-adherents@groupes.renater.fr', 'weight': 4.0, 'name': 'anstia-adherents@groupes.renater.fr'}
# debuter-en-dh@groupes.renater.fr
# groupes.renater.fr
# {'id': 'debuter-en-dh@groupes.renater.fr', 'weight': 4.0, 'name': 'debuter-en-dh@groupes.renater.fr'}
# emploi-fle@groupes.renater.fr
# groupes.renater.fr
# {'id': 'emploi-fle@groupes.renater.fr', 'weight': 4.0, 'name': 'emploi-fle@groupes.renater.fr'}
# histoire_eco-request@groupes.renater.fr
# groupes.renater.fr
# {'id': 'histoire_eco-request@groupes.renater.fr', 'weight': 4.0, 'name': 'histoire_eco-request@groupes.renater.fr'}
# athena@services.cnrs.fr
# services.cnrs.fr
# {'id': 'athena@services.cnrs.fr', 'weight': 4.0, 'name': 'athena@services.cnrs.fr'}
# archives-fr@yahoogroupes.fr
# yahoogroupes.fr
# {'id': 'archives-fr@yahoogroupes.fr', 'weight': 4.0, 'name': 'archives-fr@yahoogroupes.fr'}
# nep-his@lists.repec.org
# lists.repec.org
# {'id': 'nep-his@lists.repec.org', 'weight': 4.0, 'name': 'nep-his@lists.repec.org'}
# medici@listes.huma-num.fr
# listes.huma-num.fr
# {'id': 'medici@listes.huma-num.fr', 'weight': 4.0, 'name': 'medici@listes.huma-num.fr'}
# ferinterfrance@googlegroups.com
# googlegroups.com
# {'id': 'ferinterfrance@googlegroups.com', 'weight': 4.0, 'name': 'ferinterfrance@googlegroups.com'}
# stephane.pouyllau@cnrs.fr
# cnrs.fr
# lisa.chupin@gmail.com
# gmail.com
# Mathieu.Andro@versailles.inra.fr
# versailles.inra.fr
# marin.dacos@revues.org
# revues.org
# magis@imag.fr
# imag.fr
# {'id': 'magis@imag.fr', 'weight': 4.0, 'name': 'magis@imag.fr'}
# inforsid@listes.insa-lyon.fr
# listes.insa-lyon.fr
# {'id': 'inforsid@listes.insa-lyon.fr', 'weight': 4.0, 'name': 'inforsid@listes.insa-lyon.fr'}
# quanti@groupes.renater.fr
# groupes.renater.fr
# {'id': 'quanti@groupes.renater.fr', 'weight': 4.0, 'name': 'quanti@groupes.renater.fr'}
# rbdd@services.cnrs.fr
# services.cnrs.fr
# {'id': 'rbdd@services.cnrs.fr', 'weight': 4.0, 'name': 'rbdd@services.cnrs.fr'}
# helene.coste@univ-lehavre.fr
# univ-lehavre.fr
# {'id': 'helene.coste@univ-lehavre.fr', 'weight': 4.0, 'name': 'helene.coste@univ-lehavre.fr'}
# valerie.neouze@parisdescartes.fr
# parisdescartes.fr
# {'id': 'valerie.neouze@parisdescartes.fr', 'weight': 4.0, 'name': 'valerie.neouze@parisdescartes.fr'}
# recherche-design@listes.univ-paris1.fr
# listes.univ-paris1.fr
# {'id': 'recherche-design@listes.univ-paris1.fr', 'weight': 4.0, 'name': 'recherche-design@listes.univ-paris1.fr'}
# projekt-membres@liste.unimes.fr
# liste.unimes.fr
# {'id': 'projekt-membres@liste.unimes.fr', 'weight': 4.0, 'name': 'projekt-membres@liste.unimes.fr'}
# projekt@unimes.fr
# unimes.fr
# {'id': 'projekt@unimes.fr', 'weight': 4.0, 'name': 'projekt@unimes.fr'}
# info@design-fax.fr
# design-fax.fr
# {'id': 'info@design-fax.fr', 'weight': 4.0, 'name': 'info@design-fax.fr'}
# theuth@listes.univ-rennes1.fr
# listes.univ-rennes1.fr
# {'id': 'theuth@listes.univ-rennes1.fr', 'weight': 4.0, 'name': 'theuth@listes.univ-rennes1.fr'}
# stephane.pouyllau@huma-num.fr
# huma-num.fr
# txm-users@groupes.renater.fr
# groupes.renater.fr
# {'id': 'txm-users@groupes.renater.fr', 'weight': 4.0, 'name': 'txm-users@groupes.renater.fr'}
# gregory.grefenstette@inria.fr
# inria.fr
# christine.benevent@univ-tours.fr
# univ-tours.fr
# laurent.gerbier@univ-tours.fr
# univ-tours.fr
# sandrine.breuil@univ-tours.fr
# univ-tours.fr
# tei-fr@groupes.renater.fr
# groupes.renater.fr
# {'id': 'tei-fr@groupes.renater.fr', 'weight': 4.0, 'name': 'tei-fr@groupes.renater.fr'}
# liste-proml@lri.fr
# lri.fr
# {'id': 'liste-proml@lri.fr', 'weight': 4.0, 'name': 'liste-proml@lri.fr'}
# docs-ri@yahoogroupes.fr
# yahoogroupes.fr
# {'id': 'docs-ri@yahoogroupes.fr', 'weight': 4.0, 'name': 'docs-ri@yahoogroupes.fr'}
# martaseve@gmail.com
# gmail.com
# geotamtam@unil.ch
# unil.ch
# julia.bonaccorsi@univ-lyon2.fr
# univ-lyon2.fr
# sabine.loudcher@univ-lyon2.fr
# univ-lyon2.fr
# sarah.cordonnier@gmail.com
# gmail.com
# dh-request@groupes.renater.fr
# groupes.renater.fr
# {'id': 'dh-request@groupes.renater.fr', 'weight': 4.0, 'name': 'dh-request@groupes.renater.fr'}
# aurelie.olivesi@univ-lyon1.fr
# univ-lyon1.fr
# {'id': 'aurelie.olivesi@univ-lyon1.fr', 'weight': 4.0, 'name': 'aurelie.olivesi@univ-lyon1.fr'}
# diffusion@listes.ancmsp.com
# listes.ancmsp.com
# {'id': 'diffusion@listes.ancmsp.com', 'weight': 4.0, 'name': 'diffusion@listes.ancmsp.com'}
# efigies-info@rezo.net
# rezo.net
# {'id': 'efigies-info@rezo.net', 'weight': 4.0, 'name': 'efigies-info@rezo.net'}
# etudesfeministes-l@simone.univ-tlse2.fr
# simone.univ-tlse2.fr
# {'id': 'etudesfeministes-l@simone.univ-tlse2.fr', 'weight': 4.0, 'name': 'etudesfeministes-l@simone.univ-tlse2.fr'}
# jakob.epler@dariah.eu
# dariah.eu
# Marie-Laure.Massot@ens.fr
# ens.fr
# huyghe.marie@gmail.com
# gmail.com
# laurent.cailly@univ-tours.fr
# univ-tours.fr
# corpus-ecrits@cru.fr
# cru.fr
# {'id': 'corpus-ecrits@cru.fr', 'weight': 4.0, 'name': 'corpus-ecrits@cru.fr'}
# cahier@groupes.renater.fr
# groupes.renater.fr
# {'id': 'cahier@groupes.renater.fr', 'weight': 4.0, 'name': 'cahier@groupes.renater.fr'}
# llist@unil.ch
# unil.ch
# aurelien.berra@gmail.com
# gmail.com
# litor@listes.univ-paris3.fr
# listes.univ-paris3.fr
# {'id': 'litor@listes.univ-paris3.fr', 'weight': 4.0, 'name': 'litor@listes.univ-paris3.fr'}
# numeruniv-quotidien@cines.fr
# cines.fr
# {'id': 'numeruniv-quotidien@cines.fr', 'weight': 4.0, 'name': 'numeruniv-quotidien@cines.fr'}
# cerisier@univ-poitiers.fr
# univ-poitiers.fr
# {'id': 'cerisier@univ-poitiers.fr', 'weight': 4.0, 'name': 'cerisier@univ-poitiers.fr'}
# schassan@hab.de
# hab.de
# {'id': 'schassan@hab.de', 'weight': 4.0, 'name': 'schassan@hab.de'}
# c.schoech@gmail.com
# gmail.com
# emmanuelle.duwez@sciencespo.fr
# sciencespo.fr
# tei-fr@cru.fr
# cru.fr
# {'id': 'tei-fr@cru.fr', 'weight': 4.0, 'name': 'tei-fr@cru.fr'}
# antoine.courtin@mac.com
# mac.com
# elenagonzalezblanco@yahoo.es
# yahoo.es
# ahdig@googlegroups.com
# googlegroups.com
# {'id': 'ahdig@googlegroups.com', 'weight': 4.0, 'name': 'ahdig@googlegroups.com'}
# textualscholarship@jiscmail.ac.uk
# jiscmail.ac.uk
# {'id': 'textualscholarship@jiscmail.ac.uk', 'weight': 4.0, 'name': 'textualscholarship@jiscmail.ac.uk'}
# olivier.marlet@univ-tours.fr
# univ-tours.fr
# ontologie-patrimoine@services.cnrs.fr
# services.cnrs.fr
# {'id': 'ontologie-patrimoine@services.cnrs.fr', 'weight': 4.0, 'name': 'ontologie-patrimoine@services.cnrs.fr'}
# valerie.beaugiraud@ens-lyon.fr
# ens-lyon.fr
# digit_hum@ens.fr
# ens.fr
# corpora@uib.no
# uib.no
# {'id': 'corpora@uib.no', 'weight': 4.0, 'name': 'corpora@uib.no'}
# saes@univ-pau.fr
# univ-pau.fr
# {'id': 'saes@univ-pau.fr', 'weight': 4.0, 'name': 'saes@univ-pau.fr'}
# alaes_liste@yahoogroupes.fr
# yahoogroupes.fr
# {'id': 'alaes_liste@yahoogroupes.fr', 'weight': 4.0, 'name': 'alaes_liste@yahoogroupes.fr'}
# parislinguists@yahoogroupes.fr
# yahoogroupes.fr
# {'id': 'parislinguists@yahoogroupes.fr', 'weight': 4.0, 'name': 'parislinguists@yahoogroupes.fr'}
# agorantic@listes.univ-avignon.fr
# listes.univ-avignon.fr
# {'id': 'agorantic@listes.univ-avignon.fr', 'weight': 4.0, 'name': 'agorantic@listes.univ-avignon.fr'}
# iwetel@listserv.rediris.es
# listserv.rediris.es
# {'id': 'iwetel@listserv.rediris.es', 'weight': 4.0, 'name': 'iwetel@listserv.rediris.es'}
# INFOLING@LISTSERV.REDIRIS.ES
# LISTSERV.REDIRIS.ES
# {'id': 'INFOLING@LISTSERV.REDIRIS.ES', 'weight': 4.0, 'name': 'INFOLING@LISTSERV.REDIRIS.ES'}
# infoling@listserv.rediris.es
# listserv.rediris.es
# {'id': 'infoling@listserv.rediris.es', 'weight': 4.0, 'name': 'infoling@listserv.rediris.es'}
# redhd@humanidadesdigitales.net
# humanidadesdigitales.net
# {'id': 'redhd@humanidadesdigitales.net', 'weight': 4.0, 'name': 'redhd@humanidadesdigitales.net'}
# fil-tmd@groupes.renater.fr
# groupes.renater.fr
# {'id': 'fil-tmd@groupes.renater.fr', 'weight': 4.0, 'name': 'fil-tmd@groupes.renater.fr'}
# eda-liste@listes.univ-lyon2.fr
# listes.univ-lyon2.fr
# {'id': 'eda-liste@listes.univ-lyon2.fr', 'weight': 4.0, 'name': 'eda-liste@listes.univ-lyon2.fr'}
# gazettebd3@imag.fr
# imag.fr
# {'id': 'gazettebd3@imag.fr', 'weight': 4.0, 'name': 'gazettebd3@imag.fr'}
# madics-adoc@listes.univ-lyon2.fr
# listes.univ-lyon2.fr
# {'id': 'madics-adoc@listes.univ-lyon2.fr', 'weight': 4.0, 'name': 'madics-adoc@listes.univ-lyon2.fr'}
# annonces@madics.fr
# madics.fr
# {'id': 'annonces@madics.fr', 'weight': 4.0, 'name': 'annonces@madics.fr'}
# viera.rebolledodhuin@free.fr
# free.fr
# TEXTUALSCHOLARSHIP@jiscmail.ac.uk
# jiscmail.ac.uk
# {'id': 'TEXTUALSCHOLARSHIP@jiscmail.ac.uk', 'weight': 4.0, 'name': 'TEXTUALSCHOLARSHIP@jiscmail.ac.uk'}
# adbs-info@listes.adbs.fr
# listes.adbs.fr
# {'id': 'adbs-info@listes.adbs.fr', 'weight': 4.0, 'name': 'adbs-info@listes.adbs.fr'}
# accesouvert@groupes.renater.fr
# groupes.renater.fr
# {'id': 'accesouvert@groupes.renater.fr', 'weight': 4.0, 'name': 'accesouvert@groupes.renater.fr'}
# doccitanist@services.cnrs.fr
# services.cnrs.fr
# {'id': 'doccitanist@services.cnrs.fr', 'weight': 4.0, 'name': 'doccitanist@services.cnrs.fr'}
# info-aria@lsis.org
# lsis.org
# {'id': 'info-aria@lsis.org', 'weight': 4.0, 'name': 'info-aria@lsis.org'}
# 282

# %%
my_edges=my_edges_singled
print my_edges
# Out:
# [{'data': {'source': 'jorge.fins@univ-tours.fr', 'name': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'id': u'./DHFRsample/2017-06/msg00011.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'legram@yahoogroupes.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'culture.numerique@ml.free.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'listesocius@groups.openedition.org'}}, {'data': {'source': 'claire.clivaz@sib.swiss', 'name': u': [DH] Poste de senior technical officer (Maynooth University)', 'id': u'./DHFRsample/2016-07/msg00030.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'laetitia.bontemps@univ-tours.fr', 'name': u': [DH] Stage initiation XML-TEI (Tours, octobre 2011)', 'id': u'./DHFRsample/2011-07/msg00004.html', 'weight': 5.0, 'target': 'DH@cru.fr'}}, {'data': {'source': 'stephane.pouyllau@huma-num.fr', 'name': u': Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities', 'id': u'./DHFRsample/2013-07/msg00022.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'myriam.tazi@sciencespo.fr', 'name': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'id': u'./DHFRsample/2017-06/msg00026.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'name': u': [DH] exploreAT! job offer @ vienna: citizen science & DIY science; cultural lexicographer', 'id': u'./DHFRsample/2017-06/msg00057.html', 'weight': 5.0, 'target': 'exploreAT@oeaw.ac.at'}}, {'data': {'source': 'camillemonnier33@hotmail.com', 'name': u': RE: [DH] Hackathon ESOBD (Pr\xe9vu, MC2, Cartographie Hesam)', 'id': u'./DHFRsample/2017-06/msg00027.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'humanist@lists.digitalhumanities.org'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'globaloutlookdh-l@uleth.ca'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'digitalclassicist@jiscmail.ac.uk'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'dm-l@uleth.ca'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'dhd@mailman.rrz.uni-hamburg.de'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'aiucd-l@humnet.unipi.it'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD ...

# %%
def my_edges_list_by_source_dest() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    "weight" : float(2),
                    #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])+" "+
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(5),
                #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)
    return my_edges

my_edges_duped=my_edges_list_by_source_dest()
# Out:
# 527

# %%
def my_edges_list_with_subject() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    #"weight" : float(2),
                    "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                #"weight" : float(5),
                "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)

    return my_edges

my_edges_duped_with_subject=my_edges_list_with_subject()
# Out:
# 527

# %%
#WE HAVE TO TEST THE EDGES, BUT IT IS AN ARRAY OF DICTS,SO WE NEED TO FLATTEN THEM TO COUNT THEM SIMPLY

import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
def list_flattener_and_finder(edges_list_singled,edges_list_duped):
    from collections import Counter
    import ast
    my_edges_replacement_deduped=[]
    receiver=[]
    for i,dic in enumerate(edges_list_duped):
        #print my_edges[i]
        dicto=flatten(edges_list_duped[i])
    #    print dicto
        receiver.append(str(dicto))

    #print receiver
    CREE= Counter(receiver).iteritems()
    total=0
    dups=0
    dups_cnt=0
    
    print edges_list_singled[:1]
    for key, value in CREE:
        #print key
        #print value
        keyB={'data':{}}
        total+=1
        
        #print ast.literal_eval(key)["data_source"]
        #print ast.literal_eval(key)["data_target"]        
        keyB={'data':{"source":ast.literal_eval(key)["data_source"],"target": ast.literal_eval(key)["data_target"]}}
        #print "SUP",key, value
        dups+=value
        dups_cnt+=1
        #print ">>",keyB
        #print ast.literal_eval(key)["data_weight"]    
        keyB["data"]["weight"]= float(value*float(ast.literal_eval(key)["data_weight"]))
        #print "KEYB____",keyB
        my_edges_replacement_deduped.append(keyB)


            





    print "total",total

    print "dups",dups
    print "dups_cnt",dups_cnt
    return my_edges_replacement_deduped

listor=list_flattener_and_finder(my_edges,my_edges_duped)
print listor
# Out:
# []
# total 368
# dups 527
# dups_cnt 368
# [{'data': {'source': 'e.salvatori@mediev.unipi.it', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'delegue.general@adbu.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'graham.ranger@univ-avignon.fr', 'target': 'parislinguists@yahoogroupes.fr', 'weight': 5.0}}, {'data': {'source': 'Guillaume.Blum@design.ulaval.ca', 'target': 'docs-ri@yahoogroupes.fr', 'weight': 5.0}}, {'data': {'source': 'jahjah.marc@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'gpansu@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'liste-proml@lri.fr', 'weight': 5.0}}, {'data': {'source': 'emmanuelle.morlock@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'claire.lemercier@sciencespo.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'yamina.bensaadoune@univ-rouen.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'aurelie.olivesi@wanadoo.fr', 'target': 'efigies-info@rezo.net', 'weight': 5.0}}, {'data': {'source': 'oledeuff@gmail.com', 'target': 'valerie.beaugiraud@ens-lyon.fr', 'weight': 5.0}}, {'data': {'source': 'jorge.fins@univ-tours.fr', 'target': 'dh@groupes.renater.fr', 'weight': 10.0}}, {'data': {'source': 'jbcamps@hotmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'enrico.natale@infoclio.ch', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'pe.barrault@gmail.com', 'target': 'emmanuelle.duwez@sciencespo.fr', 'weight': 5.0}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'target': 'air-l@listserv.aoir.org', 'weight': 5.0}}, {'data': {'source': 'michel.bernard@univ-paris3.fr', 'target': 'litor@listes.univ-paris3.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'docs-ri@yahoogroupes.fr', 'weight': 10.0}}, {'data': {'source': 'marionlame@gmail.com', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'target': 'air-l@listserv.aoir.org', 'weight': 5.0}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'target': 'humanisticadh@gmail.com', 'weight': 5.0}}, {'data': {'source': 'Guillaume.Blum@design.ulaval.ca', 'target': 'liste-proml@lri.fr', 'weight': 5.0}}, {'data': {'source': 'listes@ahicf.com', 'target': 'athena@services.cnrs.fr', 'weight': 20.0}}, {'data': {'source': 'cecile.boulaire@univ-tours.fr', 'target': 'christine.benevent@univ-tours.fr', 'weight': 2.0}}, {'data': {'source': 'oledeuff@gmail.com', 'target': 'claire.clivaz@unil.ch', 'weight': 2.0}}, {'data': {'source': 'pierre.mounier@openedition.org', 'target': 'frederic@clavert.net', 'weight': 5.0}}, {'data': {'source': 'espejosuros.javier@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'vial.stephane@gmail.com', 'target': 'theuth@listes.univ-rennes1.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'info-ic@listes.irisa.fr', 'weight': 15.0}}, {'data': {'source': 'beauguittelaurent@hotmail.com', 'target': 'martaseve@gmail.com', 'weight': 2.0}}, {'data': {'source': 'vial.stephane@gmail.com', 'target': 'projekt-membres@liste.unimes.fr', 'weight': 5.0}}, {'data': {'source': 'muriel.foulonneau@gmail.com', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'aurelie.olivesi@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'ottaviano.nancy@gmail.com', 'target': 'diffusion@listes.ancmsp.com', 'weight': 5.0}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'target': 'legram@yahoogroupes.fr', 'weight': 15.0}}, {'data': {'source': 'carmen.brando@gmail.com', 'target': 'humanist@lists.digitalhumanities.org', 'weight': 5.0}}, {'data': {'source': 'jorge.fins@univ-tours.fr', 'target': 'huyghe.marie@gmail.com', 'weight': 5.0}}, {'data': {'source': 'marionlame@gmail.com', 'target': 'dh@cru.fr', 'weight': 2.0}},  ...

# %%
res=dups/dups_cnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-92eb4abda3ae> in <module>()
# ----> 1 res=dups/dups_cnt
#       2
#
# NameError: name 'dups' is not defined

# %%
my_edges=listor

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'cj08KWs0j4cq12mOT_4oQBv7NS1Bi9GXRqYXmdUjPRY', u'userId': u'MSreQEjksjoK2igp5'}}

# %%
#print my_edges
list_nodes_id=[] 
for nodes in  my_nodesdictList:
    if nodes['data']['id'] not in list_nodes_id:
        list_nodes_id.append(nodes['data']['id'])
    
print len(list_nodes_id)

print list_nodes_id
for edge in my_edges:
    source= edge['data']['source']
    target= edge['data']['target']
    if source not in list_nodes_id:
        print "NO!"
        print source
azettebd3@imag.fr', 'francesco.beretta@ish-lyon.cnrs.fr', 'florence.andreacola@univ-grenoble-alpes.fr', 'gpansu@gmail.com', 'info@design-fax.fr', 'jerome.valluy@univ-paris1.fr', 'formation.continue@enc-sorbonne.fr', 'afec-info@groupes.renater.fr', 'laurent.cailly@univ-tours.fr', 'jea.herzog@gmail.com', 'emmanuelle.morlock@gmail.com', 'gregory.grefenstette@inria.fr', 'culture.numerique@ml.free.fr', 'jouni.tuominen@helsinki.fi', 'nicolas.legrand@obspm.fr', 'archives-fr@yahoogroupes.fr', 'fil-tmd@groupes.renater.fr', 'stephane.loret@univ-nantes.fr', 'humanum-veille@listes.huma-num.fr', 'jahjah.marc@gmail.com', 'inforsid@listes.insa-lyon.fr', 'isabelle.thiebau@univ-lille2.fr', 'jouni.tuominen@aalto.fi', 'centernet@lists.digitalhumanities.org', 'raphaelle.bour@irit.fr', 'florent.laroche@ec-nantes.fr', 'marin.dacos@revues.org', 'stephane.pouyllau@huma-num.fr', 'cecile.rodrigues@cnrs.fr', 'projet.iglouvre@gmail.com', 'Rene.Audet@lit.ulaval.ca', 'marjorie.burghart@ehess.fr', 'valerie.neouze@parisdescartes.fr', 'Nicolas.Larrousse@huma-num.fr', 'dumouchelsuzanne@yahoo.fr', 'projekt@unimes.fr', 'muriel.foulonneau@gmail.com', 'olivier.marlet@univ-tours.fr', 'martin.grandjean@unil.ch', 'antoine.blanchard@gmail.com', 'sarah.cadorel@sciencespo.fr', 'tei-fr@groupes.renater.fr', 'listes@ahicf.com', 'recherche.coordination@bnf.fr', 'beauguittelaurent@hotmail.com', 'amel.fraisse@univ-lille3.fr', 'INFOLING@LISTSERV.REDIRIS.ES', 'MKoenig@dhi-paris.fr', 'sandrine.breuil@univ-tours.fr', ' ...

# %%
title = "alphaDH17"
create_topogram(title, my_nodesdictList, my_edges)
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# Creating topogram 'alphaDH17'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'alphaDH17', u'userId': u'MSreQEjksjoK2igp5', u'_id': u'vqkt7AQARrya5uPof', u'slug': u'alphadh17', u'createdAt': u'2018-04-24T10:10:26.154Z'}, u'statusCode': 200}
# topogram ID : vqkt7AQARrya5uPof
# {u'status': u'success', 'status_code': 200, u'data': [u'MaXpLsCHSPfm3E9ko', u'X93nYSLQHATf4g2Hc', u'iwMimeDhQFzWAsBuy', u'qoaA6Apdgx2sngptQ', u'38fMQvYe5HRaCBMtd', u'f7eTeYw7ftgwbAsvy', u'rAM8tGkzLKPHfZ2vb', u'tEqsSFfNWoXYfRySS', u'9rmNbGAcyA93xicoQ', u'8ExY8Fdgx3fzDKEnp', u'DGrkdkwQhZS7XyLAZ', u'Suj666MmDq6qaGvAL', u'FX8uYRHc5MD59cJhd', u'YeceRGDuCQo9QWW2d', u'2s4AJJqiAhKSTwP6w', u'QATWjjF3NPsseiRWN', u'tdcogAnbcvfdnhFJA', u'q8nK9oLDLoa9XJZxi', u'P5pMDxChn7WYmL29x', u'hkWLfXcY36