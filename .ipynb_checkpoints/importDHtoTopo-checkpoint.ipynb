# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
import pickle
with open('dict_corrected_DH.obj', 'rb') as handle:
    dict_corrected_DH = pickle.load(handle)
with open('geocoded_locs.obj', 'rb') as handle:
    geocoded_locs = pickle.load(handle)
import pickle
with open('corpus_mails_DH.obj', 'rb') as handle:
    corpus_mails_DH = pickle.load(handle)
import pickle
with open('dict_noms_mails_debut_fin.obj', 'rb') as handle:
    dict_noms_mails_debut_fin = pickle.load(handle)

# %%
    
print str(dict_corrected_DH)[:1000],"\n"
print str(geocoded_locs)[:1000],"\n"
print str(corpus_mails_DH)[:1000],"\n"
print str(dict_noms_mails_debut_fin)[:1000],"\n"
# Out:
# {'lecnam.net': {u'geometry': {u'location': {u'lat': '46.9464269', u'lng': '7.4360048'}}}, 'design.ulaval.ca': {u'geometry': {u'location': {u'lat': 46.812707, u'lng': -71.225985}, u'viewport': {u'northeast': {u'lat': 46.8140559802915, u'lng': -71.2246360197085}, u'southwest': {u'lat': 46.8113580197085, u'lng': -71.2273339802915}}, u'location_type': u'GEOMETRIC_CENTER'}, u'address_components': [{u'long_name': u'Qu\xe9bec', u'short_name': u'Qu\xe9bec', u'types': [u'locality', u'political']}, {u'long_name': u'Qu\xe9bec', u'short_name': u'QC', u'types': [u'administrative_area_level_1', u'political']}, {u'long_name': u'Canada', u'short_name': u'CA', u'types': [u'country', u'political']}, {u'long_name': u'G1K 3G8', u'short_name': u'G1K 3G8', u'types': [u'postal_code']}], u'place_id': u'ChIJDWgVp3GWuEwRKa5K0WLTYnk', u'formatted_address': u'295 Boulevard Charest Est, bureau 090, Qu\xe9bec, QC G1K 3G8, Canada', u'types': [u'establishment', u'point_of_interest', u'university']}, 'dhi-paris.fr': {
#
# {'mines.org': {u'geometry': {u'location': {u'lat': 48.845585, u'lng': 2.339632}, u'viewport': {u'northeast': {u'lat': 48.8469339802915, u'lng': 2.340980980291502}, u'southwest': {u'lat': 48.8442360197085, u'lng': 2.338283019708498}}, u'location_type': u'ROOFTOP'}, u'address_components': [{u'long_name': u'60', u'types': [u'street_number'], u'short_name': u'60'}, {u'long_name': u'Boulevard Saint-Michel', u'types': [u'route'], u'short_name': u'Boulevard Saint-Michel'}, {u'long_name': u'Paris', u'types': [u'locality', u'political'], u'short_name': u'Paris'}, {u'long_name': u'Paris', u'types': [u'administrative_area_level_2', u'political'], u'short_name': u'Paris'}, {u'long_name': u'\xcele-de-France', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'\xcele-de-France'}, {u'long_name': u'France', u'types': [u'country', u'political'], u'short_name': u'FR'}, {u'long_name': u'75006', u'types': [u'postal_code'], u'short_name': u'75006'}], u'place_id': u'ChIJa8WGQsNx5kcR2
#
# {'./DHFRsample/2017-06/msg00011.html': {'Geo_Topic': {'content': '\nBonjour,J&#39;ai eu une tr\xc3\xa8s bonne exp\xc3\xa9rience avec eux sous Drupal 7, il y a quelques ann\xc3\xa9es : http://www.supersoniks.com/Je ne sais pas comment ils g\xc3\xa8rent le passage actuel \xc3\xa0 Drupal 8, en revanche.Cordialement,Jorge FinsIE MSH Val de LoireDe: &quot;Myriam TAZI&quot; &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n &gt;\xc3\x80: \n \n <!-- \n document.write("dh" + "@" + "groupes.renater.fr")\n // -->\n Envoy\xc3\xa9: Jeudi 8 Juin 2017 12:11:54Objet: [DH] Prestation de d\xc3\xa9veloppement sous drupalBonjour,la biblioth\xc3\xa8que de Sciences Po va d\xc3\xa9velopper un site sous drupal avec un prestataire dans le cadre d&#39;un projet de valorisation. Auriez vous des prestataires \xc3\xa0 conseiller ? avec qui vous avez eu une bonne exp\xc3\xa9rience ou des bons retours ?Merci d&#39;avance,-- Myriam TaziService Appui \xc3\xa0 la Recherche et Outils num
#
# {'Pierre Mounier': [['pierre.mounier@openedition.org', datetime.datetime(2013, 7, 5, 10, 9, 24, tzinfo=tzoffset(None, 7200)), datetime.datetime(2018, 3, 5, 11, 11, tzinfo=tzoffset(None, 3600))], ['pierre.mounier@ehess.fr', datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200)), datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200))]], 'aude.da-cruz-lima': [['aude.da-cruz-lima@mae.u-paris10.fr', datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200))]], 'Thierry Poibeau': [['thierry.poibeau@ens.fr', datetime.datetime(2018, 3, 5, 7, 56, 29, tzinfo=tzoffset(None, 3600)), datetime.datetime(2018, 3, 26, 9, 17, tzinfo=tzoffset(None, 7200))]], 'delegue.general@adbu.fr': [['delegue.general@adbu.fr', datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200)), datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200))]], 'Dominique Stutzmann': [['domini

# %%
from datetime import timedelta
import datetime
# credentials
TOPOGRAM_URL = "https://app.topogram.io"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
title = "DH_studies_map"
my_nodesdict = {}
my_nodes= []
my_edges = []


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'



###FOR NODES
for name in dict_noms_mails_debut_fin:
    
    for mail_array in dict_noms_mails_debut_fin[name]:
        print mail_array[0]
        mail_address=mail_array[0]
        start= mail_array[1]
        end= mail_array[2]
        mail_address_suffix=mail_address.split("@",1)[1]
        print mail_address_suffix
        lat=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lat"]
        lng=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lng"]
        print  lat,lng
        
    print "-------"
    
    
    
    
    
    
    try: 
        #print start
        #print end
        node = {
                    "id" : mail_address,
                    "name" : name,
                   "lat" : float(lat),
                   "lng" : float(lng),
                   "weight" : float(1),
                    "start" : start.isoformat(),
                                
                   "end" : (end+timedelta(days=1)).isoformat()
                    }
    except AttributeError as e:
        print "STARTSTART",start
        #print datetime.datetime(start[:-5])
        print e
        
        node = {
                    "id" : mail_address,
                    "name" : name,
                   "lat" : float(lat),
                   "lng" : float(lng),
                   "weight" : float(1),
                    "start" : datetime.datetime(2006, 3, 2, 15, 19, 10).isoformat(),
                                
                   "end" : datetime.datetime(2018, 3, 2, 15, 19, 10).isoformat()
                    }
    my_nodes.append({ "data" : node })   
    my_nodesdict[node["id"]]= { "data" : node }
    
print my_nodesdict
# Out:
# pierre.mounier@openedition.org
# openedition.org
# 46.9464269 7.4360048
# pierre.mounier@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# aude.da-cruz-lima@mae.u-paris10.fr
# mae.u-paris10.fr
# 48.9041663 2.2098627
# -------
# thierry.poibeau@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# delegue.general@adbu.fr
# adbu.fr
# 46.9464269 7.4360048
# -------
# dominique.stutzmann@irht.cnrs.fr
# irht.cnrs.fr
# 48.8664818 2.2954043
# -------
# martin.grandjean@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
# Nicolas.Larrousse@huma-num.fr
# huma-num.fr
# 48.850142 2.3269827
# -------
# judith.hannoun@univ-amu.fr
# univ-amu.fr
# 43.293621 5.358066
# -------
# ottaviano.nancy@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# nadine.dardenne@cnrs.fr
# cnrs.fr
# 45.203453 5.700236
# -------
# colette.cadiou@irstea.fr
# irstea.fr
# 45.7627097 3.1110909
# -------
# yamina.bensaadoune@univ-rouen.fr
# univ-rouen.fr
# 49.4583047 1.0688892
# -------
# francoise.paquienseguy@sciencespo-lyon.fr
# sciencespo-lyon.fr
# 45.7470623 4.8357091
# -------
# cecile.rodrigues@cnrs.fr
# cnrs.fr
# 45.203453 5.700236
# -------
# francesco.beretta@ish-lyon.cnrs.fr
# ish-lyon.cnrs.fr
# 45.7470731 4.8355436
# -------
# michel.bernard@univ-paris3.fr
# univ-paris3.fr
# 48.8397962 2.3538807
# -------
# francois.bavaud@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
# beauguittelaurent@hotmail.com
# hotmail.com
# 47.6393769 -122.1282558
# -------
# audrey.baneyx@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# jouni.tuominen@helsinki.fi
# helsinki.fi
# 46.9464269 7.4360048
# jouni.tuominen@aalto.fi
# aalto.fi
# 46.9464269 7.4360048
# -------
# Serge.Noiret@EUI.eu
# EUI.eu
# 43.803079 11.282959
# -------
# svhoolan@ulb.ac.be
# ulb.ac.be
# 50.8132068 4.3822222
# -------
# olfa.lamloum@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# jerome.valluy@univ-paris1.fr
# univ-paris1.fr
# 48.8469373 2.344468
# -------
# caroline.muller@univ-reims.fr
# univ-reims.fr
# 49.2559131 4.0408547
# -------
# remi.jimenes@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# marie-laure.massot@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# Eric.Guichard@enssib.fr
# enssib.fr
# 45.7801398 4.8625124
# -------
# pe.barrault@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# aurelien.berra@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# florence.andreacola@univ-grenoble-alpes.fr
# univ-grenoble-alpes.fr
# 45.1914198 5.7672724
# -------
# m.bourgatte@icp.fr
# icp.fr
# 48.8480625 2.3300993
# -------
# jakob.epler@dariah.eu
# dariah.eu
# 50.5546212 6.7628843
# -------
# Rene.Audet@lit.ulaval.ca
# lit.ulaval.ca
# 46.7817463 -71.2747424
# -------
# frederic.clavert@uni.lu
# uni.lu
# 46.9464269 7.4360048
# -------
# eric.kergosien@univ-lille3.fr
# univ-lille3.fr
# 50.627577 3.126726
# -------
# marionlame@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# {'frederic@clavert.net': {'data': {'end': '2015-07-03T15:41:35+02:00', 'name': 'Fr\xc3\xa9d\xc3\xa9ric Clavert', 'weight': 1.0, 'start': '2012-07-10T10:39:11+02:00', 'lat': 46.9464269, 'lng': 7.4360048, 'id': 'frederic@clavert.net'}}, 'audrey.baneyx@sciencespo.fr': {'data': {'end': '2015-07-28T14:16:20+02:00', 'name': 'Audrey Baneyx - Sciences Po', 'weight': 1.0, 'start': '2015-07-27T14:16:20+02:00', 'lat': 48.8540917, 'lng': 2.3283745, 'id': 'audrey.baneyx@sciencespo.fr'}}, 'vial.stephane@gmail.com': {'data': {'end': '2018-03-07T10:58:35+00:00', 'name': 'St\xc3\xa9phane Vial', 'weight': 1.0, 'start': '2017-06-11T14:29:59+00:00', 'lat': 46.9464269, 'lng': 7.4360048, 'id': 'vial.stephane@gmail.com'}}, 'marie.e.lescasse@gmail.com': {'data': {'end': '2018-03-29T17:09:57+02:00', 'name': 'Marie-Eglantine Lescasse', 'weight': 1.0, 'start': '2018-03-28T17:09:57+02:00', 'lat': 46.9464269, 'lng': 7.4360048, 'id': 'marie.e.lescasse@gmail.com'}}, 'laurence.rageot@univ-tours.fr': {'data': {'end': '2018-03-13T13:45:47+01:00', 'name': 'Laurence Rageot', 'weight': 1.0, 'start': '2015-07-08T15:10:16+02:00', 'lat': 47.3838055, 'lng': 0.6738727999999999, 'id': 'laurence.rageot@univ-tours.fr'}}, 'clemence.jacquot@gmail.com': {'data': {'end': '2018-03-13T15:15:16+01:00', 'name': 'cl\xc3\xa9mence jacquot', 'weight': 1.0, 'start': '2018-03-12T15:15:16+01:00', 'lat': 46.9464269, 'lng': 7.4360048, 'id': 'clemence.jacquot@gmail.com'}}, 'michel.bernard@univ-paris3.fr': {'data': {'end': '2018-03-10T17:52:54+01:00', 'name': 'Michel Bernard', 'weight': 1.0, 'start': '2014-07-10T09:09:21+02:00', 'lat': 48.83979619999999, 'lng': 2.3538807, 'id': 'michel.bernard@univ-paris3.fr'}}, 'laurent.romary@inria.fr': {'data': {'end': '2016-07-07T19:01:56+02:00', 'name': 'Laurent Romary', 'weight': 1.0, 'start': '2014-07-30T15:35:56+02:00', 'lat': 45.7862471, 'lng': 4.8797456, 'id': 'laurent.romary@inria.fr'}}, 'valerie.beaugiraud@ens-lyon.fr': {'data': {'end': '2015-07-10T11:42:23+02:00', 'name': 'Val\xc3\xa9rie Beaugiraud', 'weight': 1.0, 'start': '2015-07-09T11:42:23+02:00', 'lat': 45.7298448, 'lng': 4.8285332, 'id': 'valerie.beaugiraud@ens-lyon.fr'}}, 'ottaviano.nancy@gmail.com': {'data': {'end': '2014-07-10T22:34:26+02:00', 'name': 'Nancy Ottaviano', 'weight': 1.0, 'start': '2014-07-09T22:34:26+02:00', 'lat': 46.9464269, 'lng': 7.4360048, 'id': 'ottaviano.nancy@gmail.com'}}, 'yamina.bensaadoune@univ-rouen.fr': {'data': {'end': '2015-07-16T17:07:53+02:00', 'name': 'YAMINA BENSAADOUNE', 'weight': 1.0, 'start': '2015-07-15T17:07:53+02:00', 'lat': 49.4583047, 'lng': 1.0688892, 'id': 'yamina.bensaadoune@univ-rouen.fr'}}, 'alexandre.hocquet@univ-lorraine.fr': {'data': {'end': '2017-06-28T14:19:29+02:00', 'name': 'Alexandre Hocquet', 'weight': 1.0, 'start': '2017-06-27T14:19:29+02:00', 'lat': 49.1203429, 'lng': 6.1627983, 'id': 'alexandre.hocquet@univ-lorraine.fr'}}, 'beatrice.markhoff@univ-tours.fr': {'data': {'end': '2018-03-05T11:39:36+01:00', 'name': 'B\xc3\xa9atrice Markhoff', 'weight': 1.0, 'start': '2017-06-13T14:27:18+02:00', 'lat': 47.3838055, 'lng': 0.6738727999999999, 'id': 'beatrice.markhoff@univ-tours.fr'}}, 'm.bourgatte@icp.fr': {'data': {'end': '2016-07-20T14:37:11+02:00', 'name': 'Michael Bourgatte', 'weight': 1.0, 'start': '2016-07-19T14:37:11+02:00', 'lat': 48.8480625, 'lng': 2.330099300000001, 'id': 'm.bourgatte@icp.fr'}}, 'dominique.stutzmann@irht.cnrs.fr': {'data': {'end': '2017-06-28T14:18:48+02:00', 'name': 'Dominique Stutzmann', 'weight': 1.0, 'start': '2012-07-02T08:25:19+02:00', 'lat': 48.8664818, 'lng': 2.2954043, 'id': 'dominique.stutzmann@irht.cnrs.fr'}}, 'caroline.cance@univ-orleans.fr': {'data': {'end': '2018-03-22T09:24:41+01:00', 'name': 'Caroline Cance', 'weight': 1.0, 'start': '2018-03-21T09:24:41+01:00', 'lat': 47.8430441, 'lng': 1.9365067, 'id': 'caroline.cance@univ-orleans.fr'}}, 'jerome.darmont@univ-lyon2.fr': {'data': {'end': '2018-03-10T11:17:31+01:00', 'name': 'J\xc3\xa9r\xc3\xb4me Darmont', 'weight': 1.0, 'start': '2018-03-09T11 ...

# %%
print len(my_nodesdict)
# Out:
# 164

# %%
my_edges=[]
for mail in corpus_mails_DH:
    #print mail
    print  corpus_mails_DH[mail]
    if "liste_CCs" in corpus_mails_DH[mail]:
        for maild in corpus_mails_DH[mail]["liste_CCs"] :
            edge = {
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(0.5),
                "data" : corpus_mails_DH[mail]["Geo_Topic"]["sujet_du_message"]+"  "+corpus_mails_DH[mail]["Geo_Topic"]["ref_physique_de_l_article"]
            }
            my_edges.append({ "data" : edge })
            
    for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
        edge = {
            "source" : corpus_mails_DH[mail]["mail_auteur"],
            "target" : maild,
            "weight" : float(1),
            "data" : corpus_mails_DH[mail]["Geo_Topic"]["sujet_du_message"]+"  "+corpus_mails_DH[mail]["Geo_Topic"]["ref_physique_de_l_article"]
        }
        my_edges.append({ "data" : edge })
        
        
        
print my_edges[:10]
# Out:
# {'Geo_Topic': {'content': '\nBonjour,J&#39;ai eu une tr\xc3\xa8s bonne exp\xc3\xa9rience avec eux sous Drupal 7, il y a quelques ann\xc3\xa9es : http://www.supersoniks.com/Je ne sais pas comment ils g\xc3\xa8rent le passage actuel \xc3\xa0 Drupal 8, en revanche.Cordialement,Jorge FinsIE MSH Val de LoireDe: &quot;Myriam TAZI&quot; &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n &gt;\xc3\x80: \n \n <!-- \n document.write("dh" + "@" + "groupes.renater.fr")\n // -->\n Envoy\xc3\xa9: Jeudi 8 Juin 2017 12:11:54Objet: [DH] Prestation de d\xc3\xa9veloppement sous drupalBonjour,la biblioth\xc3\xa8que de Sciences Po va d\xc3\xa9velopper un site sous drupal avec un prestataire dans le cadre d&#39;un projet de valorisation. Auriez vous des prestataires \xc3\xa0 conseiller ? avec qui vous avez eu une bonne exp\xc3\xa9rience ou des bons retours ?Merci d&#39;avance,-- Myriam TaziService Appui \xc3\xa0 la Recherche et Outils num\xc3\xa9riquesBiblioth\xc3\xa8queDirection des Ressources et de l&#39;Information Scientifique27 rue Saint-Guillaume 75337 Paris cedex 07 France&nbsp;T.&nbsp;+33 (0)1 45 49 56 28\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n www.sciencespo.fr---La liste DH est un service de l&#39;association francophone des humanit\xc3\xa9s num\xc3\xa9riques/digitales, Humanistica (http://www.humanisti.ca/).Adh\xc3\xa9rez \xc3\xa0 Humanistica !http://www.humanisti.ca/adhesion/\n', 'geo': [0, []]}, 'nom_auteur': 'Jorge Fins', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'jorge.fins@univ-tours.fr', 'ref_physique_de_l_article': './DHFRsample/2017-06/msg00011.html', 'sujet_du_message': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'date': datetime.datetime(2017, 6, 8, 13, 51, 2, tzinfo=tzlocal())}
# {'Geo_Topic': {'content': '\nCh\xc3\xa8res et Chers Coll\xc3\xa8gues,La deuxi\xc3\xa8me s\xc3\xa9ance du S\xc3\xa9minaire Epist\xc3\xa9mologies et Pratiques des Humanit\xc3\xa9s Num\xc3\xa9riques 2018, #EPHN2018, aura lieu le JEUDI 15 mars, de 10h \xc3\xa0 12h, \xc3\xa0 l\xe2\x80\x99Institut des Sciences de la Communication du CNRS, 20 rue Berbier-du-Mets, 75013 Paris. Marcello Vitali-Rosati (Universit\xc3\xa9 de Montr\xc3\xa9al) prononcera une conf\xc3\xa9rence intitul\xc3\xa9e  \xc2\xab&nbsp;Une API pour l&#39;Anthologie grecque: repenser le codex Palatinus \xc3\xa0 l&#39;\xc3\xa9poque du num\xc3\xa9rique&nbsp;\xc2\xbb. Xavier-Laurent Salvador\n (Univ Paris 13) sera son discutant. Les participants et auditeurs sont \nvivement invit\xc3\xa9s \xc3\xa0 contribuer \xc3\xa0 la discussion et aux \xc3\xa9changes.  Organis\xc3\xa9 par Claire Bourhis-Mariotti (Paris 8), Suzanne Dumouchel (ISCC-CNRS), Lauric Henneton (UVSQ) et Anne Vial (Univ de Rouen), ce s\xc3\xa9minaire est consacr\xc3\xa9 \xc3\xa0 la r\xc3\xa9flexion sur l&#39;\xc3\xa9pist\xc3\xa9mologie des Humanit\xc3\xa9s Num\xc3\xa9riques \xc3\xa0 partir de cas d&#39;\xc3\xa9tudes sp\xc3\xa9cifiques. Les s\xc3\xa9ances sont ouvertes \xc3\xa0 tous, sur inscription (par courrier \xc3\xa9lectronique) aupr\xc3\xa8s de Suzanne Dumouchel \n \n <!-- \n document.write("dumouchelsuzanne" + "@" + "yahoo.fr")\n // -->\n . En vous souhaitant une agr\xc3\xa9able semaine,Suzanne Dumouchel, pour le comit\xc3\xa9 d&#39;organisation@Suzdum Charg\xc3\xa9e de recherche ISCC/Huma-Num (CNRS)DARIAH Coordination Officehttps://movi.hypotheses.org/\n', 'geo': [0, []]}, 'nom_auteur': 'dumouchel suzanne', 'liste_mails_dests': ['legram@yahoogroupes.fr', 'culture.numerique@ml.free.fr', 'dh@groupes.renater.fr', 'listesocius@groups.openedition.org'], 'mail_auteur': 'dumouchelsuzanne@yahoo.fr', 'ref_physique_de_l_article': './DHFRsample/2018-03/msg00011.html', 'sujet_du_message': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'date': datetime.datetime(2018, 3, 6, 8, 37, 7, tzinfo=tzutc())}
# {'Geo_Topic': {'content': '\n\nChers membres de la liste,\n\nVoici l\'annonce d\'un poste de Senior Technical Officer \xc3\xa0 Maynooth \nUniversity, Irlande. D\xc3\xa9lai: 7 ao\xc3\xbbt.\n\n\nBel \xc3\xa9t\xc3\xa9,\n\nClaire Clivaz\n\nDe: Susan Schreibman via dariah-all \n&lt;\n \n <!-- \n document.write("dariah-all" + "@" + "gwdg.de")\n // -->\n &gt;\nObjet: [dariah-all] Job Opening: Senior Technology Officer, An Foras \nFeasa (Ireland)\n\nDate: 28 juillet 2016 15:49:12 UTC+2\n\xc3\x80: DARIAH-EU via dariah-all \n&lt;\n \n <!-- \n document.write("dariah-all" + "@" + "gwdg.de")\n // -->\n &gt;\nR\xc3\xa9pondre \xc3\xa0: Susan Schreibman \n&lt;\n \n <!-- \n document.write("susan.schreibman" + "@" + "gmail.com")\n // -->\n &gt;\n\nWe are seeking a creative and dedicated Senior Technical Officer with \nknowledge of and experience in methodologies used in the fields of \nDigital Humanities, Digital Heritage, Digital Libraries or related \nfields. This position provides an exciting opportunity for the selected \ncandidate to join a vibrant and growing team and contribute to research \nand teaching undertaken in An Foras Feasa, Maynooth University (Ireland).\n\n\nSome recent projects include Letters of 1916, Ireland\xe2\x80\x99s first public \nhumanities project, and Contested Memories: The Battle of Mount Street \nBridge which has been developed as a Virtual World, with content \ncurrently being repurposed as an Augmented Reality application for \nsecondary school students. Other projects include The Versioning Machine \nand #dariahTeach. An Foras Feasa is a member of the DIXiT Digital \nScholarly Editing network, the Virtual Heritage Network (Ireland), and \nthe Virtual Worlds Consortium.\n\n\nThe post holder will be expected to have skills and qualifications in \none or more of the following Digital Humanities methodologies, including \nbut not limited
a9ricault-Destouches -&nbsp;BP 11328 -&nbsp;F- 37 013 TOURS cedex&nbsp;02.47.36.77.80http://www.bvh.univ-tours.fr/http://cesr.univ-tours.fr/Attachment:\nPlaquette_TEI_SUFCO.pdf\nDescription: Adobe PDF document\n\n', 'geo': [0, []]}, 'nom_auteur': 'Laetitia Bontemps', 'liste_mails_dests': ['DH@cru.fr'], 'mail_auteur': 'laetitia.bontemps@univ-tours.fr', 'ref_physique_de_l_article': './DHFRsample/2011-07/msg00004.html', 'sujet_du_message': u': [DH] Stage initiation XML-TEI (Tours, octobre 2011)', 'date': datetime.datetime(2011, 7, 19, 15, 4, 42, tzinfo=tzoffset(u'BST', 3600))}
# {'Geo_Topic': {'content': '\n\nBonsoir,\nJ\'irai plus loin, en plus des emplois, j\'y ajouterai un annuaire des \nprestataires de services qui peuvent travailler pour le compte de \nprogramme de recherche. Class\xc3\xa9 selon une typologie claire, g\xc3\xa9r\xc3\xa9e par \nl\'asso. Il ne s\'agit pas de &quot;faire de la pub&quot; mais d\'avoir (peut \xc3\xaatre \ndans un espace r\xc3\xa9serv\xc3\xa9 aux adh\xc3\xa9rents) un r\xc3\xa9pertoire qui permettrai de \ntrouver un presta, avec peut-\xc3\xaatre des avis...\n\nCordialement,\n\nSt\xc3\xa9phane.\n\nLe 12/07/13 15:54, Olivier Le Deuff a \xc3\xa9crit :\n\nBonjour \xc3\xa0 tous\nL\'id\xc3\xa9e me parait int\xc3\xa9ressante en effet pour mesurer aussi l\'\xc3\xa9volution\ndans les profils \xc3\xa0 la fois au niveau statut mais aussi au niveau des\ncomp\xc3\xa9tences demand\xc3\xa9es. On pourrait donc \xc3\xa0 la fois rendre un service et\nproduire des analyses dessus. Je crois en effet qu\'il faut que\nl\'association offre des services. Je pense qu\'il serait int\xc3\xa9ressant dans\nce cadre de d\xc3\xa9velopper un service de questions-r\xc3\xa9ponses type FAQ sur les DH.\nIl faudrait sans doute aussi travailler le symbolique : faut-il remettre\ndes prix ? des aides ou des bourses? Une association peut aussi \xc3\xaatre un\nexcellent cadre pour d\xc3\xa9velopper une revue scientifique...\n\nBonne journ\xc3\xa9e\n\nOlivier Le Deuff.\nMa\xc3\xaetre de conf\xc3\xa9rences en SIC.\nLaboratoire Mica. Universit\xc3\xa9 de Bordeaux 3.\n  0687653127.\nwww.guidedesegares.info &lt;http://www.guidedesegares.info/&gt;\n\n&lt;http://www.fypeditions.com/du-tag-au-like/&gt;\n\n&lt;http://www.publie.net/fr/ebook/9782814504639/print-brain-technology&gt;\n&lt;http://www.fypeditions.com/la-formation-aux-cultures-numeriques/&gt;\n\n\n\n\n2013/7/12 Pierre Mounier \n&lt;\n \n <!-- \n document.write("pierre.mounier" + "@" + "openedition.org")\n // -->\n \n&lt;mailto:\n \n <!-- \n document.write("pierre.mounier" + "@" + "openedition.org")\n // -->\n &gt;&gt;\n\n    Bonjour,\n\n    une nouvelle mission qui serait tr\xc3\xa8s utile pourrait \xc3\xaatre assign\xc3\xa9e \xc3\xa0\n    cette association : g\xc3\xa9rer une base d\'emplois (offres et demandes)\n    pour les humanit\xc3\xa9s num\xc3\xa9riques. (L\'id\xc3\xa9e a germ\xc3\xa9 tout \xc3\xa0 l\'heure dans\n    une discussion avec Nicolas De Lavergne devant la machine \xc3\xa0 caf\xc3\xa9).\n\n    Qu\'en pensez-vous ?\n\n\n    --\n    Pierre Mounier\n    Directeur adjoint - Centre pour l\'\xc3\xa9dition \xc3\xa9lectronique ouverte\n    Associate Director - Centre for Open Electronic Publishing**\n\n    EHESS\n    190-198 avenue de France\n    75244 Paris cedex 13\n    Bureau/Office 447\n    Mob. 06 61 98 31 86\n    Twitter : @piotrr70\n\n\n\n    2013/7/9 Claire Clivaz \n&lt;\n \n <!-- \n document.write("claire.clivaz" + "@" + "unil.ch")\n // -->\n \n    \n&lt;mailto:\n \n <!-- \n document.write("claire.clivaz" + "@" + "unil.ch")\n // -->\n &gt;&gt;\n\n        Bonjour \xc3\xa0 tous!\n\n        Je pense qu\'avec cette suggestion de Pierre, on commence \xc3\xa0 avoir\n        un chemin int\xc3\xa9ressant un mod\xc3\xa8le de relation \xc3\xa0 ADHO. En tant que\n        membre du comit\xc3\xa9 EADH/LLC d\xc3\xa8s ao\xc3\xbbt 2013, je suis pr\xc3\xaate \xc3\xa0 tenter\n        la discussion sur ce point avec eux (assouplir la fameuse\n        obligation de la revue!), si le THATCamp de St-Malo va dans ce\n        sens. En tous cas, ne nous excluons pas des contacts DH\n        internationaux...\n\n        Une assembl\xc3\xa9e annuelle, parfait. Pour le lieu, \xc3\xa0 voir au fur et\n        \xc3\xa0 mesure des \xc3\xa9v\xc3\xa9nements ce qui est ad\xc3\xa9quat. Par exemple le\n        dh2014 \xc3\xa0 Lausanne peut offrir un cadre rassembleur pour une\n        prochaine assembl\xc3\xa9e (8-11 juillet 2014).\n\n        Je suis en faveur d\'un m\xc3\xa9lange d\'assembl\xc3\xa9e d\'individus et\n        d\'institutions: le lien aux institutions est tr\xc3\x ...
# {'Geo_Topic': {'content': '\nMerci \xc3\xa0 tous pour vos conseils!Bonne semaine,Myriam TaziLe\xc2\xa09 juin 2017 16:33, &quot;Gilles Pansu&quot; &lt;\n \n <!-- \n document.write("gpansu" + "@" + "gmail.com")\n // -->\n &gt; a \xc3\xa9crit\xc2\xa0:Bonjourje travaille pour le compte de l&#39;universit\xc3\xa9 Jussieu sur un projet de fusion des sites internet de l&#39;UPMC et de Paris 4. L&#39;UPMC a fait appel \xc3\xa0 la soci\xc3\xa9t\xc3\xa9 Atos/Open pour le d\xc3\xa9veloppement d&#39;un site sous Drupal. La prestation en est juste \xc3\xa0 ses d\xc3\xa9buts donc je ne peux pas encore juger de leur fiabilit\xc3\xa9. Mais il nous a \xc3\xa9t\xc3\xa9 propos\xc3\xa9 par l&#39;UGAP, ce qui veut dire qu&#39;ils ont de bonnes r\xc3\xa9f\xc3\xa9rences.CordialementGilles PansuConsultant ITAltran TechnologiesLe 8 juin 2017 \xc3\xa0 12:11, Myriam TAZI &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n &gt; a \xc3\xa9crit :Bonjour,la biblioth\xc3\xa8que de Sciences Po va d\xc3\xa9velopper un site sous drupal avec un prestataire dans le cadre d&#39;un projet de valorisation. Auriez vous des prestataires \xc3\xa0 conseiller ? avec qui vous avez eu une bonne exp\xc3\xa9rience ou des bons retours ?Merci d&#39;avance,--  \n  Myriam TaziService Appui \xc3\xa0 la Recherche et Outils num\xc3\xa9riquesBiblioth\xc3\xa8queDirection des Ressources et de l&#39;Information Scientifique27 rue Saint-Guillaume 75337 Paris cedex 07 France\xc2\xa0T.\xc2\xa0+33 (0)1 45 49 56 28\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n www.sciencespo.fr\n\n\n\n---\nLa liste DH est un service de l&#39;association francophone des humanit\xc3\xa9s num\xc3\xa9riques/digitales, Humanistica (http://www.humanisti.ca/).\n\nAdh\xc3\xa9rez \xc3\xa0 Humanistica !\nhttp://www.humanisti.ca/adhesion/\n\n\n---\nLa liste DH est un service de l&#39;association francophone des humanit\xc3\xa9s num\xc3\xa9riques/digitales, Humanistica (http://www.humanisti.ca/).\n\nAdh\xc3\xa9rez \xc3\xa0 Humanistica !\nhttp://www.humanisti.ca/adhesion/\n\n', 'geo': [0, []]}, 'nom_auteur': 'Myriam TAZI', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'myriam.tazi@sciencespo.fr', 'ref_physique_de_l_article': './DHFRsample/2017-06/msg00026.html', 'sujet_du_message': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'date': datetime.datetime(2017, 6, 12, 8, 42, 16, tzinfo=tzoffset(None, 7200))}
# {'Geo_Topic': {'content': '\n\n\n\ndear colleagues,\n\nwe are hiring!\n\nwe are delighted to offer 2 job positions in the framework of the project exploreAT!\nhttps://exploreat.usal.es/news\nat the austrian academy of sciences, austrian centre for digital humanities.\n\ncurious, open minded experimentalists, \npractitioners and innovators, \ncommitted to open innovation in science, are invited to join us and work with us in the very centre of vienna\nin close collaboration with our team members in salamanca (IT) and dublin (IE).\n\ndeadline for application: july, 15th 2017\nin case of any uncertainties, please do not hesitate to come back to me.\n\nwarm regards from vienna\neveline wandl-vogt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n***\n\n\xc3\xb6sterreichische akademie der wissenschaften (\xc3\x96AW) [austrian academy of sciences] | 1040 wien. AT | wohllebengasse 12-14/2 |\n\nhttp://www.oeaw.ac.at/acdh/ | http://wboe.oeaw.ac.at\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n', 'geo': [0, []]}, 'nom_auteur': 'Wandl-Vogt, Eveline', 'liste_mails_dests': ['exploreAT@oeaw.ac.at'], 'mail_auteur': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'ref_physique_de_l_article': './DHFRsample/2017-06/msg00057.html', 'sujet_du_message': u': [DH] exploreAT! job offer @ vienna: citizen science & DIY science; cultural lexicographer', 'date': datetime.datetime(2017, 6, 26, 20, 54, 38, tzinfo=tzutc())}
nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Le Hackathon se d\xc3\xa9roulera sans interruption du vendredi 7 juillet 2017 (midi pour l\xe2\x80\x99accueil des participants) au samedi 8 juillet (16h pour la cl\xc3\xb4ture). Il permettra aux trente participants\n s\xc3\xa9lectionn\xc3\xa9s d&#39;imaginer des sc\xc3\xa9narios innovants autour des donn\xc3\xa9es des diff\xc3\xa9rents projets et de concevoir des applications utilisant les donn\xc3\xa9es de l&#39;un des projets.\nD\xc3\xa9roul\xc3\xa9 du Hackathon:\n&nbsp;\n\nLes participants seront r\xc3\xa9partis au sein de 6 \xc3\xa9quipes (deux par projets) qui m\xc3\xaaleront d\xc3\xa9veloppeurs web et chercheur(e)s en humanit\xc3\xa9s ou expert(e)  ...
# {'Geo_Topic': {'content': '\n**Apologies for cross-posting**Dear DH\nresearchers,LINHD offers\nthe possibility to appoint a DH Post-Doctoral researcher in Madrid, Spain &nbsp;LINDH is a\nresearch center on Digital Humanities at UNED that works as a hub for\ninnovation, consultancy and training intended for researchers and projects in\nSpanish. It is a constituent member of the first Spanish Clarin-K Center and\nthe leader of the DARIAH proposal from the Spanish group. We are\noffering a 4 year Post-Doctoral position co-funded by the Madrid Community Government\nand by UNED to bring talented researchers to our university from foreign\nuniversities. Requirements\nfor this position are:-a PhD\ndegree (not before 2005)-having\nspent at least 3 years outside Spain, and at least 2 of the last 3 years in a foreign\nuniversity.-DH or\ncomputer science training through official degrees and/or courses, or proven\nexperience in the field.&nbsp;-at least 5 qualified publications.-Spanish\nlanguage abilities (not required, but very desirable) &nbsp;The closing\ndate for applications is 27th July 2016, and applications have to be sent via https://gestiona3.madrid.org/quadrivium/talento,\nbut it is a requirement to contact us by email to \n \n <!-- \n document.write("egonzalezblanco" + "@" + "linhd.uned.es")\n // -->\n \nas soon as possible and some days before the deadline in order to check\neligibility and guide you through the application process.Looking forward\nto hearing from you soon,Best regards&nbsp;Elena Gonz\xc3\xa1lez-BlancoDpto. de\nLiteratura Espa\xc3\xb1ola y Teor\xc3\xada de la Literatura, Despacho 722Facultad de\nFilolog\xc3\xada, UNEDPaseo Senda del\nRey 7\n28040 MADRIDtel. 91 3986873&nbsp;http://linhd.uned.eshttp://filindig.hypotheses.org/&nbsp;www.uned.es/personal/elenagonzalezblanco@elenagbg&nbsp;\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n&nbsp;\n', 'geo': [0, []]}, 'nom_auteur': 'Elena Gonz\xc3\xa1lez-Blanco', 'liste_mails_dests': ['humanist@lists.digitalhumanities.org', 'globaloutlookdh-l@uleth.ca', 'digitalclassicist@jiscmail.ac.uk', 'dm-l@uleth.ca', 'dhd@mailman.rrz.uni-hamburg.de', 'aiucd-l@humnet.unipi.it', 'air-l@aoir.org', 'institute@lists.uvic.ca', 'dh@groupes.renater.fr', 'tei-l@listserv.brown.edu', 'humanist-l@uleth.ca', 'centernet@lists.digitalhumanities.org', 'dhcarolina@listserv.unc.edu', 'humanidadesdigitais@gmail.com', 'website@hastac.org', 'southasia-dh@lists.globaloutlookdh.org', 'air-l@listserv.aoir.org', 'humanisticadh@gmail.com'], 'mail_auteur': 'elenagonzalezblanco@yahoo.es', 'ref_physique_de_l_article': './DHFRsample/2016-07/msg00016.html', 'sujet_du_message': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'date': datetime.datetime(2016, 7, 18, 0, 53, 35, tzinfo=tzutc())}
# {'Geo_Topic': {'content': '\n\n  \n  \n    Chers co-listiers,\n    \n    je vous transmets si-dessous un appel &agrave; communications &quot;Histories of\n    digital art&quot;.\n    \n    Bien &agrave; vous,\n    Fr&eacute;d&eacute;ric Clavert\n    \n      \n      -------- Message original --------\n      \n        \n          \n            Sujet: \n            Appel &agrave; communication : &laquo; The Histories of Digital Art &raquo;\n              (10-12 avril 2014, AAH, Londres)\n          \n          \n            Date&nbsp;: \n            Tue, 16 Jul 2013 23:04:00 +0200\n          \n          \n            De&nbsp;: \n            Laure Brossin &lt;\n \n <!-- \n document.write("laure.brossin" + "@" + "gmail.com")\n // -->\n &gt;\n          \n          \n            Pour&nbsp;: \n            \n \n <!-- \n document.write("frederic" + "@" + "clavert.net")\n // -->\n \n          \n        \n      \n      \n      \n      \n        Bonjour, \n          \n        \n        Ci-dessous, le lien vers un appel &agrave; communications qui pourrait\n        int&eacute;resser certains participants de la liste DH : \n        http://blog.apahau.org/appel-a-communication-the-histories-of-digital-art-10-12-avril-2014-aah-londres/\n        \n          \n          \n          Cordialement,\n          \n          -- \n            Laure Brossin\n            Doctorante en arch&eacute;ologie grecque\n            ATER en arch&eacute;ologie et histoire de l&#39;art grec\n            Universit&eacute; Paris-Sorbonne (Paris IV) / UMR 8167 &quot;Orient et\n            M&eacute;diterran&eacute;e&quot;\n          \n        \n      \n      \n    \n    \n  \n\n\n', 'geo': [0, []]}, 'nom_auteur': 'Fr\xc3\xa9d\xc3\xa9ric Clavert', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'frederic@clavert.net', 'ref_physique_de_l_article': './DHFRsample/2013-07/msg00029.html', 'sujet_du_message': u': [DH] Fwd: Appel \xe0 communication : \xab The Hi stories of Digital Art \xbb (10-12 avril 2014, AAH, L ondres)', 'date': datetime.datetime(2013, 7, 17, 10, 30, 2, tzinfo=tzoffset(None, 7200))}
# {'Geo_Topic': {'content': '\nBonjour,\n\ntoujours \xc3\xa0 propos de recherche reproductible, nous nous permettons de \nr\xc3\xa9activer cette discussion pour vous soumettre une tribune que Deuxi\xc3\xa8me labo \nvient de publier dans &quot;Le Monde&quot;, avec Yvan Stroppa (ing\xc3\xa9nieur CNRS / projet \nRunMyCode) : \nhttp://www.lemonde.fr/sciences/article/2013/07/15/pour-une-recherche-reproductible-publiez-vos-codes-et-donnees_3447825_1650684.html\n\nCet article porte plus sp\xc3\xa9cifiquement sur la recherche assist\xc3\xa9e par \nordinateur utilisant du code et des donn\xc3\x
roline Sporleder, \xc2\xa0University of G\xc3\xb6ttingenComputational Linguistics and Digital Humanities: Chances and Challenges11:35 - 12:20: Elena Gonz\xc3\xa1lez-Blanco, UNED (Madrid)From counting syllables to linked data. Interoperability and digital standardization as a new model to analyze European poetry: POSTDATA\xe2\x80\x9d.12:20 - 12:30: Wrap up** DetailsLinking Crowdsourced Transcription to Automated Handwriting Recognition: Lessons from Transcribe BenthamMelissa Terras, UCL (University College London)For nearly seven years, the Transcribe Bentham project has been generating high quality crowdsourced transcripts of the writings of the philosopher and jurist Jeremy Bentham (1748-1832), held at University College London, and latterly, the British Library. Now with nearly 6 million words transcribed by volunteers, little did we know at the outset that this project would provide an ideal, quality controlled dataset to provide &quot;ground truth&quot; for the development of Handwriting Technology Recognition. This paper will look at the past, present and future of automated handwriting analysis for documents, showing how our research on the EU framework 7 Transcriptorium, and now H2020 READ projects, is working towards a service to improve the searching and analysis of digitised manuscript collections across Europe, and reusing the data created by crowdsourced, volunteer labour, for machine learning purposes.Melissa Terras is Director of UCL Centre for Digital Humanities, Professor of Digital Humanities in UCL&#39;s Department of Information Studies, and Vice Dean of Research in UCL\xe2\x80\x99s Faculty of Arts and Humanities. Publications include &quot;Image to Interpretation: Intelligent Systems to Aid Historians in the Reading of the Vindolanda Texts&quot; (2006, Oxford University Press) and &quot;Digital Images for the Information Professional&quot; (2008, Ashgate) and she has co-edited various volumes such as &quot;Digital Humanities in Practice&quot; (Facet 2012) and &quot;Defining Digital Humanities: A Reader&quot; (Ashgate 2013). She is currently serving on the Board of Curators of the University of Oxford Libraries, and the Board of the National Library of Scotland, and is a Fellow of the Chartered Institute of Library and Information Professionals and Fellow of the British Computer Society. Her research focuses on the use of computational techniques to enable research in the arts and humanities that would otherwise be impossible. You can generally find her on twitter @melissaterras.Computational Linguistics and Digital Humanities: Chances and ChallengesCaroline Sporleder, University of G\xc3\xb6ttingenDigital Humanities (DH) is a field that has grown immensely in recent years. It is also a very diverse field covering -in its broadest definition- everything from corpus linguistics over computational philology and quantitative history to computational archaeology.Because the origin of the field is rooted in c ...
# {'Geo_Topic': {'content': "\nBonjour \xc3\xa0 tous,\n\nLe Centre Virtuel de la Connaissance sur l'Europe (CVCE) a ouvert deux\npostes de chercheurs en CDD (un an et six mois). Le premier chercheur\n(un an / niveau master) aura pour mission de d\xc3\xa9velopper un prototype\nd'API pour cvce.eu. Le second (six mois / post-doc) devra travailler sur\nl'\xc3\xa9dition de nos textes.\n\nLe d\xc3\xa9tail des offres est \xc3\xa0 consulter sur http://www.cvce.eu/ menu &quot;CVCE&quot;\npuis &quot;travailler au CVCE&quot;.\n\nN'h\xc3\xa9sitez pas \xc3\xa0 diffuser ces annonces le plus largement possible ou \xc3\xa0 me\ncontacter si vous avez besoin de renseignements.\n\nBien \xc3\xa0 vous,\nFr\xc3\xa9d\xc3\xa9ric Clavert\n\n\n--\nDocteur en histoire contemporaine\nCoordinateur du Digital Humanities Lab\nCentre Virtuel de la Connaissance sur l'Europe\n\n\n", 'geo': [0, []]}, 'nom_auteur': 'Fr\xc3\xa9d\xc3\xa9ric Clavert', 'liste_mails_dests': ['dh@cru.fr'], 'mail_auteur': 'frederic@clavert.net', 'ref_physique_de_l_article': './DHFRsample/2012-07/msg00002.html', 'sujet_du_message': u": [DH] Offres d'emploi - Deux chercheurs en Humani t\xe9s num\xe9riques au CVCE (Luxembourg)", 'date': datetime.datetime(2012, 7, 10, 10, 39, 11, tzinfo=tzoffset(None, 7200))}
# {'Geo_Topic': {'content': '\nBonjour \xc3\xa0 tousL&#39;id\xc3\xa9e me parait int\xc3\xa9ressante en effet pour mesurer aussi l&#39;\xc3\xa9volution dans les profils \xc3\xa0 la fois au niveau statut mais aussi au niveau des comp\xc3\xa9tences demand\xc3\xa9es. On pourrait donc \xc3\xa0 la fois rendre un service et produire des analyses dessus. Je crois en effet qu&#39;il faut que l&#39;association offre des services. Je pense qu&#39;il serait int\xc3\xa9ressant dans ce cadre de d\xc3\xa9velopper un service de questions-r\xc3\xa9ponses type FAQ sur les DH.\n\nIl faudrait sans doute aussi travailler le symbolique : faut-il remettre des prix ? des aides ou des bourses? Une association peut aussi \xc3\xaatre un excellent cadre pour d\xc3\xa9velopper une revue scientifique...\n\nBonne journ\xc3\xa9eOlivier Le Deuff. \n\nMa\xc3\xaetre de conf\xc3\xa9rences en SIC. Laboratoire Mica. Universit\xc3\xa9 de Bordeaux 3.\xc2\xa00687653127. www.guidedesegares.info\n\n\n\xc2\xa0\xc2\xa0\n\n\n2013/7/12 Pierre Mounier &lt;\n \n <!-- \n document.write("pierre.mounier" + "@" + "openedition.org")\n // -->\n &gt;\n\nBonjour,une nouvelle mission qui serait tr\xc3\xa8s utile pourrait \xc3\xaatre assign\xc3\xa9e \xc3\xa0 cette association : g\xc3\xa9rer une base d&#39;emplois (offres et demandes) pour les humanit\xc3\xa9s num\xc3\xa9riques. (L&#39;id\xc3\xa9e a germ\xc3\xa9 tout \xc3\xa0 l&#39;heure dans une discussion avec Nicolas De Lavergne devant la machine \xc3\xa0 caf\xc3\xa9).\n\n\n\nQu&#39;en pensez-vous ?-- \nPierre MounierDirecteur adjoint - Centre pour l&#39;\xc3\xa9dition \xc3\xa9lectronique ouverte\n\nAssociate Director - Centre for Open Electronic Publishing\nEHESS190-198 avenue de France75244 Paris cedex 13Bureau/Office 447Mob. 06 61 98 31 86Twitter : @piotrr70\n\n\n2013/7/9 Claire Clivaz &lt;\n \n <!-- \n document.write("claire.clivaz" + "@" + "unil.ch")\n // -->\n &gt;\n\n\n\nBonjour \xc3\xa0 tous!Je pense qu&#39;avec cette suggestion de Pierre, on commence \xc3\xa0 avoir un chemin int\xc3\xa9ressant un mod\xc3\xa8le de relation \xc3\xa0 ADHO. En tant que membre du comit\xc3\xa9 EADH/LLC d\xc3\xa8s ao\xc3\xbbt 2013, je suis pr\xc3\xaate \xc3\xa0 tenter la discussion sur ce point avec eux (assouplir la fameuse obligation de la revue!), si le THATCamp de St-Malo va dans ce sens. En tous cas, ne nous excluons pas des contacts DH internationaux
# ...
# {'Geo_Topic': {'content': '\n\n  \n  \n    Bonjour,\n      \n        \n           \n            Le labex Les pass\xc3\xa9s dans le pr\xc3\xa9sent lance un appel \xc3\xa0\n            candidatures pour un contrat post-doctoral d&#39;un an sur le\n            th\xc3\xa8me &quot;Corpus et savoirs num\xc3\xa9riques en arch\xc3\xa9ologie&quot;. Ce\n            contrat s&#39;inscrit dans le cadre du projet &quot;Archives\n\n\n\n\n              de fouilles de sites pr\xc3\xa9historiques et antiques&quot;,\n            port\xc3\xa9 par la Maison Arch\xc3\xa9ologie et Ethnologie,\n            Ren\xc3\xa9-Ginouv\xc3\xa8s. Le postdoctorant travaillera avec les\n            laboratoires ArScAn et Pr\xc3\xa9histoire &amp; Technologie.\n            L&#39;annonce est\xc2\xa0 disponible sur le site du labex, en\n\n\n\n\n\n              fran\xc3\xa7ais et en\n\n\n\n\n\n              anglais. La date limite de candidature est fix\xc3\xa9e au 1er\n\n\n\n              septembre 2015.\n            \n            Je reste \xc3\xa0 votre disposition pour tout compl\xc3\xa9ment\n            d&#39;information.\n            \n            Bien cordialement,\n            H\xc3\xa9l\xc3\xa8ne de Foucaud\n            -- \n              \n              \n              H\xc3\xa9l\xc3\xa8ne de Foucaud\n                Charg\xc3\xa9e de communication\n                Labex Les Pass\xc3\xa9s dans le\n                    pr\xc3\xa9sent\n                Universit\xc3\xa9 Paris Ouest Nanterre La D\xc3\xa9fense\n                  Maison Max Weber (b\xc3\xa2t T) - Bureau 209\n                  200 avenue de la R\xc3\xa9publique\n                  92001 Nanterre Cedex\n                  t\xc3\xa9l : +33 (0)1 40 97 41 84\n                  www.passes-present.eu\n                  Retrouvez le labex sur Facebook\n                  et Twitter\n              \n              \n            \n            \n          \n          \n          \n        \n        \n        \n      \n      \n      \n    \n    \n  \n\nAttachment:\njpg9tWg_HGKmU.jpg\nDescription: JPEG image\n\n', 'geo': [0, []]}, 'nom_auteur': 'H\xc3\xa9l\xc3\xa8ne de Foucaud', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'hdefouca@u-paris10.fr', 'ref_physique_de_l_article': './DHFRsample/2015-07/msg00009.html', 'sujet_du_message': u': [DH] Appel \xe0 candidatures postdoc "Corpus et savoirs num\xe9riques en arch\xe9ologie" - Labex Les pass\xe9s dans le pr\xe9sent', 'date': datetime.datetime(2015, 7, 8, 16, 44, 49, tzinfo=tzoffset(None, 7200))}
ique de domaine (environnement, culture, arch\xc3\xa9ologie, etc.)Cartographie et \xc3\xa9volution des Syst\xc3\xa8me d&#39;information scientifique et techniqueL\xe2\x80\x99analyse de contenu (Traitement Automatique du Langage et Fouille de texte)La recherche d&#39;information dans les donn\xc3\xa9es de la recherche pluridisciplinaireLa prise en compte du multilinguismeLa bibliom\xc3\xa9trie (d\xc3\xa9tection d&#39;affiliations; d\xc3\xa9sambigu\xc3\xafsation d&#39;auteurs...)La construction de ressources s\xc3\xa9mantiquesL&#39;annotation s\xc3\xa9mantique de documentsLa d\xc3\xa9tection de plagiatLes aspects juridiques li\xc3\xa9s ...
# {'Geo_Topic': {'content': '\n\n  \n  \n    Bonjour, \n    veuillez trouver ci jointes les premi&egrave;res informations concernant\n    THATCamp Saint-Malo.\n    Pour l&#39;&eacute;quipe organisatrice, \n    Nicolas Th&eacute;ly \n    \n    \n    \n    Le prochain THATCamp francophone se d&eacute;roulera les 18 et 19 octobre &agrave;\n    Saint-Malo au Ch&acirc;teau de la Briantais. La capacit&eacute; d&#8217;accueil est de\n    80 personnes. Des Olympiades DH, des ateliers formation (Gephi,\n    Processing, Arduino, Rapsberry), et un workshop seront &eacute;galement\n    organis&eacute;s les 17 et 20 octobre.\n    \n    \n    Th&eacute;matiques THATCamp Saint-Malo 2013\n    \n    THATCamp Saint-Malo 2013 souhaite aborder les relations entre\n    Humanit&eacute;s num&eacute;riques et Biblioth&egrave;ques : comp&eacute;tences en jeu,\n    &eacute;volutions des profils et dialogue des biblioth&egrave;ques avec la\n    recherche, pratiques informationnelles des chercheurs&#8230;\n    \n    THATCamp Saint-Malo 2013 a &eacute;galement pour ambition de rassembler\n    pour la premi&egrave;re fois la communaut&eacute; des arts et du design concern&eacute;e\n    par les humanit&eacute;s num&eacute;riques (conception de programme, design\n    d&#8217;interface, design d&#8217;information, cartographie).\n    \n    Enfin THATCamp Saint-Malo 2013 sera l&#8217;occasion pour la communaut&eacute;\n    francophone des humanit&eacute;s num&eacute;riques et/ou digitales de songer &agrave; se\n    constituer en association.\n    \n    Pour en savoir plus : \n    http://thatcamp35.hypotheses.org/17\n    \n    \n    -- \n      \n      \n        Nicolas Th&eacute;ly\n        Professeur en Arts, Esth&eacute;tique et Humanit&eacute;s Num&eacute;riques\n        Equipe d&#39;accueil Arts : Pratiques et Po&eacute;tiques\n      \n  \n\n\n\n', 'geo': [0, []]}, 'nom_auteur': 'Th\xc3\xa9ly Nicolas', 'liste_mails_dests': ['dh@groupes.renater.fr'], 'mail_auteur': 'nicolas.thely@univ-rennes2.fr', 'ref_physique_de_l_article': './DHFRsample/2013-07/msg00000.html', 'sujet_du_message': u': [DH] THATCamp Saint-Malo 18-19 octobre 2013', 'date': datetime.datetime(2013, 7, 2, 14, 15, 54, tzinfo=tzoffset(None, 7200))}
# [{'data': {'source': 'jorge.fins@univ-tours.fr', 'data': '\nBonjour,J&#39;ai eu une tr\xc3\xa8s bonne exp\xc3\xa9rience avec eux sous Drupal 7, il y a quelques ann\xc3\xa9es : http://www.supersoniks.com/Je ne sais pas comment ils g\xc3\xa8rent le passage actuel \xc3\xa0 Drupal 8, en revanche.Cordialement,Jorge FinsIE MSH Val de LoireDe: &quot;Myriam TAZI&quot; &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\
elsuzanne" + "@" + "yahoo.fr")\n // -->\n . En vous souhaitant une agr\xc3\xa9able semaine,Suzanne Dumouchel, pour le comit\xc3\xa9 d&#39;organisation@Suzdum Charg\xc3\xa9e de recherche ISCC/Huma-Num (CNRS)DARIAH Coordination Officehttps://movi.hypotheses.org/\n', 'target': 'legram@yahoogroupes.fr', 'weight': 1.0}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'data': '\nCh\xc3\xa8res et Chers Coll\xc3\xa8gues,La deuxi\xc3\xa8me s\xc3\xa9ance du S\xc3\xa9minaire Epist\xc3\xa9mologies et Pratiques des Humanit\xc3\xa9s Num\xc3\xa9riques 2018, #EPHN2018, aura lieu le JEUDI 15 mars, de 10h \xc3\xa0 12h, \xc3\xa0 l\xe2\x80\x99Institut des Sciences de la Communication du CNRS, 20 rue Berbier-du-Mets, 75013 Paris. Marcello Vitali-Rosati (Universit\xc3\xa9 de Montr\xc3\xa9al) prononcera une conf\xc3\xa9rence intitul\xc3\xa9e  \xc2\xab&nbsp;Une API pour l&#39;Anthologie grecque: repenser le codex Palatinus \xc3\xa0 l&#39;\xc3\xa9poque du num\xc3\xa9rique&nbsp;\xc2\xbb. Xavier-Laurent Salvador\n (Univ Paris 13) sera son discutant. Les participants et auditeurs sont \nviveme ...

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'L6fyqUuwFs_1qgULdsAOSb1LeHZstK2W0RjWhyP7q1F', u'userId': u'DaofbRenqYpqqNmtz'}}

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'ORHxACPHswJMDN5tTFw25n8z6kUXmjE32n4zI1W-_hy', u'userId': u'DaofbRenqYpqqNmtz'}}

# %%
print my_nodesdictList
# Out:
# [{'data': {'end': '2015-07-03T15:41:35+02:00', 'name': 'Fr\xc3\xa9d\xc3\xa9ric Clavert', 'weight': 1.0, 'start': '2012-07-10T10:39:11+02:00', 'lat': 46.9464269, 'lng': 7.4360048, 'id': 
625, 'lng': 2.330099300000001, 'id': 'm.bourgatte@icp.fr'}}, {'data': {'end': '2017-06-28T14:18:48+02:00', 'name': 'Dominique Stutzmann', 'weight': 1.0, 'start': '2012-07-02T08:25:19+02:00', 'lat': 48.8664818, 'lng': 2.2954043, 'id': 'dominique.stutzmann@irht.cnrs.fr'}}, {'data': {'end': '2018-03-22T09:24:41+01:00', 'name': 'Caroline Cance', 'weight': 1.0, 'start': '2018-03-21T09:24:41+01:00', 'lat': 47.8430441, 'lng': 1.9365067, 'id': 'caroline.cance@univ-orleans.fr'}}, {'data': {'end': '2018-03-10T11:17:31+01:00', 'name': 'J\xc3\xa9r\xc3\xb4me Darmont', 'weight': 1.0, 'start': '2018-03-09T11:17:31+01:00', 'lat': 45.7507518, 'lng': 4.8371866, 'id': 'jerome.darmont@univ-lyon2.fr'}}, {'data': {'end': '2018-03-13T12:39:06+01:00', 'name': 'Cristofoli Pascal', 'weight': 1.0, 'start': '2018-03-12T12:39:06+01:00', 'lat': 48.850174, 'lng': 2.3268487, 'id': 'pascal.cristofoli@ehess.fr'}}, {'data': {'end': '2015-07-10T12:05:28+02:00', 'name': 'Mathieu Andro', 'weight': 1.0, 'start': '2015-07-09T12:05:28+02:00', 'lat': 48.8021553, 'lng': 2.0872588, 'id': 'Mathieu.Andro@versailles.inra.fr'}}, {'data': {'end': '2017-06-22T17: ...

# %%
title = "alphaDH"
create_topogram(title, my_nodesdictList, my_edges)
# Out:
# Creating topogram 'alphaDH'
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'alphaDH', u'userId': u'DaofbRenqYpqqNmtz', u'_id': u'b2jzkxmhLQKwokirn', u'slug': u'alphadh', u'createdAt': u'2018-04-23T02:38:52.459Z'}, u'statusCode': 200}
# topogram ID : b2jzkxmhLQKwokirn
# 164 nodes deleted
# {u'status': u'success', 'status_code': 200, u'data': [u'LzkupztotxJB7cRv8', u'gnBE2AWGyzytgARBH', u'AWAhhS9z3LWLy8LR3', u's6qqgpPjsMx47DtAM', u'wyBDYLvpf2SXZQkTa', u'psTbbNAuXwBEmo628', u'E4GzP2mBvcuHBfHBQ', u'PmeNprFTbmWWCHurQ', u'zxjyH3XEwFQvRPHxR', u'seERxe8uq7zBqokTg', u'dXQdEu6DcedbH57rm', u'KHFT7RE5cNJYP63PS', u'cFfFTGPcuNFTL2fGo', u'F26jdBrFhYuEPauaf', u'dAdKYJ2DPEHWrF5X4', u'w6n3gDyGP5FsCTP87', u'MzZCt3TJYLHTwt5Wr', u'bdeXqAsmYAhgDzwrh', u'Hu8CCR4uHcHbEqyzZ', u'ETP6bTtHrd5cSBFK9', u'PrbZWAiGjpQop75K6', u'jKNopQNWYL59MFox5', u'pzutgEvLi2tv9HiWB', u'iKfavbcZkos5irzsZ', u'2xZh6XAze65zZypWN', u'FeHLu4Fxybk95M2jp', u'KFrn9CgME5qvXb3LX', u'gXsJr2LJ4aSd6Pyh
oL6pN8QzZxQcSQDC', u'YgJ6CmR4bTqH6Jm6M', u'Q53gA4xNpCS7Cg4jr', u'8GMLuHx7F8PTdTFMY', u'Mce5EiWphvmFFwZ56', u'PNoRaL4EBKv6ZKYpE', u'Ttd3oMJhCHpok3CPW', u'naBpjqimuHeQXZBqd', u'KS9H2gN2p8bWkvp4b', u'dbMMeRBvNq2YiEWJs', u'HyPcaokbXgtpPuEj7', u'ximudNbogbtPwoSLv', u'hxgDLvcDNKjavpBXY', u'PEYeFr8jXLW8NNzZo', u'oAQm7PFnooaqsHtRL', u'wp3HYR5NJhpqYbTfn', u'ugCKuZ8j24xMtkn2T', u'5eL2Hw9Cu8yMLoWHP', u'rBk9tiyJfnqkhEDmm', u'iZxB2JzGeqG3cKew4', u'yLpyMdk6ouP6enXnE', u'pWxWAumG4ZE4c6QCg', u'fHcvuAKoZ9gEqXLxW', u'Dy4dr3gpdvoFYNEyM', u'soizu5EKndN6NLXdk', u'Z4FuRyGWrTziH2Pkk', u'mfBc4Pr2JaDJyKiMy', u'9AitPHCyktcthQxrC', u'Y3sK8GwwGSoWoNkk8', u'6rX48qJkttAkbdkkQ', u'RuHhGeJPLQwti8JYT', u'5yCNtSckExJhRjHRA', u'mzKGNLRBFyX686ixo', u'z8QdaYyCKkaE5yE3Q', u'HoEN5Ati9ji3bFTsr', u'HkoEyMWBkPcoryKW8', u'RvGxA3zbZoki9MP2Z', u'5iLCFAsFu9vqskqSf', u'Haw2GrsFNdSGDeDB4', u'jkNSMH9bz8hXQNE3G', u'45zL4vbLK3wAdyKm4', u'zW7xdiqMnePkRHi9z', u'acwZsNZFKibssF74G', u'oHt3qdb5bcQEfSDM8', u'TR7q2DvEZJQdbh3Zp', u'CKde948FtErr5kCX2', u'S8H3cSdEuew4RJLFk', u'PvmgKQpk8oaTaWM3d', u'78k4es2fA4kvCnoGT', u'cMCTZi5fgfyvuBfQt', u'Wp9rwX43graH8hxAy', u'9vaT5n6DGSqod3PnR', u'QDysn8gc5NEWu3z5j', u'aRXQmKEev62yrhbFQ', u'SctiHajZn8FWfDa3b'], u'statusCode': 201}
# 164 nodes created.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-b4edb4943127> in <module>()
#       1 title = "alphaDH"
# ----> 2 create_topogram(title, my_nodesdictList, my_edges)
#
# <ipython-input-91-410c73c9aa45> in create_topogram(title, nodes, edges)
#      27     print r
#      28     print "%s nodes created."%len(r["data"])
# ---> 29     r = topogram.create_edges(topogram_ID, edges)
#      30     print "%s edges created."%len(r["data"])
#      31
#
# /home/goonieb/anaconda2/lib/python2.7/site-packages/topogram_client/__init__.pyc in create_edges(self, topogramId, edges)
#     184         """POST Create a bunch of edges. Returns the created edges"""
#     185         assert type(edges) is list
# --> 186         return self.make_request("POST", "edges", { "topogramId" : topogramId, "edges" : edges})
#     187
#     188
#
# /home/goonieb/anaconda2/lib/python2.7/site-packages/topogram_client/__init__.pyc in make_request(self, method, path, data)
#      55
#      56         if r.status_code >= 500 : # handle 403 error
# ---> 57             err = "%s - Error : %s"%(r.status_code, r.json()["message"])
#      58             log.error(err)
#      59             raise ValueError(err)
#
# /home/goonieb/anaconda2/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# /home/goonieb/anaconda2/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# /home/goonieb/anaconda2/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# --> 364         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     365         end = _w(s, end).end()
#     366         if end != len(s):
#
# /home/goonieb/anaconda2/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     380             obj, end = self.scan_once(s, idx)
#     381         except StopIteration:
# --> 382             raise ValueError("No JSON object could be decoded")
#     383         return obj, end
#
# ValueError: No JSON object could be decoded

# %%
    #print artist
    

        dates_coords.append( [latitude,longitude])
    #print "datec",date_coords
    datapushed={}
    datapushed["dates_coords_lat_long"]=dates_coords
    datapushed["id"]=artist["_id"]
    datapushed["slug"]=artist["slug"]
    print datapushed
    dict_coords[artist["slug"]]=datapushed
print dict_coords



with open('data/test_data_nodes.csv') as f :
    reader = DictReader(f)
    for n in reader :
        node = {
            "id" : n["id"],
            "name" : n["name"],
            "lat" : float(n["lat"]),
            "lng" : float(n["lng"]),
            "weight" : float(n["weight"]),
            "start" : n["year_start"],
            "end" : n["year_stop"]
            }
        my_nodes.append({ "data" : node })

print my_nodes

with open('data/test_data_edges.csv') as f :
    reader = DictReader(f)
    for e in reader :
        edge = {
            "source" : e["source"],
            "target" : e["target"],
            "weight" : float(e["weight"])
        }
        my_edges.append({ "data" : edge })

# print my_edges

def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)

    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)

create_topogram("Geo-time network", my_nodes, my_edges)
