# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
import pickle
with open('dict_corrected_DH.obj', 'rb') as handle:
    dict_corrected_DH = pickle.load(handle)
with open('geocoded_locs.obj', 'rb') as handle:
    geocoded_locs = pickle.load(handle)
import pickle
with open('corpus_mails_DH.obj', 'rb') as handle:
    corpus_mails_DH = pickle.load(handle)
import pickle
with open('dict_noms_mails_debut_fin.obj', 'rb') as handle:
    dict_noms_mails_debut_fin = pickle.load(handle)

# %%
    
print str(dict_corrected_DH)[:1000],"\n"
print str(geocoded_locs)[:1000],"\n"
print str(corpus_mails_DH)[:1000],"\n"
print str(dict_noms_mails_debut_fin)[:1000],"\n"
# Out:
# {'lecnam.net': {u'geometry': {u'location': {u'lat': '46.9464269', u'lng': '7.4360048'}}}, 'design.ulaval.ca': {u'geometry': {u'location': {u'lat': 46.812707, u'lng': -71.225985}, u'viewport': {u'northeast': {u'lat': 46.8140559802915, u'lng': -71.2246360197085}, u'southwest': {u'lat': 46.8113580197085, u'lng': -71.2273339802915}}, u'location_type': u'GEOMETRIC_CENTER'}, u'address_components': [{u'long_name': u'Qu\xe9bec', u'short_name': u'Qu\xe9bec', u'types': [u'locality', u'political']}, {u'long_name': u'Qu\xe9bec', u'short_name': u'QC', u'types': [u'administrative_area_level_1', u'political']}, {u'long_name': u'Canada', u'short_name': u'CA', u'types': [u'country', u'political']}, {u'long_name': u'G1K 3G8', u'short_name': u'G1K 3G8', u'types': [u'postal_code']}], u'place_id': u'ChIJDWgVp3GWuEwRKa5K0WLTYnk', u'formatted_address': u'295 Boulevard Charest Est, bureau 090, Qu\xe9bec, QC G1K 3G8, Canada', u'types': [u'establishment', u'point_of_interest', u'university']}, 'dhi-paris.fr': {
#
# {'mines.org': {u'geometry': {u'location': {u'lat': 48.845585, u'lng': 2.339632}, u'viewport': {u'northeast': {u'lat': 48.8469339802915, u'lng': 2.340980980291502}, u'southwest': {u'lat': 48.8442360197085, u'lng': 2.338283019708498}}, u'location_type': u'ROOFTOP'}, u'address_components': [{u'long_name': u'60', u'types': [u'street_number'], u'short_name': u'60'}, {u'long_name': u'Boulevard Saint-Michel', u'types': [u'route'], u'short_name': u'Boulevard Saint-Michel'}, {u'long_name': u'Paris', u'types': [u'locality', u'political'], u'short_name': u'Paris'}, {u'long_name': u'Paris', u'types': [u'administrative_area_level_2', u'political'], u'short_name': u'Paris'}, {u'long_name': u'\xcele-de-France', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'\xcele-de-France'}, {u'long_name': u'France', u'types': [u'country', u'political'], u'short_name': u'FR'}, {u'long_name': u'75006', u'types': [u'postal_code'], u'short_name': u'75006'}], u'place_id': u'ChIJa8WGQsNx5kcR2
#
# {'./DHFRsample/2017-06/msg00011.html': {'Geo_Topic': {'content': '\nBonjour,J&#39;ai eu une tr\xc3\xa8s bonne exp\xc3\xa9rience avec eux sous Drupal 7, il y a quelques ann\xc3\xa9es : http://www.supersoniks.com/Je ne sais pas comment ils g\xc3\xa8rent le passage actuel \xc3\xa0 Drupal 8, en revanche.Cordialement,Jorge FinsIE MSH Val de LoireDe: &quot;Myriam TAZI&quot; &lt;\n \n <!-- \n document.write("myriam.tazi" + "@" + "sciencespo.fr")\n // -->\n &gt;\xc3\x80: \n \n <!-- \n document.write("dh" + "@" + "groupes.renater.fr")\n // -->\n Envoy\xc3\xa9: Jeudi 8 Juin 2017 12:11:54Objet: [DH] Prestation de d\xc3\xa9veloppement sous drupalBonjour,la biblioth\xc3\xa8que de Sciences Po va d\xc3\xa9velopper un site sous drupal avec un prestataire dans le cadre d&#39;un projet de valorisation. Auriez vous des prestataires \xc3\xa0 conseiller ? avec qui vous avez eu une bonne exp\xc3\xa9rience ou des bons retours ?Merci d&#39;avance,-- Myriam TaziService Appui \xc3\xa0 la Recherche et Outils num
#
# {'Pierre Mounier': [['pierre.mounier@openedition.org', datetime.datetime(2013, 7, 5, 10, 9, 24, tzinfo=tzoffset(None, 7200)), datetime.datetime(2018, 3, 5, 11, 11, tzinfo=tzoffset(None, 3600))], ['pierre.mounier@ehess.fr', datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200)), datetime.datetime(2013, 7, 5, 12, 13, 22, tzinfo=tzoffset(None, 7200))]], 'aude.da-cruz-lima': [['aude.da-cruz-lima@mae.u-paris10.fr', datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 28, 9, 38, 17, tzinfo=tzoffset(None, 7200))]], 'Thierry Poibeau': [['thierry.poibeau@ens.fr', datetime.datetime(2018, 3, 5, 7, 56, 29, tzinfo=tzoffset(None, 3600)), datetime.datetime(2018, 3, 26, 9, 17, tzinfo=tzoffset(None, 7200))]], 'delegue.general@adbu.fr': [['delegue.general@adbu.fr', datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200)), datetime.datetime(2017, 6, 13, 15, 36, 29, tzinfo=tzoffset(None, 7200))]], 'Dominique Stutzmann': [['domini

# %%
from datetime import timedelta
import datetime
# credentials
TOPOGRAM_URL = "http://localhost:3000"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
title = "DH_studies_map"
my_nodesdict = {}
my_nodes= []
my_edges = []


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'



###FOR NODES
print len(dict_noms_mails_debut_fin)
print dict_noms_mails_debut_fin['Claire Clivaz']
#claire.clivaz@unil.ch
# Out:
# 167
# [['claire.clivaz@unil.ch', datetime.datetime(2013, 7, 9, 15, 28, 26, tzinfo=tzoffset(None, 7200)), datetime.datetime(2014, 7, 12, 12, 31, 28, tzinfo=tzoffset(None, 7200))], ['claire.clivaz@sib.swiss', datetime.datetime(2016, 7, 20, 16, 54, 26, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 7, 29, 13, 21, 16, tzinfo=tzoffset(None, 7200))]]

# %%
for name in dict_noms_mails_debut_fin:
    
    for mail_array in dict_noms_mails_debut_fin[name]:
        print mail_array[0]
        mail_address=mail_array[0]
        start= mail_array[1]
        end= mail_array[2]
        mail_address_suffix=mail_address.split("@",1)[1]
        print mail_address_suffix
        lat=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lat"]
        lng=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lng"]
        print  lat,lng
        
        print "-------"
         
        try: 
            #print start
            #print end
            node = {
                        "id" : mail_address,
                        "name" : name,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),
                        "start" : start.isoformat(),

                       "end" : (end+timedelta(days=1)).isoformat()
                        }
        except AttributeError as e:
            print "STARTSTART",start
            #print datetime.datetime(start[:-5])
            print e

            node = {
                        "id" : mail_address,
                        "name" : name,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),
                        "start" : datetime.datetime(2012, 3, 2, 15, 19, 10).isoformat(),

                       "end" : datetime.datetime(2018, 3, 2, 15, 19, 10).isoformat()
                        }
            print node
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
    
print len(my_nodesdict)
# Out:
# pierre.mounier@openedition.org
# openedition.org
# 46.9464269 7.4360048
# -------
# pierre.mounier@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# aude.da-cruz-lima@mae.u-paris10.fr
# mae.u-paris10.fr
# 48.9041663 2.2098627
# -------
# thierry.poibeau@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# delegue.general@adbu.fr
# adbu.fr
# 46.9464269 7.4360048
# -------
# dominique.stutzmann@irht.cnrs.fr
# irht.cnrs.fr
# 48.8664818 2.2954043
# -------
# martin.grandjean@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
# Nicolas.Larrousse@huma-num.fr
# huma-num.fr
# 48.850142 2.3269827
# -------
# judith.hannoun@univ-amu.fr
# univ-amu.fr
# 43.293621 5.358066
# -------
# ottaviano.nancy@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# nadine.dardenne@cnrs.fr
# cnrs.fr
# 45.203453 5.700236
# -------
# colette.cadiou@irstea.fr
# irstea.fr
# 45.7627097 3.1110909
# -------
# yamina.bensaadoune@univ-rouen.fr
# univ-rouen.fr
# 49.4583047 1.0688892
# -------
# francoise.paquienseguy@sciencespo-lyon.fr
# sciencespo-lyon.fr
# 45.7470623 4.8357091
# -------
# cecile.rodrigues@cnrs.fr
# cnrs.fr
# 45.203453 5.700236
# -------
# francesco.beretta@ish-lyon.cnrs.fr
# ish-lyon.cnrs.fr
# 45.7470731 4.8355436
# -------
# michel.bernard@univ-paris3.fr
# univ-paris3.fr
# 48.8397962 2.3538807
# -------
# francois.bavaud@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
# beauguittelaurent@hotmail.com
# hotmail.com
# 47.6393769 -122.1282558
# -------
# audrey.baneyx@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# jouni.tuominen@helsinki.fi
# helsinki.fi
# 46.9464269 7.4360048
# -------
# jouni.tuominen@aalto.fi
# aalto.fi
# 46.9464269 7.4360048
# -------
# Serge.Noiret@EUI.eu
# EUI.eu
# 43.803079 11.282959
# -------
# svhoolan@ulb.ac.be
# ulb.ac.be
# 50.8132068 4.3822222
# -------
# olfa.lamloum@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# jerome.valluy@univ-paris1.fr
# univ-paris1.fr
# 48.8469373 2.344468
# -------
# caroline.muller@univ-reims.fr
# univ-reims.fr
# 49.2559131 4.0408547
# -------
# remi.jimenes@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# anne-laure.brisac@inha.fr
# inha.fr
# 48.8663364 2.3388561
# -------
# STARTSTART  Fri, 13 Jul 2012 09:56:18 +0100
# 'str' object has no attribute 'isoformat'
# {'end': '2018-03-02T15:19:10', 'name': 'Anne-Laure Brisac-Chra\xc3\xafbi', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.86633639999999, 'lng': 2.3388561, 'id': 'anne-laure.brisac@inha.fr'}
# lisette.calderan@inria.fr
# inria.fr
# 45.7862471 4.8797456
# -------
# gpansu@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# hdefouca@u-paris10.fr
# u-paris10.fr
# 48.903399 2.211274
# -------
# laetitia.bontemps@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# aurelie.olivesi@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# manuel.zacklad@cnam.fr
# cnam.fr
# 48.866746 2.3554313
# -------
# vial.stephane@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# cynthia.pedroja@meshs.fr
# meshs.fr
# 50.638053 3.0712393
# -------
# richard.walter@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# oledeuff@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# Christine.michel@insa-lyon.fr
# insa-lyon.fr
# 45.782938 4.878273
# -------
# laurence.rageot@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# christine.chadier@univ-lyon3.fr
# univ-lyon3.fr
# 45.748149 4.860553
# -------
# emilien.ruiz@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# Guillaume.Blum@design.ulaval.ca
# design.ulaval.ca
# 46.812707 -71.225985
# -------
# antonio.casilli@googlemail.com
# googlemail.com
# 37.4219999 -122.0840575
# -------
# antonio.casilli@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# gerald.kembellec@lecnam.net
# lecnam.net
# 46.9464269 7.4360048
# -------
# jea.herzog@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# ncasanova@mmsh.univ-aix.fr
# mmsh.univ-aix.fr
# 43.5285412 5.4182645
# -------
# claire.clivaz@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
# claire.clivaz@sib.swiss
# sib.swiss
# 46.1935479 17
# -------
# fatihaidmhand@yahoo.es
# yahoo.es
# 46.9464269 7.4360048
# -------
# yosra.ghliss17@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# projet.iglouvre@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# martaseve@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# julia.bonaccorsi@univ-lyon2.fr
# univ-lyon2.fr
# 45.7507518 4.8371866
# -------
# annael.le-poullennec@psl.eu
# psl.eu
# 48.8864969 2.3130983
# -------
# emmanuelguez@yahoo.fr
# yahoo.fr
# 46.227638 2.213749
# -------
# Francoise.Blum@univ-paris1.fr
# univ-paris1.fr
# 48.8469373 2.344468
# -------
# caroline.cance@univ-orleans.fr
# univ-orleans.fr
# 47.8430441 1.9365067
# -------
# viera.rebolledodhuin@free.fr
# free.fr
# 46.8051945 1.6860012
# -------
# isabelle.thiebau@univ-lille2.fr
# univ-lille2.fr
# 50.63166 3.0751371
# -------
# alexandre.moatti@mines.org
# mines.org
# 48.845585 2.339632
# -------
# slh@ens-lyon.fr
# ens-lyon.fr
# 45.7298448 4.8285332
# -------
# benoit.epron@enssib.fr
# enssib.fr
# 45.7801398 4.8625124
# -------
# emmanuelle.morlock@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# jorge.fins@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# nicolasthelyrennes2@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# raphaelle.bour@irit.fr
# irit.fr
# 43.5617391 1.4680172
# -------
# caroline.rossi@univ-grenoble-alpes.fr
# univ-grenoble-alpes.fr
# 45.1914198 5.7672724
# -------
# gerald.kembellec@cnam.fr
# cnam.fr
# 48.866746 2.3554313
# -------
# mehdi.khamassi@upmc.fr
# upmc.fr
# 48.8471036 2.357499
# -------
# carmen.brando@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# sarah.cadorel@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# listes@ahicf.com
# ahicf.com
# 46.9464269 7.4360048
# -------
# recherche.coordination@bnf.fr
# bnf.fr
# 48.8335842 2.3757659
# -------
# pascal.cristofoli@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# nicolas.thely@univ-rennes2.fr
# univ-rennes2.fr
# 48.1179154 -1.7028658
# -------
# irihs@univ-rouen.fr
# univ-rouen.fr
# 49.4583047 1.0688892
# -------
# myriam.tazi@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# spadinielena@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# joel.marchand@huma-num.fr
# huma-num.fr
# 48.850142 2.3269827
# -------
# laurent.romary@inria.fr
# inria.fr
# 45.7862471 4.8797456
# -------
# elodie.faath@openedition.org
# openedition.org
# 46.9464269 7.4360048
# -------
# Frederic.Clavert@unil.ch
# unil.ch
# 46.5210895 6.5801606
# -------
# frederic@clavert.net
# clavert.net
# 46.9464269 7.4360048
# -------
# aurelie.olivesi@wanadoo.fr
# wanadoo.fr
# 44.556284 -0.248764
# -------
# antoine.blanchard@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# espejosuros.javier@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# emmanuelle.duwez@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# beatrice.markhoff@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# stamkou@free.fr
# free.fr
# 46.8051945 1.6860012
# -------
# graham.ranger@univ-avignon.fr
# univ-avignon.fr
# 43.9492289 4.8181272
# -------
# gresillon@cmb.hu-berlin.de
# cmb.hu-berlin.de
# 52.517883 13.3936551
# -------
# camillemonnier33@hotmail.com
# hotmail.com
# 47.6393769 -122.1282558
# -------
# cecile.boulaire@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# elinaleblanc3007@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# georges-xavier.blary@unilim.fr
# unilim.fr
# 45.826307 1.258409
# -------
# amelie.vairelles@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# florence.clavaud@free.fr
# free.fr
# 46.8051945 1.6860012
# -------
# e.salvatori@mediev.unipi.it
# mediev.unipi.it
# 43.712207 10.405946
# -------
# alexandre.hocquet@univ-lorraine.fr
# univ-lorraine.fr
# 49.1203429 6.1627983
# -------
# pierazzo@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# jerome.darmont@univ-lyon2.fr
# univ-lyon2.fr
# 45.7507518 4.8371866
# -------
# isabelle.thiebau@univ-lille2.fr
# univ-lille2.fr
# 50.63166 3.0751371
# -------
# marin.dacos@openedition.org
# openedition.org
# 46.9464269 7.4360048
# -------
# marin.dacos@revues.org
# revues.org
# 46.9464269 7.4360048
# -------
# marjorie.burghart@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# enrico.natale@infoclio.ch
# infoclio.ch
# 46.9464269 7.4360048
# -------
# delphine.cavallo@univ-amu.fr
# univ-amu.fr
# 43.293621 5.358066
# -------
# stephane.pouyllau@cnrs.fr
# cnrs.fr
# 45.203453 5.700236
# -------
# stephane.pouyllau@huma-num.fr
# huma-num.fr
# 48.850142 2.3269827
# -------
# clarisse_bardiot@me.com
# me.com
# 37.3316756 -122.030189
# -------
# clarisse_bardiot@mac.com
# mac.com
# 37.3316756 -122.030189
# -------
# stephane.lamasse@univ-paris1.fr
# univ-paris1.fr
# 48.8469373 2.344468
# -------
# MKoenig@dhi-paris.fr
# dhi-paris.fr
# 48.8586809 2.3635197
# -------
# cecile.soudan@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# Eveline.Wandl-Vogt@oeaw.ac.at
# oeaw.ac.at
# 48.2088405 16.3771845
# -------
# aamonnz@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# jahjah.marc@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# jf.omhover@histographe.com
# histographe.com
# 46.9464269 7.4360048
# -------
# marjorie.burghart@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# sandrine.clerisse@cnrs.fr
# cnrs.fr
# 45.203453 5.700236
# -------
# sclerisse@parisnanterre.fr
# parisnanterre.fr
# 48.903399 2.211274
# -------
# formation.continue@enc-sorbonne.fr
# enc-sorbonne.fr
# 48.8673191 2.3374701
# -------
# paul.girard@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# elenagonzalezblanco@yahoo.es
# yahoo.es
# 46.9464269 7.4360048
# -------
# elisabeth.belmas@wanadoo.fr
# wanadoo.fr
# 44.556284 -0.248764
# -------
# iglouvremb@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# claire.lemercier@sciencespo.fr
# sciencespo.fr
# 48.8540917 2.3283745
# -------
# vanessa.juloux@ephe.sorbonne.fr
# ephe.sorbonne.fr
# 48.8483803 2.3434592
# -------
# ghislain.sillaume@cvce.eu
# cvce.eu
# 49.5432608 5.9262592
# -------
# secardinolivier@yahoo.fr
# yahoo.fr
# 46.227638 2.213749
# -------
# nicolas.legrand@obspm.fr
# obspm.fr
# 48.8358925 2.3365123
# -------
# michaelesinatra@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# mahe.annaig@wanadoo.fr
# wanadoo.fr
# 44.556284 -0.248764
# -------
# jbcamps@hotmail.com
# hotmail.com
# 47.6393769 -122.1282558
# -------
# sylvain.laube@univ-brest.fr
# univ-brest.fr
# 48.3980356 -4.5076415
# -------
# adeline.joffres@huma-num.fr
# huma-num.fr
# 48.850142 2.3269827
# -------
# dbernhard@unistra.fr
# unistra.fr
# 48.5790692 7.7664545
# -------
# muriel.foulonneau@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# marta.materni@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# marie-noelle.polino@ahicf.com
# ahicf.com
# 46.9464269 7.4360048
# -------
# antoine.courtin@mac.com
# mac.com
# 37.3316756 -122.030189
# -------
# raphaelle.krummeich@univ-rouen.fr
# univ-rouen.fr
# 49.4583047 1.0688892
# -------
# inatheque@ina.fr
# ina.fr
# 48.8757828 2.3503673
# -------
# arno.zucker@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# Daniel.Stoekl@ephe.sorbonne.fr
# ephe.sorbonne.fr
# 48.8483803 2.3434592
# -------
# amel.fraisse@univ-lille3.fr
# univ-lille3.fr
# 50.627577 3.126726
# -------
# Mathieu.Andro@versailles.inra.fr
# versailles.inra.fr
# 48.8021553 2.0872588
# -------
# clemence.jacquot@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# stefanev@club-internet.fr
# club-internet.fr
# 48.8961335 2.3812061
# -------
# dumouchelsuzanne@yahoo.fr
# yahoo.fr
# 46.227638 2.213749
# -------
# stephane.loret@univ-nantes.fr
# univ-nantes.fr
# 47.2095499 -1.5559718
# -------
# anne.baillot@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# francois.theron@uvsq.fr
# uvsq.fr
# 48.799627 2.1415644
# -------
# florent.laroche@ec-nantes.fr
# ec-nantes.fr
# 47.248066 -1.5501304
# -------
# johann.holland@campus-condorcet.fr
# campus-condorcet.fr
# 48.9081455 2.3665891
# -------
# listes@ahicf.com
# ahicf.com
# 46.9464269 7.4360048
# -------
# sandrine.breuil@univ-tours.fr
# univ-tours.fr
# 47.3838055 0.6738728
# -------
# laurens@ehess.fr
# ehess.fr
# 48.850174 2.3268487
# -------
# maud.ingarao@ens-lyon.fr
# ens-lyon.fr
# 45.7298448 4.8285332
# -------
# pabloruizfabo@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# valerie.beaugiraud@ens-lyon.fr
# ens-lyon.fr
# 45.7298448 4.8285332
# -------
# marie.e.lescasse@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# marie-laure.massot@ens.fr
# ens.fr
# 48.8422058 2.3451689
# -------
# Eric.Guichard@enssib.fr
# enssib.fr
# 45.7801398 4.8625124
# -------
# pe.barrault@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# aurelien.berra@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# florence.andreacola@univ-grenoble-alpes.fr
# univ-grenoble-alpes.fr
# 45.1914198 5.7672724
# -------
# m.bourgatte@icp.fr
# icp.fr
# 48.8480625 2.3300993
# -------
# jakob.epler@dariah.eu
# dariah.eu
# 50.5546212 6.7628843
# -------
# Rene.Audet@lit.ulaval.ca
# lit.ulaval.ca
# 46.7817463 -71.2747424
# -------
# frederic.clavert@uni.lu
# uni.lu
# 46.9464269 7.4360048
# -------
# eric.kergosien@univ-lille3.fr
# univ-lille3.fr
# 50.627577 3.126726
# -------
# marionlame@gmail.com
# gmail.com
# 46.9464269 7.4360048
# -------
# 173

# %%
print len(my_nodesdict)
# Out:
# 173

# %%
def my_edges_list_singled() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                edge = {
                    "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    "weight" : float(2),
                    "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(5),
                "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)
    return my_edges
my_edges_singled=my_edges_list_singled()

# %%
my_edges=my_edges_singled
print my_edges
# Out:
# [{'data': {'source': 'jorge.fins@univ-tours.fr', 'name': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'id': u'./DHFRsample/2017-06/msg00011.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'legram@yahoogroupes.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'culture.numerique@ml.free.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'name': u': [DH] Conf\xe9rence de Marcello Vitali-Rosati [s\xe9minaire EPHN]', 'id': u'./DHFRsample/2018-03/msg00011.html', 'weight': 5.0, 'target': 'listesocius@groups.openedition.org'}}, {'data': {'source': 'claire.clivaz@sib.swiss', 'name': u': [DH] Poste de senior technical officer (Maynooth University)', 'id': u'./DHFRsample/2016-07/msg00030.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'laetitia.bontemps@univ-tours.fr', 'name': u': [DH] Stage initiation XML-TEI (Tours, octobre 2011)', 'id': u'./DHFRsample/2011-07/msg00004.html', 'weight': 5.0, 'target': 'DH@cru.fr'}}, {'data': {'source': 'stephane.pouyllau@huma-num.fr', 'name': u': Re: [DH] THATCamp Saint-Malo - Association francophone des Digital humanities', 'id': u'./DHFRsample/2013-07/msg00022.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'myriam.tazi@sciencespo.fr', 'name': u': Re: [DH] Prestation de d\xe9veloppement sous drupal', 'id': u'./DHFRsample/2017-06/msg00026.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'name': u': [DH] exploreAT! job offer @ vienna: citizen science & DIY science; cultural lexicographer', 'id': u'./DHFRsample/2017-06/msg00057.html', 'weight': 5.0, 'target': 'exploreAT@oeaw.ac.at'}}, {'data': {'source': 'camillemonnier33@hotmail.com', 'name': u': RE: [DH] Hackathon ESOBD (Pr\xe9vu, MC2, Cartographie Hesam)', 'id': u'./DHFRsample/2017-06/msg00027.html', 'weight': 5.0, 'target': 'dh@groupes.renater.fr'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'humanist@lists.digitalhumanities.org'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'globaloutlookdh-l@uleth.ca'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'digitalclassicist@jiscmail.ac.uk'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'dm-l@uleth.ca'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'dhd@mailman.rrz.uni-hamburg.de'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD-UNED', 'id': u'./DHFRsample/2016-07/msg00016.html', 'weight': 5.0, 'target': 'aiucd-l@humnet.unipi.it'}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'name': u': [DH] Post-doctoral 4 years DH position in Madrid at LINHD ...

# %%
def my_edges_list_by_source_dest() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    "weight" : float(2),
                    #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])+" "+
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(5),
                #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)
    return my_edges

my_edges_duped=my_edges_list_by_source_dest()
# Out:
# 527

# %%
def my_edges_list_with_subject() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    #"weight" : float(2),
                    "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                #"weight" : float(5),
                "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)

    return my_edges

my_edges_duped_with_subject=my_edges_list_with_subject()
# Out:
# 527

# %%
#WE HAVE TO TEST THE EDGES, BUT IT IS AN ARRAY OF DICTS,SO WE NEED TO FLATTEN THEM TO COUNT THEM SIMPLY

import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
def list_flattener_and_finder(edges_list_singled,edges_list_duped):
    from collections import Counter
    import ast
    my_edges_replacement_deduped=[]
    receiver=[]
    for i,dic in enumerate(edges_list_duped):
        #print my_edges[i]
        dicto=flatten(edges_list_duped[i])
    #    print dicto
        receiver.append(str(dicto))

    #print receiver
    CREE= Counter(receiver).iteritems()
    total=0
    dups=0
    dups_cnt=0
    
    print edges_list_singled[:1]
    for key, value in CREE:
        #print key
        #print value
        keyB={'data':{}}
        total+=1
        
        #print ast.literal_eval(key)["data_source"]
        #print ast.literal_eval(key)["data_target"]        
        keyB={'data':{"source":ast.literal_eval(key)["data_source"],"target": ast.literal_eval(key)["data_target"]}}
        #print "SUP",key, value
        dups+=value
        dups_cnt+=1
        #print ">>",keyB
        #print ast.literal_eval(key)["data_weight"]    
        keyB["data"]["weight"]= float(value*float(ast.literal_eval(key)["data_weight"]))
        #print "KEYB____",keyB
        my_edges_replacement_deduped.append(keyB)


            





    print "total",total

    print "dups",dups
    print "dups_cnt",dups_cnt
    return my_edges_replacement_deduped

listor=list_flattener_and_finder(my_edges,my_edges_duped)
print listor
# Out:
# []
# total 368
# dups 527
# dups_cnt 368
# [{'data': {'source': 'e.salvatori@mediev.unipi.it', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'delegue.general@adbu.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'graham.ranger@univ-avignon.fr', 'target': 'parislinguists@yahoogroupes.fr', 'weight': 5.0}}, {'data': {'source': 'Guillaume.Blum@design.ulaval.ca', 'target': 'docs-ri@yahoogroupes.fr', 'weight': 5.0}}, {'data': {'source': 'jahjah.marc@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'gpansu@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'liste-proml@lri.fr', 'weight': 5.0}}, {'data': {'source': 'emmanuelle.morlock@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'claire.lemercier@sciencespo.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'yamina.bensaadoune@univ-rouen.fr', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'aurelie.olivesi@wanadoo.fr', 'target': 'efigies-info@rezo.net', 'weight': 5.0}}, {'data': {'source': 'oledeuff@gmail.com', 'target': 'valerie.beaugiraud@ens-lyon.fr', 'weight': 5.0}}, {'data': {'source': 'jorge.fins@univ-tours.fr', 'target': 'dh@groupes.renater.fr', 'weight': 10.0}}, {'data': {'source': 'jbcamps@hotmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'enrico.natale@infoclio.ch', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'pe.barrault@gmail.com', 'target': 'emmanuelle.duwez@sciencespo.fr', 'weight': 5.0}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'target': 'air-l@listserv.aoir.org', 'weight': 5.0}}, {'data': {'source': 'michel.bernard@univ-paris3.fr', 'target': 'litor@listes.univ-paris3.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'docs-ri@yahoogroupes.fr', 'weight': 10.0}}, {'data': {'source': 'marionlame@gmail.com', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'elenagonzalezblanco@yahoo.es', 'target': 'air-l@listserv.aoir.org', 'weight': 5.0}}, {'data': {'source': 'Eveline.Wandl-Vogt@oeaw.ac.at', 'target': 'humanisticadh@gmail.com', 'weight': 5.0}}, {'data': {'source': 'Guillaume.Blum@design.ulaval.ca', 'target': 'liste-proml@lri.fr', 'weight': 5.0}}, {'data': {'source': 'listes@ahicf.com', 'target': 'athena@services.cnrs.fr', 'weight': 20.0}}, {'data': {'source': 'cecile.boulaire@univ-tours.fr', 'target': 'christine.benevent@univ-tours.fr', 'weight': 2.0}}, {'data': {'source': 'oledeuff@gmail.com', 'target': 'claire.clivaz@unil.ch', 'weight': 2.0}}, {'data': {'source': 'pierre.mounier@openedition.org', 'target': 'frederic@clavert.net', 'weight': 5.0}}, {'data': {'source': 'espejosuros.javier@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'vial.stephane@gmail.com', 'target': 'theuth@listes.univ-rennes1.fr', 'weight': 5.0}}, {'data': {'source': 'eric.kergosien@univ-lille3.fr', 'target': 'info-ic@listes.irisa.fr', 'weight': 15.0}}, {'data': {'source': 'beauguittelaurent@hotmail.com', 'target': 'martaseve@gmail.com', 'weight': 2.0}}, {'data': {'source': 'vial.stephane@gmail.com', 'target': 'projekt-membres@liste.unimes.fr', 'weight': 5.0}}, {'data': {'source': 'muriel.foulonneau@gmail.com', 'target': 'dh@cru.fr', 'weight': 5.0}}, {'data': {'source': 'aurelie.olivesi@gmail.com', 'target': 'dh@groupes.renater.fr', 'weight': 5.0}}, {'data': {'source': 'ottaviano.nancy@gmail.com', 'target': 'diffusion@listes.ancmsp.com', 'weight': 5.0}}, {'data': {'source': 'dumouchelsuzanne@yahoo.fr', 'target': 'legram@yahoogroupes.fr', 'weight': 15.0}}, {'data': {'source': 'carmen.brando@gmail.com', 'target': 'humanist@lists.digitalhumanities.org', 'weight': 5.0}}, {'data': {'source': 'jorge.fins@univ-tours.fr', 'target': 'huyghe.marie@gmail.com', 'weight': 5.0}}, {'data': {'source': 'marionlame@gmail.com', 'target': 'dh@cru.fr', 'weight': 2.0}},  ...

# %%
res=dups/dups_cnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-92eb4abda3ae> in <module>()
# ----> 1 res=dups/dups_cnt
#       2
#
# NameError: name 'dups' is not defined

# %%
my_edges=listor

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:requests.packages.urllib3.connection:Certificate did not match expected hostname: app.topogram.io. Certificate: {'subjectAltName': [('DNS', 'portailwifi.ens-lyon.fr'), ('DNS', 'portailwifi2.ens-lyon.fr')], 'subject': ((('commonName', u'portailwifi.ens-lyon.fr'),),)}
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-91-9c7404c2ee39> in <module>()
#       1 # connect to the topogram instance (pass debug=True params for more info )
# ----> 2 topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)
#       3
#       4 # create a new user
#       5 try :
#
# /home/goonieb/anaconda2/lib/python2.7/site-packages/topogram_api_client-1.0.0-py2.7.egg/topogram_client/__init__.pyc in __init__(self, base_url, debug)
#      25
#      26         log.debug("Init Topogram API at %s", base_url)
# ---> 27         self.check_active_connection() # check if the connection is ready
#      28
#      29     def make_url(self, path):
#
# /home/goonieb/anaconda2/lib/python2.7/site-packages/topogram_api_client-1.0.0-py2.7.egg/topogram_client/__init__.pyc in check_active_connection(self)
#      71
#      72     def check_active_connection(self):
# ---> 73         r = self.make_request("GET", " ", {})
#      74         assert r["status_code"] == 200
#      75
#
# /home/goonieb/anaconda2/lib/python2.7/site-packages/topogram_api_client-1.0.0-py2.7.egg/topogram_client/__init__.pyc in make_request(self, method, path, data)
#      46             r = self.session.delete(req_url, json=data)
#      47         elif method == "GET":
# ---> 48             r = self.session.get(req_url, json=data)
#      49         elif method == "PUT":
#      50             r = self.session.put(req_url, json=data)
#
# /home/goonieb/.local/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     499
#     500         kwargs.setdefault('allow_redirects', True)
# --> 501         return self.request('GET', url, **kwargs)
#     502
#     503     def options(self, url, **kwargs):
#
# /home/goonieb/.local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /home/goonieb/.local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /home/goonieb/.local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     495         except (_SSLError, _HTTPError) as e:
#     496             if isinstance(e, _SSLError):
# --> 497                 raise SSLError(e, request=request)
#     498             elif isinstance(e, ReadTimeoutError):
#     499                 raise ReadTimeout(e, request=request)
#
# SSLError: hostname 'app.topogram.io' doesn't match either of 'portailwifi.ens-lyon.fr', 'portailwifi2.ens-lyon.fr'

# %%
#print my_edges
list_nodes_id=[] 
for nodes in  my_nodesdictList:
    if nodes['data']['id'] not in list_nodes_id:
        list_nodes_id.append(nodes['data']['id'])
    
print len(list_nodes_id)

print list_nodes_id
for edge in my_edges:
    source= edge['data']['source']
    target= edge['data']['target']
    if source not in list_nodes_id:
        print "NO!"
        print source
    if target not in list_nodes_id:
        print "NO2!"
        print target
# Out:
# 173
# ['frederic@clavert.net', 'audrey.baneyx@sciencespo.fr', 'vial.stephane@gmail.com', 'marie.e.lescasse@gmail.com', 'laurence.rageot@univ-tours.fr', 'clemence.jacquot@gmail.com', 'michel.bernard@univ-paris3.fr', 'laurent.romary@inria.fr', 'valerie.beaugiraud@ens-lyon.fr', 'ottaviano.nancy@gmail.com', 'yamina.bensaadoune@univ-rouen.fr', 'alexandre.hocquet@univ-lorraine.fr', 'beatrice.markhoff@univ-tours.fr', 'm.bourgatte@icp.fr', 'dominique.stutzmann@irht.cnrs.fr', 'caroline.cance@univ-orleans.fr', 'jerome.darmont@univ-lyon2.fr', 'pascal.cristofoli@ehess.fr', 'Mathieu.Andro@versailles.inra.fr', 'Guillaume.Blum@design.ulaval.ca', 'fatihaidmhand@yahoo.es', 'adeline.joffres@huma-num.fr', 'ncasanova@mmsh.univ-aix.fr', 'richard.walter@ens.fr', 'pierre.mounier@openedition.org', 'nadine.dardenne@cnrs.fr', 'hdefouca@u-paris10.fr', 'aurelie.olivesi@wanadoo.fr', 'caroline.rossi@univ-grenoble-alpes.fr', 'lisette.calderan@inria.fr', 'julia.bonaccorsi@univ-lyon2.fr', 'cecile.boulaire@univ-tours.fr', 'myriam.tazi@sciencespo.fr', 'anne-laure.brisac@inha.fr', 'judith.hannoun@univ-amu.fr', 'camillemonnier33@hotmail.com', 'elisabeth.belmas@wanadoo.fr', 'paul.girard@sciencespo.fr', 'delegue.general@adbu.fr', 'enrico.natale@infoclio.ch', 'marie-laure.massot@ens.fr', 'thierry.poibeau@ens.fr', 'jorge.fins@univ-tours.fr', 'michaelesinatra@gmail.com', 'secardinolivier@yahoo.fr', 'francesco.beretta@ish-lyon.cnrs.fr', 'florence.andreacola@univ-grenoble-alpes.fr', 'gpansu@gmail.com', 'jerome.valluy@univ-paris1.fr', 'formation.continue@enc-sorbonne.fr', 'jea.herzog@gmail.com', 'emmanuelle.morlock@gmail.com', 'jouni.tuominen@helsinki.fi', 'nicolas.legrand@obspm.fr', 'stephane.loret@univ-nantes.fr', 'jahjah.marc@gmail.com', 'isabelle.thiebau@univ-lille2.fr', 'jouni.tuominen@aalto.fi', 'raphaelle.bour@irit.fr', 'florent.laroche@ec-nantes.fr', 'marin.dacos@revues.org', 'stephane.pouyllau@huma-num.fr', 'cecile.rodrigues@cnrs.fr', 'projet.iglouvre@gmail.com', 'Rene.Audet@lit.ulaval.ca', 'marjorie.burghart@ehess.fr', 'Nicolas.Larrousse@huma-num.fr', 'dumouchelsuzanne@yahoo.fr', 'muriel.foulonneau@gmail.com', 'martin.grandjean@unil.ch', 'antoine.blanchard@gmail.com', 'sarah.cadorel@sciencespo.fr', 'listes@ahicf.com', 'recherche.coordination@bnf.fr', 'beauguittelaurent@hotmail.com', 'amel.fraisse@univ-lille3.fr', 'MKoenig@dhi-paris.fr', 'sandrine.breuil@univ-tours.fr', 'benoit.epron@enssib.fr', 'gerald.kembellec@cnam.fr', 'nicolas.thely@univ-rennes2.fr', 'Francoise.Blum@univ-paris1.fr', 'pabloruizfabo@gmail.com', 'caroline.muller@univ-reims.fr', 'sandrine.clerisse@cnrs.fr', 'gresillon@cmb.hu-berlin.de', 'ghislain.sillaume@cvce.eu', 'elinaleblanc3007@gmail.com', 'jbcamps@hotmail.com', 'Eric.Guichard@enssib.fr', 'iglouvremb@gmail.com', 'georges-xavier.blary@unilim.fr', 'sylvain.laube@univ-brest.fr', 'anne.baillot@gmail.com', 'laetitia.bontemps@univ-tours.fr', 'aurelie.olivesi@gmail.com', 'aamonnz@gmail.com', 'jakob.epler@dariah.eu', 'stamkou@free.fr', 'cecile.soudan@ehess.fr', 'raphaelle.krummeich@univ-rouen.fr', 'florence.clavaud@free.fr', 'Frederic.Clavert@unil.ch', 'cynthia.pedroja@meshs.fr', 'elodie.faath@openedition.org', 'olfa.lamloum@gmail.com', 'svhoolan@ulb.ac.be', 'carmen.brando@gmail.com', 'eric.kergosien@univ-lille3.fr', 'elenagonzalezblanco@yahoo.es', 'clarisse_bardiot@mac.com', 'manuel.zacklad@cnam.fr', 'jf.omhover@histographe.com', 'aurelien.berra@gmail.com', 'mehdi.khamassi@upmc.fr', 'nicolasthelyrennes2@gmail.com', 'yosra.ghliss17@gmail.com', 'laurens@ehess.fr', 'Daniel.Stoekl@ephe.sorbonne.fr', 'espejosuros.javier@gmail.com', 'clarisse_bardiot@me.com', 'e.salvatori@mediev.unipi.it', 'claire.lemercier@sciencespo.fr', 'viera.rebolledodhuin@free.fr', 'gerald.kembellec@lecnam.net', 'antonio.casilli@googlemail.com', 'joel.marchand@huma-num.fr', 'amelie.vairelles@sciencespo.fr', 'martaseve@gmail.com', 'christine.chadier@univ-lyon3.fr', 'emmanuelguez@yahoo.fr', 'Eveline.Wandl-Vogt@oeaw.ac.at', 'colette.cadiou@irstea.fr', 'stefanev@club-internet.fr', 'emilien ...
# NO2!
# dh@groupes.renater.fr
# NO2!
# legram@yahoogroupes.fr
# NO2!
# culture.numerique@ml.free.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# listesocius@groups.openedition.org
# NO2!
# dh@groupes.renater.fr
# NO2!
# DH@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# exploreAT@oeaw.ac.at
# NO2!
# dh@groupes.renater.fr
# NO2!
# humanist@lists.digitalhumanities.org
# NO2!
# globaloutlookdh-l@uleth.ca
# NO2!
# digitalclassicist@jiscmail.ac.uk
# NO2!
# dm-l@uleth.ca
# NO2!
# dhd@mailman.rrz.uni-hamburg.de
# NO2!
# aiucd-l@humnet.unipi.it
# NO2!
# air-l@aoir.org
# NO2!
# institute@lists.uvic.ca
# NO2!
# dh@groupes.renater.fr
# NO2!
# tei-l@listserv.brown.edu
# NO2!
# humanist-l@uleth.ca
# NO2!
# centernet@lists.digitalhumanities.org
# NO2!
# dhcarolina@listserv.unc.edu
# NO2!
# humanidadesdigitais@gmail.com
# NO2!
# website@hastac.org
# NO2!
# southasia-dh@lists.globaloutlookdh.org
# NO2!
# air-l@listserv.aoir.org
# NO2!
# humanisticadh@gmail.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# jean-daniel.fekete@inria.fr
# NO2!
# Nicole.Dufournaud@laposte.net
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# archives-son-audiovisuel@groups.openedition.org
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# francesca.frontini@univ-montp3.fr
# NO2!
# liste-egc@polytech.univ-nantes.fr
# NO2!
# bull-i3@irit.fr
# NO2!
# info-ic@listes.irisa.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# ln@cines.fr
# NO2!
# humanist@lists.digitalhumanities.org
# NO2!
# humanum-veille@listes.huma-num.fr
# NO2!
# humanum-diffusion@listes.huma-num.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# thibault.clerice@enc-sorbonne.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# adherents-aipu-fr@groupes.renater.fr
# NO2!
# afec-info@groupes.renater.fr
# NO2!
# anstia-adherents@groupes.renater.fr
# NO2!
# debuter-en-dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# emploi-fle@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# histoire_eco-request@groupes.renater.fr
# NO2!
# athena@services.cnrs.fr
# NO2!
# archives-fr@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# nep-his@lists.repec.org
# NO2!
# medici@listes.huma-num.fr
# NO2!
# ferinterfrance@googlegroups.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# lisa.chupin@gmail.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# liste-egc@polytech.univ-nantes.fr
# NO2!
# info-ic@listes.irisa.fr
# NO2!
# ln@cines.fr
# NO2!
# magis@imag.fr
# NO2!
# bull-i3@irit.fr
# NO2!
# inforsid@listes.insa-lyon.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# quanti@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# rbdd@services.cnrs.fr
# NO2!
# helene.coste@univ-lehavre.fr
# NO2!
# valerie.neouze@parisdescartes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# recherche-design@listes.univ-paris1.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# projekt-membres@liste.unimes.fr
# NO2!
# projekt@unimes.fr
# NO2!
# info@design-fax.fr
# NO2!
# athena@services.cnrs.fr
# NO2!
# theuth@listes.univ-rennes1.fr
# NO2!
# culture.numerique@ml.free.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# txm-users@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# culture.numerique@ml.free.fr
# NO2!
# legram@yahoogroupes.fr
# NO2!
# listesocius@groups.openedition.org
# NO2!
# gregory.grefenstette@inria.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# gregory.grefenstette@inria.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# christine.benevent@univ-tours.fr
# NO2!
# laurent.gerbier@univ-tours.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# tei-fr@groupes.renater.fr
# NO2!
# christine.benevent@univ-tours.fr
# NO2!
# laurent.gerbier@univ-tours.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# liste-egc@polytech.univ-nantes.fr
# NO2!
# info-ic@listes.irisa.fr
# NO2!
# magis@imag.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# bull-i3@irit.fr
# NO2!
# ln@cines.fr
# NO2!
# liste-proml@lri.fr
# NO2!
# docs-ri@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dhd@mailman.rrz.uni-hamburg.de
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# legram@yahoogroupes.fr
# NO2!
# culture.numerique@ml.free.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# geotamtam@unil.ch
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# sabine.loudcher@univ-lyon2.fr
# NO2!
# sarah.cordonnier@gmail.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh-request@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh-request@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# aurelie.olivesi@univ-lyon1.fr
# NO2!
# diffusion@listes.ancmsp.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# efigies-info@rezo.net
# NO2!
# etudesfeministes-l@simone.univ-tlse2.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# Marie-Laure.Massot@ens.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# Marie-Laure.Massot@ens.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# huyghe.marie@gmail.com
# NO2!
# laurent.cailly@univ-tours.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# huyghe.marie@gmail.com
# NO2!
# laurent.cailly@univ-tours.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# corpus-ecrits@cru.fr
# NO2!
# cahier@groupes.renater.fr
# NO2!
# ln@cines.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# llist@unil.ch
# NO2!
# dh@groupes.renater.fr
# NO2!
# histoire_eco-request@groupes.renater.fr
# NO2!
# athena@services.cnrs.fr
# NO2!
# archives-fr@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# nep-his@lists.repec.org
# NO2!
# medici@listes.huma-num.fr
# NO2!
# ferinterfrance@googlegroups.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# liste-egc@polytech.univ-nantes.fr
# NO2!
# info-ic@listes.irisa.fr
# NO2!
# magis@imag.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# bull-i3@irit.fr
# NO2!
# ln@cines.fr
# NO2!
# liste-proml@lri.fr
# NO2!
# docs-ri@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# DH@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh-request@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh-request@groupes.renater.fr
# NO2!
# litor@listes.univ-paris3.fr
# NO2!
# dh@cru.fr
# NO2!
# numeruniv-quotidien@cines.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# cerisier@univ-poitiers.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# cerisier@univ-poitiers.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# histoire_eco-request@groupes.renater.fr
# NO2!
# athena@services.cnrs.fr
# NO2!
# archives-fr@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# nep-his@lists.repec.org
# NO2!
# medici@listes.huma-num.fr
# NO2!
# ferinterfrance@googlegroups.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# schassan@hab.de
# NO2!
# c.schoech@gmail.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# info-ic@listes.irisa.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@cru.fr
# NO2!
# tei-fr@groupes.renater.fr
# NO2!
# tei-fr@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# tei-fr@groupes.renater.fr
# NO2!
# tei-fr@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dhd@mailman.rrz.uni-hamburg.de
# NO2!
# air-l@aoir.org
# NO2!
# dh@groupes.renater.fr
# NO2!
# institute@lists.uvic.ca
# NO2!
# globaloutlookdh-l@uleth.ca
# NO2!
# humanist-l@uleth.ca
# NO2!
# dhcarolina@listserv.unc.edu
# NO2!
# humanidadesdigitais@gmail.com
# NO2!
# website@hastac.org
# NO2!
# southasia-dh@lists.globaloutlookdh.org
# NO2!
# air-l@listserv.aoir.org
# NO2!
# humanisticadh@gmail.com
# NO2!
# ahdig@googlegroups.com
# NO2!
# textualscholarship@jiscmail.ac.uk
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# olivier.marlet@univ-tours.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# ontologie-patrimoine@services.cnrs.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# diffusion@listes.ancmsp.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# tei-fr@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# digit_hum@ens.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# digit_hum@ens.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# corpora@uib.no
# NO2!
# saes@univ-pau.fr
# NO2!
# alaes_liste@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# parislinguists@yahoogroupes.fr
# NO2!
# agorantic@listes.univ-avignon.fr
# NO2!
# tei-l@listserv.brown.edu
# NO2!
# humanist@lists.digitalhumanities.org
# NO2!
# digitalclassicist@jiscmail.ac.uk
# NO2!
# dm-l@uleth.ca
# NO2!
# dhd@mailman.rrz.uni-hamburg.de
# NO2!
# globaloutlookdh-l@uleth.ca
# NO2!
# iwetel@listserv.rediris.es
# NO2!
# aiucd-l@humnet.unipi.it
# NO2!
# air-l@aoir.org
# NO2!
# institute@lists.uvic.ca
# NO2!
# dh@groupes.renater.fr
# NO2!
# INFOLING@LISTSERV.REDIRIS.ES
# NO2!
# infoling@listserv.rediris.es
# NO2!
# humanist-l@uleth.ca
# NO2!
# redhd@humanidadesdigitales.net
# NO2!
# centernet@lists.digitalhumanities.org
# NO2!
# dhcarolina@listserv.unc.edu
# NO2!
# website@hastac.org
# NO2!
# humanidadesdigitais@gmail.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# fil-tmd@groupes.renater.fr
# NO2!
# liste-egc@polytech.univ-nantes.fr
# NO2!
# eda-liste@listes.univ-lyon2.fr
# NO2!
# gazettebd3@imag.fr
# NO2!
# bull-i3@irit.fr
# NO2!
# madics-adoc@listes.univ-lyon2.fr
# NO2!
# annonces@madics.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# TEXTUALSCHOLARSHIP@jiscmail.ac.uk
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# histoire_eco-request@groupes.renater.fr
# NO2!
# athena@services.cnrs.fr
# NO2!
# archives-fr@yahoogroupes.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# nep-his@lists.repec.org
# NO2!
# medici@listes.huma-num.fr
# NO2!
# ferinterfrance@googlegroups.com
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# txm-users@groupes.renater.fr
# NO2!
# corpus-ecrits@cru.fr
# NO2!
# ln@cines.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@cru.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# ln@cines.fr
# NO2!
# liste-egc@polytech.univ-nantes.fr
# NO2!
# info-ic@listes.irisa.fr
# NO2!
# dh@groupes.renater.fr
# NO2!
# adbs-info@listes.adbs.fr
# NO2!
# bull-i3@irit.fr
# NO2!
# accesouvert@groupes.renater.fr
# NO2!
# docs-ri@yahoogroupes.fr
# NO2!
# doccitanist@services.cnrs.fr
# NO2!
# info-aria@lsis.org
# NO2!
# inforsid@listes.insa-lyon.fr
# NO2!
# dh@groupes.renater.fr

# %%
title = "alphaDH15"
create_topogram(title, my_nodesdictList, my_edges)
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# Creating topogram 'alphaDH15'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'alphaDH15', u'userId': u'MSreQEjksjoK2igp5', u'_id': u'RA27zh39RGRrb6cNu', u'slug': u'alphadh15', u'createdAt': u'2018-04-24T09:01:42.822Z'}, u'statusCode': 200}
# topogram ID : RA27zh39RGRrb6cNu
# 173 nodes deleted
# 527 edges deleted
# {u'status': u'success', 'status_code': 200, u'data': [u'qeSJrZMvJ2RzQyrWc', u'hKaYgN8YtpW6qecZA', u'5XzMAK5S46n2DDmxu', u'vnuTWdTn6k69RLDXz', u'rdm7Y5pMzDNmundma', u'aRthjkfbcb74XqDWq', u'gSfEX82C4NzohM4EW', u'ZgRbTjmiuJBei77Kx', u'MzR8yXRMfK95ZXaBi', u'eo5H5u9rCHCHdgpvj', u'JPscxMM2zh7zvqBqK', u'huNrYAQYth2Sn2Atz', u'C6eYYyfEQoRuiP3tz', u'vhY2myPutDnbWgTyZ', u'nW9sr5xFP5AvgQttP', u'Q3K8wh5yanjpBfqk7', u'KiZTY5Z95AW6azmWb', u'aPSBKDkFMxvsSP96R', u'pQSGkvDhMauJPAiyD', u'CgM5KW6cTCAzHvPrB', u'rgGAwXfw4TigGpzcu', u'piMM8gkCnDFiwvr8t', u'9qAjqq3xdnQvaMM4f', u'ScyodWeaFYQCJHbYn', u'cCTpE4A653PXf7SvW', u'fbvwYjqLRHdqdDgoG', u'gjChCcX5XfdQYdkox', u'qzacgtXkXrztvw6LJ', u'HcBPBsazHHtGCp4FF', u'EXcwtPiJXz6nD5efP', u'3vWvxeqHP4YRy9ezq', u'7dX2Yew45fYzgkenC', u'zPwtE4NiYYm6rFWoF', u'dqht5ePpoBv2wYd68', u'pL2GNj9SJhGdLZDuj', u'pxjrE8vNpwdPh8D7y', u'RXJX6piTuvMJkFSg3', u'xHnE9Aui5cFBsXFTH', u'qAE4wD7CaxjMMfHjt', u'ABdYcdxXJu5HkBGZX', u'HZ89vYjxNhHmKJCzt', u'TPCQ43H6JdnQ8qMZj', u'S59TeZAQdmvuNQijv', u'aTsPNJpSPzbPydKWv', u'NfDbqM4ayvFCawbQj', u'zNvRugoLz4pxJj4gi', u'wvtegWGttyn6EBhkw', u'3SExJ6T7jxbdYc2CT', u'rKbnPkLKuPqaossBi', u'vT4ruABR7xGb9eTKn', u'amJzE8oXKngpZ5doi', u'KGXWb4kvCzqXmH4jp', u'95pGpd6NcLJtzdKGJ', u'Tv7PXWzFXx4ixRmHA', u'WHDdnj5RfFhp9HfH9', u'aErfgxatgEr4CtxPC', u'8CSauBJEpZvL7JNxW', u'qfZpqyxKBLgFXbtBt', u'fKy2mBWrwoGAZkjro', u'ogJgLLvkRPLQCtthb', u'EkZBTEeZcvt9RQ6s8', u'nJmb4LMmkDLgyfTB8', u'N5ZWsyfnW5RQHX2XF', u'BMBjXCJiv7NxP2nWn', u'HBWmuWjk6uZ57iMYy', u'5K8ku74arZNWK2Cno', u'xj6X5ardDK6WZqMY6', u'j5uw6NCHPmFFdEaCf', u'vM4e4LgDgBSoD88pe', u'shhAQkWpacFv8XsYE', u'xXgZraeypGGd4zcuc', u'Ed7aErB5oAv46ZoMT', u'cgrMGjh6rusHfe6S8', u'CNJfwQgertrpkB4aA', u'cCxuQAnphePYnZedB', u'nmyco4EbyzWfw9Gq7', u'reLmw5Quxn5vxTmGv', u'oxX2Gg3zXuYiT6XT3', u'97dQM6vWY7uDb9Fy4', u'892r9fP2tT8tz9EHD', u'LsJs7pJKiqFXbEFZb', u'Q9aLDZgNg4HXochCC', u'nrQE2pyE2nNHRFmAc', u'i6XaG4369SWj2f96M', u'C3qeQt7MjeFwNAngj', u'tgMMncteCvebAhkwG', u'syuDBh7vsrSrhf8oY', u'Ps8Gq67jxvWENa2QX', u'j3gp87C6QnjbxFA5R', u'QjDZNnmW7mY8BpY4D', u'bvq7r9ZD65rKmqXSD', u'K43NsSunqMzSkz9bj', u'3CGifgWgg3firrd4x', u'AdfKMKHkHAyPxWsWi', u'7zBce8vfmqYxzkXaw', u'CMqvEkbK593kbpo2i', u'e2eAaLfyKru7XcNWW', u'HDMoFvdiBD2bDb9p8', u'oXC4MvySBbHzm9cRc', u'R97oZfPY2gCwT2veq', u'uBCB5p56Z75qiN5w3', u'H8Rtw5CacToXvTxfz', u'6Q9T4yoM7tHBE36ck', u'dJhL6qQSwLm3bYCxn', u'22LCiLQQReW78Mste', u'yNr8bhP9FjHYXeJWx', u'gHWMmooKtqwLy4ysW', u'phfeXrM8isdR4Ci6k', u'4CqHCwAuy3HXPP5mM', u'PPfz2DhWuh3ZP3CBJ', u'4tD9d5b62GACoECHf', u'LdCxxEpej3Cwy9MqL', u'RcdN5qfFJcqGMj6yQ', u'3wwdeKqiSREP7AXTy', u'w4aPrCk97ppSH24iW', u'oBWwSQnnDZniehvK3', u'ufBcFC5m3RKzP3afJ', u'YqhJBhTzWugyKMABc', u'xgpZ86aXdGFJrjP8d', u'euB8jqTyTnpBhrNce', u'i4g6htDPwWiKJ5oej', u'57doMiQpznXeJKR5c', u'GXF9AGyaSj8hfWui8', u'FDvYtmrgjAR5Em4kf', u'NhPSPxxE9YgrP2xAG', u'jk3yjdsKhQ49e2aE6', u'tSFJEzL9qdAGczrdS', u'jaqxSvRgpK3abcuJK', u'nqqKxBCeW8Y8bg5o9', u'DF3Fzv943KBDS9qoQ', u't65knaspcfBDzXRiB', u'GnjMPDqmv7JZqogAF', u'PsFixGgBopjXN8e49', u'uXnWLX5DkLtsK2wvd', u'u9nmTDL2uvxrRzbfx', u'bNBD8Yx7u6GZZQZcg', u'y2fziuv5W8QTiENME', u'HtWPh7nxB8CmJFanY', u'YCTkLyLEXkMZ5qXCT', u'gdfMj6XDXWZbf8i9i', u'QmofGdPkTeq3y2REA', u'z4f4QZEEm52thKKrv', u'WMPyja2dZ7DQ95fDj', u'KsPCZx2H8Cx9dRBfX', u'4SGGPXyLkiCdswP8b', u'B9yNRCaCKhXxcS3D2', u'r8ydkNxAE6jebcrz2', u'fnZY5Ei6eNHrxodF6', u'by2aNM7SbeK5YENwf', u'D7ikNF7RiDzayfocA', u'J8i2NrBFcrcudsrbh', u'7ewv4gjA8yTs7oDkg', u'JPyh7gTbBHswCNwta', u'PZ3z4xj9CRxGwm24d', u'rGyGvnqRLuCEegpux', u'YHxCY2Wqg482EngFT', u'K9kYBhLeSYzexiZsm', u'vSJCRc6bFBBQZR2Hg', u'dp8xnCXmLockZJZmP', u'2zY8CjHSe9gxNAto3', u'R6TX8Eg4kqvvWfNmT', u'iX9hMn6DBsCABYNua', u'GSjMcWaxQ5YRrACgR', u'JWprWmtadAo3nYXpL', u'zDPpnoNoajquPHks2', u'k5dbg3RBf8FwpQTR3', u'MmkEYgzeWfkLr5TfQ', u'iS2BHdcFN9dYMG6WM', u'ZD47XctntThwCWqTW', u'PzedqMpoJGGQCCbzx', u'QX4mktzv2RqnfQtkC', u'dFZYxFdDhkAniaX7u', u'tzMAG9KtYM2cjM9Gz'], u'statusCode': 201}
# 173 nodes created.
# 527 edges created.
# done. Topogram has been updated. Check it at http://localhost:3000/topograms/RA27zh39RGRrb6cNu
